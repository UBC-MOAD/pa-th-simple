# %% [markdown]
# Solves the [Th] on a 2D grid using an upwind advection scheme, and contains plots of [Th] profile for a zero velocity field, a single cell velocity field, and a two cell velocity field.

# %%
from __future__ import division
import numpy
import pylab
import math
import matplotlib.pyplot as plt
from math import pi
import Th2D
# %matplotlib inline

# %%
reload(Th2D)
# Out:
# <module 'Th2D' from 'Th2D.py'>

# %% [markdown]
# # [Th] for Zero Velocity Field

# %%
# set parameters

T = 1
V = 1/10
xmin = 1
xmax = 1000000
zmin = 0
zmax = 5000
nz = 20
nx = 20

# chemistry
[k_ad, k_de, Q] = Th2D.k_sorp('Th', xmin, xmax, zmin, zmax, nx, nz)

# velocity
[u, flowfig] = Th2D.u_zero(xmin, xmax, zmin, zmax, nx, nz)

# [Th] loop
[flowfig, meshTh, DTh, PTh] = Th2D.adflow(T, V, u, nz, nx, k_ad, k_de, Q, flowfig, 'Th')

# %%
T = 2
[flowfig, meshTh, DTh, PTh] = Th2D.adflow(T, V, u, nz, nx, k_ad, k_de, Q, flowfig, 'Th')
pylab.close(1)

# %%
T = 3
[flowfig, meshTh, DTh, PTh] = Th2D.adflow(T, V, u, nz, nx, k_ad, k_de, Q, flowfig, 'Th')
pylab.close(1)

# %%
T = 5
[flowfig, meshTh, DTh, PTh] = Th2D.adflow(T, V, u, nz, nx, k_ad, k_de, Q, flowfig, 'Th')
pylab.close(1)

# %%
T = 10
[flowfig, meshTh, DTh, PTh] = Th2D.adflow(T, V, u, nz, nx, k_ad, k_de, Q, flowfig, 'Th')
pylab.close(1)

# %% [markdown]
# Since the distribution and magnitude of the [Th] does not change between 50 and 100 years, the system appears to reach steady state after 50 years.

# %% [markdown]
# # [Th] for Single Cell Velocity Field

# %%
reload(Th2D)
# Out:
# <module 'Th2D' from 'Th2D.pyc'>

# %%
# set parameters

T = 1
V = 1
xmin = 1
xmax = 1000000
zmin = 0
zmax = 5000
nz = 60
nx = 30

# chemistry
[k_ad, k_de, Q] = Th2D.k_sorp('Th', xmin, xmax, zmin, zmax, nx, nz)

# velocity
[u, flowfig] = Th2D.u_simple(xmin, xmax, zmin, zmax, nx, nz)

# [Th] loop
[flowfig, meshTh, DTh, PTh] = Th2D.adflow(T, V, u, nz, nx, k_ad, k_de, Q, flowfig, 'Th')

# %%
T = 2
[flowfig, meshTh, DTh, PTh] = Th2D.adflow(T, V, u, nz, nx, k_ad, k_de, Q, flowfig, 'Th')
pylab.close(1)

# %%
T = 3
[flowfig, meshTh, DTh, PTh] = Th2D.adflow(T, V, u, nz, nx, k_ad, k_de, Q, flowfig, 'Th')
pylab.close(1)

# %%
T = 5
[flowfig, meshTh, DTh, PTh] = Th2D.adflow(T, V, u, nz, nx, k_ad, k_de, Q, flowfig, 'Th')
pylab.close(1)

# %%
T = 6
[flowfig, meshTh, DTh, PTh] = Th2D.adflow(T, V, u, nz, nx, k_ad, k_de, Q, flowfig, 'Th')
pylab.close(1)

# %%
T = 10
[flowfig, meshTh, DTh, PTh] = Th2D.adflow(T, V, u, nz, nx, k_ad, k_de, Q, flowfig, 'Th')
pylab.close(1)

# %% [markdown]
# These figures show that the steady state is reached after 30 years. The steady state is different from steady state in the static case: the downwelling region exhibits higher [Th] (left), and the upwellling exhibits lower [Th] (right), as opposed to a horizontally uniform distribution.
#
# Explanation: the velocity scheme is superposed on the background sinking velocity of particulate Th, S = 500 m/yr. The overall sinking rate is therefore minimal in upwelling region, and maximal in downwelling region. The downwelling region should reach a steady state quickly, because the faster the sinking rate, the faster the initial distribution falls out.
#
# Why is the steady state different from the zero velocity steady state?
#
# Increasing the sinking velocity in the 1D model increases the maximum [Th] at z = zmax. This is congruent to the horizontally varying effect observed here.
#
# Why does downwelling and/or a faster sinking rate increase the magnitude of the steady state[Th]?

# %% [markdown]
# # [Th] for Two Cell Velocity Scheme

# %%
reload(Th2D)
# Out:
# <module 'Th2D' from 'Th2D.py'>

# %%
# setup function adflow for Th 

T = 1
V = 1/10
xmin = 1
xmax = 1e6
zmin = 0
zmax = 5e3
nz = 20
nx = 20

# chemistry
[k_ad, k_de, Q] = Th2D.k_sorp('Th', xmin, xmax, zmin, zmax, nx, nz)

# velocity
[u, flowfig] = Th2D.u_complex(xmin, xmax, zmin, zmax, nx, nz)

# Th loop
[flowfig, meshTh, DTh, PTh] = Th2D.adflow(T, V, u, nz, nx, k_ad, k_de, Q, flowfig, 'Th')

# %%
T = 2
[flowfig, meshTh, DTh, PTh] = Th2D.adflow(T, V, u, nz, nx, k_ad, k_de, Q, flowfig, 'Th')
pylab.close(1)

# %%
T = 3
[flowfig, meshTh, DTh, PTh] = Th2D.adflow(T, V, u, nz, nx, k_ad, k_de, Q, flowfig, 'Th')
pylab.close(1)

# %%
T = 5
[flowfig, meshTh, DTh, PTh] = Th2D.adflow(T, V, u, nz, nx, k_ad, k_de, Q, flowfig, 'Th')
pylab.close(1)

# %%
T = 10
[flowfig, meshTh, DTh, PTh] = Th2D.adflow(T, V, u, nz, nx, k_ad, k_de, Q, flowfig, 'Th')
pylab.close(1)

# %% [markdown]
# The solution is 90% similar to the steady state after 50 years. The maximal [Th] increases only slightly between 50 and 100 years. The solution exhibits higher [Th] in regions of downwelling velocity, and lower [Th] in regions of upwelling.

# %%
run = {
    'Th_0vel_dis': ,
    'b': 2,
}

# %%
d
# Out:
# {'a': 1, 'b': 2}

# %%
d['a']
# Out:
# 1

# %%
[1, 'a', 3]
# Out:
# [1, 'a', 3]

# %%
a = (1, 2, 3)

# %%
a[1]
# Out:
# 2

# %%
a = 1
b = 2
a, b = b, a
print a, b
# Out:
# 2 1

# %%
s = set([1, 2, 3, 1])
s
# Out:
# {1, 2, 3}

# %%
s.
