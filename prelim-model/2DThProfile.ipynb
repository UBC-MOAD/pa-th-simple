# %% [markdown]
# Solves the [Th] on a 2D grid using an upwind advection scheme, and contains plots of [Th] profile for a zero velocity field, a single cell velocity field, and a two cell velocity field.

# %%
from __future__ import division
import numpy
import pylab
import math
import matplotlib.pyplot as plt
from math import pi
import ThPa2D
# %matplotlib inline

# %% [markdown]
# # [Th] for Zero Velocity Field

# %%
# setup function adflow for Th 
reload(ThPa2D)
tmax = (0, 1, 2, 3, 5, 10, 20, 60, 100)
t = tmax[0]
T = tmax[1]
V = 0.02/1000*365.*86400.
xmin = 0
xmax = 1e6
zmin = 0
zmax = 5e3
nz = 20
nx = 29
ng = 1
g = ThPa2D.FDgrid(nx, nz, ng)
h = ThPa2D.FDgrid(nx, nz, ng)

# chemistry
k_ad, k_de, Q = ThPa2D.k_sorp('Th', xmin, xmax, zmin, zmax, nx, nz)

# initial profile
init = ThPa2D.plot_init(g, h, xmin, xmax, zmin, zmax, nx, nz, 'Th')

# velocity
u, flowfig = ThPa2D.u_zero(xmin, xmax, zmin, zmax, nx, nz, V)

# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upstream)

#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Th')

# store results
DTh0vel = {}
PTh0vel = {}
DTh0vel['1tmax'] = g.a
PTh0vel['1tmax'] = h.a

# %%
t = tmax[1]
T = tmax[2]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upstream)

#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Th')

# store results
DTh0vel['2tmax'] = g.a
PTh0vel['2tmax'] = h.a

# %%
t = tmax[2]
T = tmax[3]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upstream)

#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Th')

# store results
DTh0vel['3tmax'] = g.a
PTh0vel['3tmax'] = h.a

# %%
t = tmax[3]
T = tmax[4]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upstream)

#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Th')

# store results
DTh0vel['5tmax'] = g.a
PTh0vel['5tmax'] = h.a

# %%
t = tmax[4]
T = tmax[5]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upstream)

#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Th')

# store results
DTh0vel['10tmax'] = g.a
PTh0vel['10tmax'] = h.a

# %%
t = tmax[5]
T = tmax[6]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upstream)

#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Th')

# store results
DTh0vel['20tmax'] = g.a
PTh0vel['20tmax'] = h.a

# %% [markdown]
# Since the distribution and magnitude of the [Th] does not change between 50 and 100 years, the system appears to reach steady state after 50 years.

# %% [markdown]
# # [Th] for Single Cell Velocity Field

# %%
# use 0=vel steady state as initial profile
g.a = DTh0vel['20tmax']
h.a = PTh0vel['20tmax']

# setup function adflow for Th 
reload(ThPa2D)
tmax = (0, 1, 2, 3, 5, 10)
t = tmax[0]
T = tmax[1]
V = 0.02/1000*365.*86400.
xmin = 0
xmax = 1e6
zmin = 0
zmax = 5e3
nz = 20
nx = 30
ng = 1

# chemistry
k_ad, k_de, Q = ThPa2D.k_sorp('Th', xmin, xmax, zmin, zmax, nx, nz)

# initial profile
init = ThPa2D.plot_init(g, h, xmin, xmax, zmin, zmax, nx, nz, 'Th')

# velocity
u, flowfig = ThPa2D.u_simple(xmin, xmax, zmin, zmax, nx, nz, V)
u, flowfig = ThPa2D.u_simple_c(u, xmin, xmax, zmin, zmax, nx, nz)

# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upstream)

#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Th')

# store results
DTh1vel = {}
PTh1vel = {}
DTh1vel['1tmax'] = g.a
PTh1vel['1tmax'] = h.a

# %%
t = tmax[1]
T = tmax[2]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upwind)

#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Th')

# store results
DTh1vel['2tmax'] = g.a
PTh1vel['2tmax'] = h.a
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-33-1bff04d51bdc> in <module>()
#       5
#       6 #plot results
# ----> 7 meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Th')
#       8
#       9 # store results
#
# /home/abellas/Documents/GEOTRACES/Pa-Th/prelim-model/ThPa2D.pyc in plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, string)
#     735         pylab.ylim([zmax_plt, zmin])
#     736
# --> 737         pylab.subplot(122)
#     738         mesh4 = pylab.pcolormesh(xx_plt/1e3, zz_plt, h.a)
#     739         if string == 'Th':
#
# /home/abellas/anaconda/lib/python2.7/site-packages/matplotlib/pyplot.pyc in subplot(*args, **kwargs)
#     895
#     896     fig = gcf()
# --> 897     a = fig.add_subplot(*args, **kwargs)
#     898     bbox = a.bbox
#     899     byebye = []
#
# /home/abellas/anaconda/lib/python2.7/site-packages/matplotlib/figure.pyc in add_subplot(self, *args, **kwargs)
#     912                     self._axstack.remove(ax)
#     913
# --> 914             a = subplot_class_factory(projection_class)(self, *args, **kwargs)
#     915
#     916         self._axstack.add(key, a)
#
# /home/abellas/anaconda/lib/python2.7/site-packages/matplotlib/axes.pyc in __init__(self, fig, *args, **kwargs)
#    9257
#    9258         # _axes_class is set in the subplot_class_factory
# -> 9259         self._axes_class.__init__(self, fig, self.figbox, **kwargs)
#    9260
#    9261     def __reduce__(self):
#
# /home/abellas/anaconda/lib/python2.7/site-packages/matplotlib/axes.pyc in __init__(self, fig, rect, axisbg, frameon, sharex, sharey, label, xscale, yscale, **kwargs)
#     447
#     448         # this call may differ for non-sep axes, eg polar
# --> 449         self._init_axis()
#     450
#     451         if axisbg is None:
#
# /home/abellas/anaconda/lib/python2.7/site-packages/matplotlib/axes.pyc in _init_axis(self)
#     508         self.spines['top'].register_axis(self.xaxis)
#     509         self.yaxis = maxis.YAxis(self)
# --> 510         self.spines['left'].register_axis(self.yaxis)
#     511         self.spines['right'].register_axis(self.yaxis)
#     512         self._update_transScale()
#
# /home/abellas/anaconda/lib/python2.7/site-packages/matplotlib/spines.pyc in register_axis(self, axis)
#     151         self.axis = axis
#     152         if self.axis is not None:
# --> 153             self.axis.cla()
#     154
#     155     def cla(self):
#
# /home/abellas/anaconda/lib/python2.7/site-packages/matplotlib/axis.pyc in cla(self)
#     740         self._set_artist_props(self.label)
#     741
# --> 742         self.reset_ticks()
#     743
#     744         self.converter = None
#
# /home/abellas/anaconda/lib/python2.7/site-packages/matplotlib/axis.pyc in reset_ticks(self)
#     754
#     755         self.majorTicks.extend([self._get_tick(major=True)])
# --> 756         self.minorTicks.extend([self._get_tick(major=False)])
#     757         self._lastNumMajorTicks = 1
#     758         self._lastNumMinorTicks = 1
#
# /home/abellas/anaconda/lib/python2.7/site-packages/matplotlib/axis.pyc in _get_tick(self, major)
#    1909         else:
#    1910             tick_kw = self._minor_tick_kw
# -> 1911         return YTick(self.axes, 0, '', major=major, **tick_kw)
#    1912
#    1913     def _get_label(self):
#
# /home/abellas/anaconda/lib/python2.7/site-packages/matplotlib/axis.pyc in __init__(self, axes, loc, label, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major)
#     138         self.apply_tickdir(tickdir)
#     139
# --> 140         self.tick1line = self._get_tick1line()
#     141         self.tick2line = self._get_tick2line()
#     142         self.gridline = self._get_gridline()
#
# /home/abellas/anaconda/lib/python2.7/site-packages/matplotlib/axis.pyc in _get_tick1line(self)
#     524                     markersize=self._size,
#     525                     markeredgewidth=self._width,
# --> 526                     zorder=self._zorder,
#     527                     )
#     528         l.set_transform(self.axes.get_yaxis_transform(which='tick1'))
#
# /home/abellas/anaconda/lib/python2.7/site-packages/matplotlib/lines.pyc in __init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     219         self.set_markeredgecolor(markeredgecolor)
#     220         self.set_markeredgewidth(markeredgewidth)
# --> 221         self.set_fillstyle(fillstyle)
#     222
#     223         self.verticalOffset = None
#
# /home/abellas/anaconda/lib/python2.7/site-packages/matplotlib/lines.pyc in set_fillstyle(self, fs)
#     335         ACCEPTS: ['full' | 'left' | 'right' | 'bottom' | 'top' | 'none']
#     336         """
# --> 337         self._marker.set_fillstyle(fs)
#     338
#     339     def set_markevery(self, every):
#
# /home/abellas/anaconda/lib/python2.7/site-packages/matplotlib/markers.pyc in set_fillstyle(self, fillstyle)
#     205                              % ' '.join(self.fillstyles))
#     206         self._fillstyle = fillstyle
# --> 207         self._recache()
#     208
#     209     def get_joinstyle(self):
#
# /home/abellas/anaconda/lib/python2.7/site-packages/matplotlib/markers.pyc in _recache(self)
#     175     def _recache(self):
#     176         self._path = Path(np.empty((0, 2)))
# --> 177         self._transform = IdentityTransform()
#     178         self._alt_path = None
#     179         self._alt_transform = None
#
# KeyboardInterrupt:

# %%
t = tmax[2]
T = tmax[3]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upwind)

#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Th')

# store results
DTh1vel['3tmax'] = g.a
PTh1vel['3tmax'] = h.a

# %%
t = tmax[3]
T = tmax[4]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upwind)

#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Th')

# store results
DTh1vel['5tmax'] = g.a
PTh1vel['5tmax'] = h.a

# %%
t = tmax[4]
T = tmax[5]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upwind)

#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Th')

# store results
DTh1vel['10tmax'] = g.a
PTh1vel['10tmax'] = h.a

# %% [markdown]
# # [Th] for Two Cell Velocity Scheme

# %%
# setup function adflow for Th 
reload(ThPa2D)
tmax = (0, 1, 2, 3, 5, 10)
t = tmax[0]
T = tmax[1]
V = 0.02/1000*365.*86400.
xmin = 0
xmax = 1e6
zmin = 0
zmax = 5e3
nz = 20
nz_fine = 2*nz - 1
nx = 29
ng = 1
g = ThPa2D.FDgrid(nx, nz, ng)
h = ThPa2D.FDgrid(nx, nz, ng)

# chemistry
k_ad, k_de, Q = ThPa2D.k_sorp('Th', xmin, xmax, zmin, zmax, nx, nz)

# inital profile
init = ThPa2D.plot_init(g, h, xmin, xmax, zmin, zmax, nx, nz, 'Th')

# velocity
u, flowfig = ThPa2D.u_simple(xmin, xmax, zmin, zmax, nx, nz, V)
u_fine, flowfig = ThPa2D.u_simple(xmin, xmax, zmin, zmax, nx, nz_fine, V)
u, flowfig = ThPa2D.u_simple_c(u, u_fine, xmin, xmax, zmin, zmax, nx, nz)

# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upwind)

#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Th')

# store results
DTh2vel = {}
PTh2vel = {}
DTh2vel['1tmax'] = g.a
PTh2vel['1tmax'] = h.a

# %%
t = tmax[1]
T = tmax[2]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upwind)

#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Th')

# store results
DTh2vel['2tmax'] = g.a
PTh2vel['2tmax'] = h.a

# %%
t = tmax[2]
T = tmax[3]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upwind)

#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Th')

# store results
DTh2vel['3tmax'] = g.a
PTh2vel['3tmax'] = h.a

# %%
t = tmax[3]
T = tmax[4]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upwind)

#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Th')

# store results
DTh2vel['5tmax'] = g.a
PTh2vel['5tmax'] = h.a

# %%
t = tmax[4]
T = tmax[5]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upwind)

#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Th')

# store results
DTh2vel['10tmax'] = g.a
PTh2vel['10tmax'] = h.a

# %% [markdown]
# Why is the effect of different velocity schemes indiscernable for Th, but not for Pa?
#
# Both particulate and dissolved phases are affected by velocity, but in the dissolved case, ONLY the imposed velocity field, not the sinking velocity.
