# %% [markdown]
# Solves the [Th]/[Pa] on a 2D grid using an upwind advection scheme, and contains plots of [Th]/[Pa] profile for a zero velocity field, a single cell velocity field, and a two cell velocity field.

# %%
from __future__ import division
import numpy as np
import pylab as plb
import copy
import math
import matplotlib.pyplot as plt
from math import pi
import ThPa2D
# %matplotlib inline

# %%
reload(ThPa2D)
# Out:
# <module 'ThPa2D' from 'ThPa2D.pyc'>

# %% [markdown]
# # [Th]/[Pa] in Zero Velocity Field

# %%
reload(ThPa2D)
# set parameters
time = (0, 1, 2, 3, 5, 10, 20, 60, 100)
t = time[0]
T = time[1]
V = 0.02/1000*365.*86400.  # first number in mm/s, corrections give needed value in m/yr ~ 630
xmin = 1
xmax = 1e6
zmin = 0
zmax = 5e3
nz = 20
nx = 30
ng = 1
g = ThPa2D.FDgrid(nx, nz, ng)
h = ThPa2D.FDgrid(nx, nz, ng)
# velocity field
u = ThPa2D.u_zero(nz, nx)
# initial profile
init, flowfig = ThPa2D.plot_init(g, h, u, xmin, xmax, zmin, zmax, nx, nz, 'ThPa')
# Th chemistry
Tk_ad, Tk_de, TQ = ThPa2D.k_sorp('Th', xmin, xmax, zmin, zmax, nx, nz)
# Pa chemistry
Pk_ad, Pk_de, PQ = ThPa2D.k_sorp('Pa', xmin, xmax, zmin, zmax, nx, nz)
# [Th] loop
DTh, PTh = ThPa2D.adflow(g, h, t, T, u, Tk_ad, Tk_de, TQ, ThPa2D.upstream)
# [Pa] loop
g = ThPa2D.FDgrid(nx, nz, ng)
h = ThPa2D.FDgrid(nx, nz, ng)
DPa, PPa = ThPa2D.adflow(g, h, t, T, u, Pk_ad, Pk_de, PQ, ThPa2D.upstream)
# plot ratio of [Th]/[Pa]
ThPa = ThPa2D.plotratio(DTh.a, DPa.a, PTh.a, PPa.a, xmin, xmax, zmin, zmax, nx, nz, T)
# store Th results
DTh0vel = {}
PTh0vel = {}
DTh0vel['1tmax'] = copy.copy(DTh.a)
PTh0vel['1tmax'] = copy.copy(PTh.a)
# store Pa results
DPa0vel = {}
PPa0vel = {}
DPa0vel['1tmax'] = copy.copy(DPa.a)
PPa0vel['1tmax'] = copy.copy(PPa.a)
# Out:
# ThPa2D.py:625: RuntimeWarning: invalid value encountered in true_divide
#   Dratio = DTh/DPa
# ThPa2D.py:630: RuntimeWarning: invalid value encountered in true_divide
#   Pratio = PTh/PPa
# /home/abellas/anaconda/lib/python2.7/site-packages/matplotlib/quiver.py:570: RuntimeWarning: divide by zero encountered in double_scalars
#   length = a * (widthu_per_lenu / (self.scale * self.width))
# /home/abellas/anaconda/lib/python2.7/site-packages/matplotlib/quiver.py:570: RuntimeWarning: invalid value encountered in multiply
#   length = a * (widthu_per_lenu / (self.scale * self.width))
# /home/abellas/anaconda/lib/python2.7/site-packages/matplotlib/quiver.py:626: RuntimeWarning: invalid value encountered in less
#   short = np.repeat(length < minsh, 8, axis=1)
# /home/abellas/anaconda/lib/python2.7/site-packages/matplotlib/quiver.py:636: RuntimeWarning: invalid value encountered in less
#   tooshort = length < self.minlength

# %%
t = time[1]
T = time[2]
# [Th] loop
[DTh, PTh] = ThPa2D.adflow(DTh, PTh, t, T, u, Tk_ad, Tk_de, TQ, ThPa2D.upstream)
# [Pa] loop
[DPa, PPa] = ThPa2D.adflow(DPa, PPa, t, T, u, Pk_ad, Pk_de, PQ, ThPa2D.upstream)
# plot ratio of [Th]/[Pa]
ThPa = ThPa2D.plotratio(DTh.a, DPa.a, PTh.a, PPa.a, xmin, xmax, zmin, zmax, nx, nz, T)
# store Th results
DTh0vel['2tmax'] = copy.copy(DTh.a)
PTh0vel['2tmax'] = copy.copy(PTh.a)
# store Pa results
DPa0vel['2tmax'] = copy.copy(DPa.a)
PPa0vel['2tmax'] = copy.copy(PPa.a)

# %%
t = time[2]
T = time[3]
# [Th] loop
DTh, PTh = ThPa2D.adflow(DTh, PTh, t, T, u, Tk_ad, Tk_de, TQ, ThPa2D.upstream)
# [Pa] loop
DPa, PPa = ThPa2D.adflow(DPa, PPa, t, T, u, Pk_ad, Pk_de, PQ, ThPa2D.upstream)
# plot ratio of [Th]/[Pa]
ThPa = ThPa2D.plotratio(DTh.a, DPa.a, PTh.a, PPa.a, xmin, xmax, zmin, zmax, nx, nz, T)
# store Th results
DTh0vel['3tmax'] = copy.copy(DTh.a)
PTh0vel['3tmax'] = copy.copy(PTh.a)
# store Pa results
DPa0vel['3tmax'] = copy.copy(DPa.a)
PPa0vel['3tmax'] = copy.copy(PPa.a)

# %%
t = time[3]
T = time[4]
# [Th] loop
DTh, PTh = ThPa2D.adflow(DTh, PTh, t, T, u, Tk_ad, Tk_de, TQ, ThPa2D.upstream)
# [Pa] loop
DPa, PPa = ThPa2D.adflow(DPa, PPa, t, T, u, Pk_ad, Pk_de, PQ, ThPa2D.upstream)
# plot ratio of [Th]/[Pa]
ThPa = ThPa2D.plotratio(DTh.a, DPa.a, PTh.a, PPa.a, xmin, xmax, zmin, zmax, nx, nz, T)
# store Th results
DTh0vel['5tmax'] = copy.copy(DTh.a)
PTh0vel['5tmax'] = copy.copy(PTh.a)
# store Pa results
DPa0vel['5tmax'] = copy.copy(DPa.a)
PPa0vel['5tmax'] = copy.copy(PPa.a)

# %%
t = time[4]
T = time[5]
# [Th] loop
DTh, PTh = ThPa2D.adflow(DTh, PTh, t, T, u, Tk_ad, Tk_de, TQ, ThPa2D.upstream)
# [Pa] loop
DPa, PPa = ThPa2D.adflow(DPa, PPa, t, T, u, Pk_ad, Pk_de, PQ, ThPa2D.upstream)
# plot ratio of [Th]/[Pa]
ThPa = ThPa2D.plotratio(DTh.a, DPa.a, PTh.a, PPa.a, xmin, xmax, zmin, zmax, nx, nz, T)
# store Th results
DTh0vel['10tmax'] = copy.copy(DTh.a)
PTh0vel['10tmax'] = copy.copy(PTh.a)
# store Pa results
DPa0vel['10tmax'] = copy.copy(DPa.a)
PPa0vel['10tmax'] = copy.copy(PPa.a)

# %%
t = time[5]
T = time[6]
# [Th] loop
DTh, PTh = ThPa2D.adflow(DTh, PTh, t, T, u, Tk_ad, Tk_de, TQ, ThPa2D.upstream)
# [Pa] loop
DPa, PPa = ThPa2D.adflow(DPa, PPa, t, T, u, Pk_ad, Pk_de, PQ, ThPa2D.upstream)
# plot ratio of [Th]/[Pa]
ThPa = ThPa2D.plotratio(DTh.a, DPa.a, PTh.a, PPa.a, xmin, xmax, zmin, zmax, nx, nz, T)
# store Th steady state sol.
DTh0vel['20tmax'] = copy.copy(DTh.a)
PTh0vel['20tmax'] = copy.copy(PTh.a)
# store Pa results
DPa0vel['20tmax'] = copy.copy(DPa.a)
PPa0vel['20tmax'] = copy.copy(PPa.a)

# %%
DPa = ThPa2D.FDgrid(nx, nz, ng)
PPa = ThPa2D.FDgrid(nx, nz, ng)
DPa.a = DPa0vel['20tmax']
PPa.a = PPa0vel['20tmax']
#
t = time[6]
T = time[7]
# [Th] loop
#DTh, PTh = ThPa2D.adflow(DTh, PTh, t, T, u, Tk_ad, Tk_de, TQ, ThPa2D.upstream)
# [Pa] loop
DPa, PPa = ThPa2D.adflow(DPa, PPa, t, T, u, Pk_ad, Pk_de, PQ, ThPa2D.upstream)
# plot ratio of [Th]/[Pa]
ThPa = ThPa2D.plotratio(DTh.a, DPa.a, PTh.a, PPa.a, xmin, xmax, zmin, zmax, nx, nz, T)
# store Pa results
DPa0vel['60tmax'] = copy.copy(DPa.a)
PPa0vel['60tmax'] = copy.copy(PPa.a)

# %%
DPa.a = DPa0vel['60tmax']
PPa.a = PPa0vel['60tmax']
t = time[7]
T = time[8]
# [Th] loop
#DTh, PTh = ThPa2D.adflow(DTh, PTh, t, T, u, Tk_ad, Tk_de, TQ, ThPa2D.upstream)
# [Pa] loop
DPa, PPa = ThPa2D.adflow(DPa, PPa, t, T, u, Pk_ad, Pk_de, PQ, ThPa2D.upstream)
# plot ratio of [Th]/[Pa]
ThPa = ThPa2D.plotratio(DTh.a, DPa.a, PTh.a, PPa.a, xmin, xmax, zmin, zmax, nx, nz, T)
# store Pa results
DPa0vel['100tmax'] = copy.copy(DPa.a)
PPa0vel['100tmax'] = copy.copy(PPa.a)

# %% [markdown]
# # [Th]/[Pa] in Single Cell Velocity Field, upstream scheme

# %%
reload(ThPa2D)
# set parameters
time = (0, 1, 2, 3, 5, 10, 20, 60, 100)
t = time[0]
T = time[1]
V = 0.02/1000*365.*86400.  # first number in mm/s, corrections give needed value in m/yr ~ 630
xmin = 1
xmax = 1e6
zmin = 0
zmax = 5e3
nz = 20
nx = 30
ng = 1
# set initial profile to steady state of 0-vel. calculation
g.a = copy.copy(DTh0vel['20tmax']/DPa0vel['100tmax'])
h.a = copy.copy(PTh0vel['20tmax']/PPa0vel['100tmax'])
# velocity
u = ThPa2D.u_simple(xmin, xmax, zmin, zmax, nx, nz, V)
u = ThPa2D.u_simple_c(u, xmin, xmax, zmin, zmax, nx, nz)
# initial profile
init, flowfig = ThPa2D.plot_init(g, h, u, xmin, xmax, zmin, zmax, nx, nz, 'ThPa')
# Th chemistry
Tk_ad, Tk_de, TQ = ThPa2D.k_sorp('Th', xmin, xmax, zmin, zmax, nx, nz)
# Pa chemistry
Pk_ad, Pk_de, PQ = ThPa2D.k_sorp('Pa', xmin, xmax, zmin, zmax, nx, nz)
# [Th] loop
DTh, PTh = ThPa2D.adflow(DTh, PTh, t, T, u, Tk_ad, Tk_de, TQ, ThPa2D.upstream)
# [Pa] loop
DPa, PPa = ThPa2D.adflow(DPa, PPa, t, T, u, Pk_ad, Pk_de, PQ, ThPa2D.upstream)
# plot ratio of [Th]/[Pa]
ThPa = ThPa2D.plotratio(DTh.a, DPa.a, PTh.a, PPa.a, xmin, xmax, zmin, zmax, nx, nz, T)
# store Th results
DTh1vel = {}
PTh1vel = {}
DTh1vel['1tmax'] = copy.copy(DTh.a)
PTh1vel['1tmax'] = copy.copy(PTh.a)
# store Pa results
DPa1vel = {}
PPa1vel = {}
DPa1vel['1tmax'] = copy.copy(DPa.a)
PPa1vel['1tmax'] = copy.copy(PPa.a)

# %%
t = time[1]
T = time[2]
# [Th] loop
[DTh, PTh] = ThPa2D.adflow(DTh, PTh, t, T, u, Tk_ad, Tk_de, TQ, ThPa2D.upstream)
# [Pa] loop
[DPa, PPa] = ThPa2D.adflow(DPa, PPa, t, T, u, Pk_ad, Pk_de, PQ, ThPa2D.upstream)
# plot ratio of [Th]/[Pa]
ThPa = ThPa2D.plotratio(DTh.a, DPa.a, PTh.a, PPa.a, xmin, xmax, zmin, zmax, nx, nz, T)
# store Th results
DTh1vel['2tmax'] = copy.copy(DTh.a)
PTh1vel['2tmax'] = copy.copy(PTh.a)
# store Pa results
DPa1vel['2tmax'] = copy.copy(DPa.a)
PPa1vel['2tmax'] = copy.copy(PPa.a)

# %%
t = time[2]
T = time[3]
# [Th] loop
[DTh, PTh] = ThPa2D.adflow(DTh, PTh, t, T, u, Tk_ad, Tk_de, TQ, ThPa2D.upstream)
# [Pa] loop
[DPa, PPa] = ThPa2D.adflow(DPa, PPa, t, T, u, Pk_ad, Pk_de, PQ, ThPa2D.upstream)
# plot ratio of [Th]/[Pa]
ThPa = ThPa2D.plotratio(DTh.a, DPa.a, PTh.a, PPa.a, xmin, xmax, zmin, zmax, nx, nz, T)
# store Th results
DTh1vel['3tmax'] = copy.copy(DTh.a)
PTh1vel['3tmax'] = copy.copy(PTh.a)
# store Pa results
DPa1vel['3tmax'] = copy.copy(DPa.a)
PPa1vel['3tmax'] = copy.copy(PPa.a)

# %%
t = time[3]
T = time[4]
# [Th] loop
[DTh, PTh] = ThPa2D.adflow(DTh, PTh, t, T, u, Tk_ad, Tk_de, TQ, ThPa2D.upstream)
# [Pa] loop
[DPa, PPa] = ThPa2D.adflow(DPa, PPa, t, T, u, Pk_ad, Pk_de, PQ, ThPa2D.upstream)
# plot ratio of [Th]/[Pa]
ThPa = ThPa2D.plotratio(DTh.a, DPa.a, PTh.a, PPa.a, xmin, xmax, zmin, zmax, nx, nz, T)
# store Th results
DTh1vel['5tmax'] = copy.copy(DTh.a)
PTh1vel['5tmax'] = copy.copy(PTh.a)
# store Pa results
DPa1vel['5tmax'] = copy.copy(DPa.a)
PPa1vel['5tmax'] = copy.copy(PPa.a)

# %%
t = time[4]
T = time[5]
# [Th] loop
[DTh, PTh] = ThPa2D.adflow(DTh, PTh, t, T, u, Tk_ad, Tk_de, TQ, ThPa2D.upstream)
# [Pa] loop
[DPa, PPa] = ThPa2D.adflow(DPa, PPa, t, T, u, Pk_ad, Pk_de, PQ, ThPa2D.upstream)
# plot ratio of [Th]/[Pa]
ThPa = ThPa2D.plotratio(DTh.a, DPa.a, PTh.a, PPa.a, xmin, xmax, zmin, zmax, nx, nz, T)
# store Th results
DTh1vel['10tmax'] = copy.copy(DTh.a)
PTh1vel['10tmax'] = copy.copy(PTh.a)
# store Pa results
DPa1vel['10tmax'] = copy.copy(DPa.a)
PPa1vel['10tmax'] = copy.copy(PPa.a)

# %%
t = time[5]
T = time[6]
# [Th] loop
[DTh, PTh] = ThPa2D.adflow(DTh, PTh, t, T, u, Tk_ad, Tk_de, TQ, ThPa2D.upstream)
# [Pa] loop
[DPa, PPa] = ThPa2D.adflow(DPa, PPa, t, T, u, Pk_ad, Pk_de, PQ, ThPa2D.upstream)
# plot ratio of [Th]/[Pa]
ThPa = ThPa2D.plotratio(DTh.a, DPa.a, PTh.a, PPa.a, xmin, xmax, zmin, zmax, nx, nz, T)
# store Th results
DTh1vel['20tmax'] = copy.copy(DTh.a)
PTh1vel['20tmax'] = copy.copy(PTh.a)
# store Pa results
DPa1vel['20tmax'] = copy.copy(DPa.a)
PPa1vel['20tmax'] = copy.copy(PPa.a)

# %%
t = time[6]
T = time[7]
# [Th] loop
#[DTh, PTh] = ThPa2D.adflow(DTh, PTh, t, T, u, Tk_ad, Tk_de, TQ, ThPa2D.upstream)
# [Pa] loop
[DPa, PPa] = ThPa2D.adflow(DPa, PPa, t, T, u, Pk_ad, Pk_de, PQ, ThPa2D.upstream)
# plot ratio of [Th]/[Pa]
ThPa = ThPa2D.plotratio(DTh.a, DPa.a, PTh.a, PPa.a, xmin, xmax, zmin, zmax, nx, nz, T)
# store Pa results
DPa1vel['60tmax'] = copy.copy(DPa.a)
PPa1vel['60tmax'] = copy.copy(PPa.a)

# %% [markdown]
# This is clearly unstable, but at least the concentration is always > 0.

# %%
t = time[7]
T = time[8]
# [Th] loop
#[DTh, PTh] = ThPa2D.adflow(DTh, PTh, t, T, u, Tk_ad, Tk_de, TQ, ThPa2D.upstream)
# [Pa] loop
[DPa, PPa] = ThPa2D.adflow(DPa, PPa, t, T, u, Pk_ad, Pk_de, PQ, ThPa2D.upstream)
# plot ratio of [Th]/[Pa]
ThPa = ThPa2D.plotratio(DTh.a, DPa.a, PTh.a, PPa.a, xmin, xmax, zmin, zmax, nx, nz, T)
# store Pa results
DPa1vel['100tmax'] = copy.copy(DPa.a)
PPa1vel['100tmax'] = copy.copy(PPa.a)

# %% [markdown]
# # [Th]/[Pa] in Two Cell Velocity Field, upstream scheme

# %%
# set parms
reload(ThPa2D)
time = (0, 1, 2, 3, 5, 10, 20, 60, 100)
t = time[0]
T = time[1]
V = 0.02/1000*365.*86400.  # first number in mm/s, corrections give needed value in m/yr ~ 630
xmin = 0
xmax = 1e6
zmin = 0
zmax = 5e3
nz = 20
nx = 30
ng = 1
# set initial profile to steady state of 0-vel. calculation
g.a = copy.copy(DTh0vel['20tmax']/DPa0vel['100tmax'])
h.a = copy.copy(PTh0vel['20tmax']/PPa0vel['100tmax'])
# velocity
u = ThPa2D.u_complex(xmin, xmax, zmin, zmax, nx, nz, V)
u = ThPa2D.u_complex_c(u, xmin, xmax, zmin, zmax, nx, nz)
# initial profile
init, flowfig = ThPa2D.plot_init(g, h, u, xmin, xmax, zmin, zmax, nx, nz, 'ThPa')
# Th chemistry
Tk_ad, Tk_de, TQ = ThPa2D.k_sorp('Th', xmin, xmax, zmin, zmax, nx, nz)
# Pa chemistry
Pk_ad, Pk_de, PQ = ThPa2D.k_sorp('Pa', xmin, xmax, zmin, zmax, nx, nz)
# [Th] loop
DTh, PTh = ThPa2D.adflow(g, h, t, T, u, Tk_ad, Tk_de, TQ, ThPa2D.upstream)
# [Pa] loop
DPa, PPa = ThPa2D.adflow(g, h, t, T, u, Pk_ad, Pk_de, PQ, ThPa2D.upstream)
# plot ratio of [Th]/[Pa]
ThPa = ThPa2D.plotratio(DTh.a, DPa.a, PTh.a, PPa.a, xmin, xmax, zmin, zmax, nx, nz, T)
# store Th results
DTh2vel['1tmax'] = copy.copy(DTh.a)
PTh2vel['1tmax'] = copy.copy(PTh.a)
# store Pa results
DPa2vel['1tmax'] = copy.copy(DPa.a)
PPa2vel['1tmax'] = copy.copy(PPa.a)

# %%
t = time[1]
T = time[2]
# [Th] loop
[DTh, PTh] = ThPa2D.adflow(DTh, PTh, t, T, u, Tk_ad, Tk_de, TQ, ThPa2D.upstream)
# [Pa] loop
[DPa, PPa] = ThPa2D.adflow(DPa, PPa, t, T, u, Pk_ad, Pk_de, PQ, ThPa2D.upstream)
# plot ratio of [Th]/[Pa]
ThPa = ThPa2D.plotratio(DTh.a, DPa.a, PTh.a, PPa.a, xmin, xmax, zmin, zmax, nx, nz, T)
# store Th results
DTh2vel['2tmax'] = copy.copy(DTh.a)
PTh2vel['2tmax'] = copy.copy(PTh.a)
# store Pa results
DPa2vel['2tmax'] = copy.copy(DPa.a)
PPa2vel['2tmax'] = copy.copy(PPa.a)

# %%
t = time[2]
T = time[3]
# [Th] loop
[DTh, PTh] = ThPa2D.adflow(DTh, PTh, t, T, u, Tk_ad, Tk_de, TQ, ThPa2D.upstream)
# [Pa] loop
[DPa, PPa] = ThPa2D.adflow(DPa, PPa, t, T, u, Pk_ad, Pk_de, PQ, ThPa2D.upstream)
# plot ratio of [Th]/[Pa]
ThPa = ThPa2D.plotratio(DTh.a, DPa.a, PTh.a, PPa.a, xmin, xmax, zmin, zmax, nx, nz, T)
# store Th results
DTh2vel['3tmax'] = copy.copy(DTh.a)
PTh2vel['3tmax'] = copy.copy(PTh.a)
# store Pa results
DPa2vel['3tmax'] = copy.copy(DPa.a)
PPa2vel['3tmax'] = copy.copy(PPa.a)

# %%
t = time[3]
T = time[4]
# [Th] loop
[DTh, PTh] = ThPa2D.adflow(DTh, PTh, t, T, u, Tk_ad, Tk_de, TQ, ThPa2D.upstream)
# [Pa] loop
[DPa, PPa] = ThPa2D.adflow(DPa, PPa, t, T, u, Pk_ad, Pk_de, PQ, ThPa2D.upstream)
# plot ratio of [Th]/[Pa]
ThPa = ThPa2D.plotratio(DTh.a, DPa.a, PTh.a, PPa.a, xmin, xmax, zmin, zmax, nx, nz, T)
# store Th results
DTh2vel['5tmax'] = copy.copy(DTh.a)
PTh2vel['5tmax'] = copy.copy(PTh.a)
# store Pa results
DPa2vel['5tmax'] = copy.copy(DPa.a)
PPa2vel['5tmax'] = copy.copy(PPa.a)

# %%
t = time[4]
T = time[5]
# [Th] loop
[DTh, PTh] = ThPa2D.adflow(DTh, PTh, t, T, u, Tk_ad, Tk_de, TQ, ThPa2D.upstream)
# [Pa] loop
[DPa, PPa] = ThPa2D.adflow(DPa, PPa, t, T, u, Pk_ad, Pk_de, PQ, ThPa2D.upstream)
# plot ratio of [Th]/[Pa]
ThPa = ThPa2D.plotratio(DTh.a, DPa.a, PTh.a, PPa.a, xmin, xmax, zmin, zmax, nx, nz, T)
# store Th results
DTh2vel['10tmax'] = copy.copy(DTh.a)
PTh2vel['10tmax'] = copy.copy(PTh.a)
# store Pa results
DPa2vel['10tmax'] = copy.copy(DPa.a)
PPa2vel['10tmax'] = copy.copy(PPa.a)

# %%
t = time[5]
T = time[6]
# [Th] loop
[DTh, PTh] = ThPa2D.adflow(DTh, PTh, t, T, u, Tk_ad, Tk_de, TQ, ThPa2D.upstream)
# [Pa] loop
[DPa, PPa] = ThPa2D.adflow(DPa, PPa, t, T, u, Pk_ad, Pk_de, PQ, ThPa2D.upstream)
# plot ratio of [Th]/[Pa]
ThPa = ThPa2D.plotratio(DTh.a, DPa.a, PTh.a, PPa.a, xmin, xmax, zmin, zmax, nx, nz, T)
# store Th results
DTh2vel['20tmax'] = copy.copy(DTh.a)
PTh2vel['20tmax'] = copy.copy(PTh.a)
# store Pa results
DPa2vel['20tmax'] = copy.copy(DPa.a)
PPa2vel['20tmax'] = copy.copy(PPa.a)

# %%
t = time[6]
T = time[7]
# [Th] loop
[DTh, PTh] = ThPa2D.adflow(DTh, PTh, t, T, u, Tk_ad, Tk_de, TQ, ThPa2D.upstream)
# [Pa] loop
[DPa, PPa] = ThPa2D.adflow(DPa, PPa, t, T, u, Pk_ad, Pk_de, PQ, ThPa2D.upstream)
# plot ratio of [Th]/[Pa]
ThPa = ThPa2D.plotratio(DTh.a, DPa.a, PTh.a, PPa.a, xmin, xmax, zmin, zmax, nx, nz, T)
# store Th results
DTh2vel['60tmax'] = copy.copy(DTh.a)
PTh2vel['60tmax'] = copy.copy(PTh.a)
# store Pa results
DPa2vel['60tmax'] = copy.copy(DPa.a)
PPa2vel['60tmax'] = copy.copy(PPa.a)

# %%
t = time[7]
T = time[8]
# [Th] loop
[DTh, PTh] = ThPa2D.adflow(DTh, PTh, t, T, u, Tk_ad, Tk_de, TQ, ThPa2D.upstream)
# [Pa] loop
[DPa, PPa] = ThPa2D.adflow(DPa, PPa, t, T, u, Pk_ad, Pk_de, PQ, ThPa2D.upstream)
# plot ratio of [Th]/[Pa]
ThPa = ThPa2D.plotratio(DTh.a, DPa.a, PTh.a, PPa.a, xmin, xmax, zmin, zmax, nx, nz, T)
# store Th results
DTh2vel['100tmax'] = copy.copy(DTh.a)
PTh2vel['100tmax'] = copy.copy(PTh.a)
# store Pa results
DPa2vel['100tmax'] = copy.copy(DPa.a)
PPa2vel['100tmax'] = copy.copy(PPa.a)

# %% [markdown]
# # [Th]/[Pa] in a 2-cell velocity field with flux based advection

# %%
# set parms
reload(ThPa2D)
time = (0, 1, 2, 3, 5, 10, 20, 60, 100)
t = time[0]
T = time[1]
V = 0.02/1000*365.*86400.  # first number in mm/s, corrections give needed value in m/yr ~ 630
xmin = 0
xmax = 1e6
zmin = 0
zmax = 5e3
nz = 20
nx = 30
ng = 1
# set initial profile to steady state of 0-vel. calculation
g.a = copy.copy(DTh0vel['20tmax']/DPa0vel['100tmax'])
h.a = copy.copy(PTh0vel['20tmax']/PPa0vel['100tmax'])
# velocity
u = ThPa2D.u_complex(xmin, xmax, zmin, zmax, nx, nz, V)
u = ThPa2D.u_complex_c(u, xmin, xmax, zmin, zmax, nx, nz)
# initial profile
init, flowfig = ThPa2D.plot_init(g, h, u, xmin, xmax, zmin, zmax, nx, nz, 'ThPa')
# Th chemistry
Tk_ad, Tk_de, TQ = ThPa2D.k_sorp('Th', xmin, xmax, zmin, zmax, nx, nz)
# Pa chemistry
Pk_ad, Pk_de, PQ = ThPa2D.k_sorp('Pa', xmin, xmax, zmin, zmax, nx, nz)
# [Th] loop
DTh, PTh = ThPa2D.adflow(g, h, t, T, u, Tk_ad, Tk_de, TQ, ThPa2D.flux)
# [Pa] loop
DPa, PPa = ThPa2D.adflow(g, h, t, T, u, Pk_ad, Pk_de, PQ, ThPa2D.flux)
# plot ratio of [Th]/[Pa]
ThPa = ThPa2D.plotratio(DTh.a, DPa.a, PTh.a, PPa.a, xmin, xmax, zmin, zmax, nx, nz, T)
# store Th results
DTh2vel['1tmax'] = copy.copy(DTh.a)
PTh2vel['1tmax'] = copy.copy(PTh.a)
# store Pa results
DPa2vel['1tmax'] = copy.copy(DPa.a)
PPa2vel['1tmax'] = copy.copy(PPa.a)

# %%
t = time[1]
T = time[2]
# [Th] loop
[DTh, PTh] = ThPa2D.adflow(DTh, PTh, t, T, u, Tk_ad, Tk_de, TQ, ThPa2D.flux)
# [Pa] loop
[DPa, PPa] = ThPa2D.adflow(DPa, PPa, t, T, u, Pk_ad, Pk_de, PQ, ThPa2D.flux)
# plot ratio of [Th]/[Pa]
ThPa = ThPa2D.plotratio(DTh.a, DPa.a, PTh.a, PPa.a, xmin, xmax, zmin, zmax, nx, nz, T)
# store Th results
DTh2vel['2tmax'] = copy.copy(DTh.a)
PTh2vel['2tmax'] = copy.copy(PTh.a)
# store Pa results
DPa2vel['2tmax'] = copy.copy(DPa.a)
PPa2vel['2tmax'] = copy.copy(PPa.a)

# %%
t = time[2]
T = time[3]
# [Th] loop
[DTh, PTh] = ThPa2D.adflow(DTh, PTh, t, T, u, Tk_ad, Tk_de, TQ, ThPa2D.flux)
# [Pa] loop
[DPa, PPa] = ThPa2D.adflow(DPa, PPa, t, T, u, Pk_ad, Pk_de, PQ, ThPa2D.flux)
# plot ratio of [Th]/[Pa]
ThPa = ThPa2D.plotratio(DTh.a, DPa.a, PTh.a, PPa.a, xmin, xmax, zmin, zmax, nx, nz, T)
# store Th results
DTh2vel['3tmax'] = copy.copy(DTh.a)
PTh2vel['3tmax'] = copy.copy(PTh.a)
# store Pa results
DPa2vel['3tmax'] = copy.copy(DPa.a)
PPa2vel['3tmax'] = copy.copy(PPa.a)

# %%
t = time[3]
T = time[4]
# [Th] loop
[DTh, PTh] = ThPa2D.adflow(DTh, PTh, t, T, u, Tk_ad, Tk_de, TQ, ThPa2D.flux)
# [Pa] loop
[DPa, PPa] = ThPa2D.adflow(DPa, PPa, t, T, u, Pk_ad, Pk_de, PQ, ThPa2D.flux)
# plot ratio of [Th]/[Pa]
ThPa = ThPa2D.plotratio(DTh.a, DPa.a, PTh.a, PPa.a, xmin, xmax, zmin, zmax, nx, nz, T)
# store Th results
DTh2vel['5tmax'] = copy.copy(DTh.a)
PTh2vel['5tmax'] = copy.copy(PTh.a)
# store Pa results
DPa2vel['5tmax'] = copy.copy(DPa.a)
PPa2vel['5tmax'] = copy.copy(PPa.a)
