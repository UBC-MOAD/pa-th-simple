# %% [markdown]
# Solves the [Th]/[Pa] on a 2D grid using an upwind advection scheme, and contains plots of [Th]/[Pa] profile for a zero velocity field, a single cell velocity field, and a two cell velocity field.

# %%
from __future__ import division
import numpy as np
import pylab as plb
import copy
import math
import matplotlib.pyplot as plt
from math import pi
import ThPa2D
import plot
import flow
# %matplotlib inline

# %% [markdown]
# # [Th]/[Pa] in Zero Velocity Field

# %%
reload(ThPa2D)
reload(flow)
reload(plot)
# set parameters
time = (0, 1, 2, 3, 5, 10, 20, 60, 100)
t = time[0]
T = time[1]
V = 0.02/1000*365.*86400.  # first number in mm/s, corrections give needed value in m/yr ~ 630
xmin = 1
xmax = 1e6
zmin = 0
zmax = 5e3
nz = 20
nx = 30
ng = 1
DTh = ThPa2D.FDTgrid(nx, nz, ng)
PTh = ThPa2D.FPTgrid(nx, nz, ng)
# velocity field
u = flow.zero(nz, nx)
# initial profile
init, flowfig = plot.init(DTh.a, PTh.a, u, xmin, xmax, zmin, zmax, nx, nz, 'ThPa')
# Th chemistry
Tk_ad, Tk_de, TQ = ThPa2D.k_sorp('Th', zmin, zmax, nx, nz)
# Pa chemistry
Pk_ad, Pk_de, PQ = ThPa2D.k_sorp('Pa', zmin, zmax, nx, nz)
# [Th] loop
DTh, PTh = ThPa2D.adflow(DTh, PTh, t, T, u, Tk_ad, Tk_de, TQ, ThPa2D.upstream_d, ThPa2D.upstream_p)
# [Pa] loop
DPa = ThPa2D.FDPgrid(nx, nz, ng)
PPa = ThPa2D.FPPgrid(nx, nz, ng)
DPa, PPa = ThPa2D.adflow(DPa, PPa, t, T, u, Pk_ad, Pk_de, PQ, ThPa2D.upstream_d, ThPa2D.upstream_p)
# plot ratio of [Th]/[Pa]
ThPa = plot.ratio(DTh.a, DPa.a, PTh.a, PPa.a, xmin, xmax, zmin, zmax, nx, nz, T)
# store Th results
DTh0vel = {}
PTh0vel = {}
DTh0vel['1tmax'] = copy.copy(DTh.a)
PTh0vel['1tmax'] = copy.copy(PTh.a)
# store Pa results
DPa0vel = {}
PPa0vel = {}
DPa0vel['1tmax'] = copy.copy(DPa.a)
PPa0vel['1tmax'] = copy.copy(PPa.a)
# Out:
# plot.py:101: RuntimeWarning: invalid value encountered in true_divide
#   Pratio = copy.copy(PT/PP)

# %%
t = time[1]
T = time[2]
# [Th] loop
[DTh, PTh] = ThPa2D.adflow(DTh, PTh, t, T, u, Tk_ad, Tk_de, TQ, ThPa2D.upstream_d, ThPa2D.upstream_p)
# [Pa] loop
[DPa, PPa] = ThPa2D.adflow(DPa, PPa, t, T, u, Pk_ad, Pk_de, PQ, ThPa2D.upstream_d, ThPa2D.upstream_p)
# plot ratio of [Th]/[Pa]
ThPa = plot.ratio(DTh.a, DPa.a, PTh.a, PPa.a, xmin, xmax, zmin, zmax, nx, nz, T)
# store Th results
DTh0vel['2tmax'] = copy.copy(DTh.a)
PTh0vel['2tmax'] = copy.copy(PTh.a)
# store Pa results
DPa0vel['2tmax'] = copy.copy(DPa.a)
PPa0vel['2tmax'] = copy.copy(PPa.a)

# %% [markdown]
# The dark stripe is the initial profile falling out. The steady state should be linear and ~constant in slope.

# %%
t = time[2]
T = time[3]
# [Th] loop
DTh, PTh = ThPa2D.adflow(DTh, PTh, t, T, u, Tk_ad, Tk_de, TQ, ThPa2D.upstream_d, ThPa2D.upstream_p)
# [Pa] loop
DPa, PPa = ThPa2D.adflow(DPa, PPa, t, T, u, Pk_ad, Pk_de, PQ, ThPa2D.upstream_d, ThPa2D.upstream_p)
# plot ratio of [Th]/[Pa]
ThPa = plot.ratio(DTh.a, DPa.a, PTh.a, PPa.a, xmin, xmax, zmin, zmax, nx, nz, T)
# store Th results
DTh0vel['3tmax'] = copy.copy(DTh.a)
PTh0vel['3tmax'] = copy.copy(PTh.a)
# store Pa results
DPa0vel['3tmax'] = copy.copy(DPa.a)
PPa0vel['3tmax'] = copy.copy(PPa.a)

# %%
t = time[3]
T = time[4]
# [Th] loop
DTh, PTh = ThPa2D.adflow(DTh, PTh, t, T, u, Tk_ad, Tk_de, TQ, ThPa2D.upstream_d, ThPa2D.upstream_p)
# [Pa] loop
DPa, PPa = ThPa2D.adflow(DPa, PPa, t, T, u, Pk_ad, Pk_de, PQ, ThPa2D.upstream_d, ThPa2D.upstream_p)
# plot ratio of [Th]/[Pa]
ThPa = plot.ratio(DTh.a, DPa.a, PTh.a, PPa.a, xmin, xmax, zmin, zmax, nx, nz, T)
# store Th results
DTh0vel['5tmax'] = copy.copy(DTh.a)
PTh0vel['5tmax'] = copy.copy(PTh.a)
# store Pa results
DPa0vel['5tmax'] = copy.copy(DPa.a)
PPa0vel['5tmax'] = copy.copy(PPa.a)

# %%
t = time[4]
T = time[5]
# [Th] loop
DTh, PTh = ThPa2D.adflow(DTh, PTh, t, T, u, Tk_ad, Tk_de, TQ, ThPa2D.upstream_d, ThPa2D.upstream_p)
# [Pa] loop
DPa, PPa = ThPa2D.adflow(DPa, PPa, t, T, u, Pk_ad, Pk_de, PQ, ThPa2D.upstream_d, ThPa2D.upstream_p)
# plot ratio of [Th]/[Pa]
ThPa = plot.ratio(DTh.a, DPa.a, PTh.a, PPa.a, xmin, xmax, zmin, zmax, nx, nz, T)
# store Th results
DTh0vel['10tmax'] = copy.copy(DTh.a)
PTh0vel['10tmax'] = copy.copy(PTh.a)
# store Pa results
DPa0vel['10tmax'] = copy.copy(DPa.a)
PPa0vel['10tmax'] = copy.copy(PPa.a)

# %%
t = time[5]
T = time[6]
# [Th] loop
DTh, PTh = ThPa2D.adflow(DTh, PTh, t, T, u, Tk_ad, Tk_de, TQ, ThPa2D.upstream_d, ThPa2D.upstream_p)
# [Pa] loop
DPa, PPa = ThPa2D.adflow(DPa, PPa, t, T, u, Pk_ad, Pk_de, PQ, ThPa2D.upstream_d, ThPa2D.upstream_p)
# plot ratio of [Th]/[Pa]
ThPa = plot.ratio(DTh.a, DPa.a, PTh.a, PPa.a, xmin, xmax, zmin, zmax, nx, nz, T)
# store Th steady state sol.
DTh0vel['20tmax'] = copy.copy(DTh.a)
PTh0vel['20tmax'] = copy.copy(PTh.a)
# store Pa results
DPa0vel['20tmax'] = copy.copy(DPa.a)
PPa0vel['20tmax'] = copy.copy(PPa.a)

# %%
t = time[6]
T = time[7]
# [Th] loop
#DTh, PTh = ThPa2D.adflow(DTh, PTh, t, T, u, Tk_ad, Tk_de, TQ, ThPa2D.upstream)
# [Pa] loop
DPa, PPa = ThPa2D.adflow(DPa, PPa, t, T, u, Pk_ad, Pk_de, PQ, ThPa2D.upstream_d, ThPa2D.upstream_p)
# plot ratio of [Th]/[Pa]
ThPa = plot.ratio(DTh.a, DPa.a, PTh.a, PPa.a, xmin, xmax, zmin, zmax, nx, nz, T)
# store Pa results
DPa0vel['60tmax'] = copy.copy(DPa.a)
PPa0vel['60tmax'] = copy.copy(PPa.a)

# %%
t = time[7]
T = time[8]
# [Th] loop
#DTh, PTh = ThPa2D.adflow(DTh, PTh, t, T, u, Tk_ad, Tk_de, TQ, ThPa2D.upstream)
# [Pa] loop
DPa, PPa = ThPa2D.adflow(DPa, PPa, t, T, u, Pk_ad, Pk_de, PQ, ThPa2D.upstream_d, ThPa2D.upstream_p)
# plot ratio of [Th]/[Pa]
ThPa = plot.ratio(DTh.a, DPa.a, PTh.a, PPa.a, xmin, xmax, zmin, zmax, nx, nz, T)
# store Pa results
DPa0vel['100tmax'] = copy.copy(DPa.a)
PPa0vel['100tmax'] = copy.copy(PPa.a)

# %% [markdown]
# In a region with no imposed velocity field, the particulate ratio becomes uniform and steady at ~ 10.8 = Q_Th / Q_Pa, the ratio of production rates.

# %% [markdown]
# The dissolved profile decreases fairly linearly with depth, with a steeper slope at the surface that at depth. The values never drop below zero.

# %% [markdown]
# # [Th]/[Pa] in Single Cell Velocity Field, upstream scheme

# %%
reload(ThPa2D)
reload(flow)
reload(plot)
# reset to 0-vel steady state
DTh = ThPa2D.FDTgrid(nx, nz, ng)
PTh = ThPa2D.FPTgrid(nx, nz, ng)
DPa = ThPa2D.FDPgrid(nx, nz, ng)
PPa = ThPa2D.FPPgrid(nx, nz, ng)
#DTh.a = copy.copy(DTh0vel['20tmax'])
#PTh.a = copy.copy(PTh0vel['20tmax'])
#DPa.a = copy.copy(DPa0vel['100tmax'])
#PPa.a = copy.copy(PPa0vel['100tmax'])
# set parameters
time = (0, 1, 2, 3, 5, 10, 20, 60, 100)
t = time[0]
T = time[1]
V = 0.02/1000*365.*86400.  # first number in mm/s, corrections give needed value in m/yr ~ 630
xmin = 0
xmax = 1e6
zmin = 0
zmax = 5e3
nz = 20
nx = 30
ng = 1
# velocity
u = flow.onecell(xmin, xmax, zmin, zmax, nx, nz, V)
u = flow.onecell_c(u, xmin, xmax, zmin, zmax, nx, nz)
# set initial profile to steady state of 0-vel. calculation (match plot.init input)
init, flowfig = plot.init(DTh.a/DPa.a, PTh.a/PPa.a, u, xmin, xmax, zmin, zmax, nx, nz, 'ThPa')
# Th chemistry
Tk_ad, Tk_de, TQ = ThPa2D.k_sorp('Th', zmin, zmax, nx, nz)
# Pa chemistry
Pk_ad, Pk_de, PQ = ThPa2D.k_sorp('Pa', zmin, zmax, nx, nz)
# [Th] loop
DTh, PTh = ThPa2D.adflow(DTh, PTh, t, T, u, Tk_ad, Tk_de, TQ, ThPa2D.upstream_d, ThPa2D.upstream_p)
# [Pa] loop
DPa, PPa = ThPa2D.adflow(DPa, PPa, t, T, u, Pk_ad, Pk_de, PQ, ThPa2D.upstream_d, ThPa2D.upstream_p)
# plot ratio of [Th]/[Pa]
ThPa = plot.ratio(DTh.a, DPa.a, PTh.a, PPa.a, xmin, xmax, zmin, zmax, nx, nz, T)
# store Th results
DTh1vel_T = {}
PTh1vel_T = {}
DTh1vel_T['1tmax'] = copy.copy(DTh.a)
PTh1vel_T['1tmax'] = copy.copy(PTh.a)
# store Pa results
DPa1vel_P = {}
PPa1vel_P = {}
DPa1vel_P['1tmax'] = copy.copy(DPa.a)
PPa1vel_P['1tmax'] = copy.copy(PPa.a)

# %%
t = time[1]
T = time[2]
# [Th] loop
[DTh, PTh] = ThPa2D.adflow(DTh, PTh, t, T, u, Tk_ad, Tk_de, TQ, ThPa2D.upstream_d, ThPa2D.upstream_p)
# [Pa] loop
[DPa, PPa] = ThPa2D.adflow(DPa, PPa, t, T, u, Pk_ad, Pk_de, PQ, ThPa2D.upstream_d, ThPa2D.upstream_p)
# plot ratio of [Th]/[Pa]
ThPa = plot.ratio(DTh.a, DPa.a, PTh.a, PPa.a, xmin, xmax, zmin, zmax, nx, nz, T)
# store Th results
DTh1vel_T['2tmax'] = copy.copy(DTh.a)
PTh1vel_T['2tmax'] = copy.copy(PTh.a)
# store Pa results
DPa1vel_P['2tmax'] = copy.copy(DPa.a)
PPa1vel_P['2tmax'] = copy.copy(PPa.a)

# %%
t = time[2]
T = time[3]
# [Th] loop
[DTh, PTh] = ThPa2D.adflow(DTh, PTh, t, T, u, Tk_ad, Tk_de, TQ, ThPa2D.upstream_d, ThPa2D.upstream_p)
# [Pa] loop
[DPa, PPa] = ThPa2D.adflow(DPa, PPa, t, T, u, Pk_ad, Pk_de, PQ, ThPa2D.upstream_d, ThPa2D.upstream_p)
# plot ratio of [Th]/[Pa]
ThPa = plot.ratio(DTh.a, DPa.a, PTh.a, PPa.a, xmin, xmax, zmin, zmax, nx, nz, T)
# store Th results
DTh1vel_T['3tmax'] = copy.copy(DTh.a)
PTh1vel_T['3tmax'] = copy.copy(PTh.a)
# store Pa results
DPa1vel_P['3tmax'] = copy.copy(DPa.a)
PPa1vel_P['3tmax'] = copy.copy(PPa.a)

# %%
t = time[3]
T = time[4]
# [Th] loop
[DTh, PTh] = ThPa2D.adflow(DTh, PTh, t, T, u, Tk_ad, Tk_de, TQ, ThPa2D.upstream_d, ThPa2D.upstream_p)
# [Pa] loop
[DPa, PPa] = ThPa2D.adflow(DPa, PPa, t, T, u, Pk_ad, Pk_de, PQ, ThPa2D.upstream_d, ThPa2D.upstream_p)
# plot ratio of [Th]/[Pa]
ThPa = plot.ratio(DTh.a, DPa.a, PTh.a, PPa.a, xmin, xmax, zmin, zmax, nx, nz, T)
# store Th results
DTh1vel_T['5tmax'] = copy.copy(DTh.a)
PTh1vel_T['5tmax'] = copy.copy(PTh.a)
# store Pa results
DPa1vel_P['5tmax'] = copy.copy(DPa.a)
PPa1vel_P['5tmax'] = copy.copy(PPa.a)

# %%
t = time[4]
T = time[5]
# [Th] loop
[DTh, PTh] = ThPa2D.adflow(DTh, PTh, t, T, u, Tk_ad, Tk_de, TQ, ThPa2D.upstream_d, ThPa2D.upstream_p)
# [Pa] loop
[DPa, PPa] = ThPa2D.adflow(DPa, PPa, t, T, u, Pk_ad, Pk_de, PQ, ThPa2D.upstream_d, ThPa2D.upstream_p)
# plot ratio of [Th]/[Pa]
ThPa = plot.ratio(DTh.a, DPa.a, PTh.a, PPa.a, xmin, xmax, zmin, zmax, nx, nz, T)
# store Th results
DTh1vel_T['10tmax'] = copy.copy(DTh.a)
PTh1vel_T['10tmax'] = copy.copy(PTh.a)
# store Pa results
DPa1vel_P['10tmax'] = copy.copy(DPa.a)
PPa1vel_P['10tmax'] = copy.copy(PPa.a)

# %%
t = time[5]
T = time[6]
# [Th] loop
[DTh, PTh] = ThPa2D.adflow(DTh, PTh, t, T, u, Tk_ad, Tk_de, TQ, ThPa2D.upstream_d, ThPa2D.upstream_p)
# [Pa] loop
[DPa, PPa] = ThPa2D.adflow(DPa, PPa, t, T, u, Pk_ad, Pk_de, PQ, ThPa2D.upstream_d, ThPa2D.upstream_p)
# plot ratio of [Th]/[Pa]
ThPa = plot.ratio(DTh.a, DPa.a, PTh.a, PPa.a, xmin, xmax, zmin, zmax, nx, nz, T)
# store Th results
DTh1vel_T['20tmax'] = copy.copy(DTh.a)
PTh1vel_T['20tmax'] = copy.copy(PTh.a)
# store Pa results
DPa1vel_P['20tmax'] = copy.copy(DPa.a)
PPa1vel_P['20tmax'] = copy.copy(PPa.a)

# %%
t = time[6]
T = time[7]
# [Th] loop
#[DTh, PTh] = ThPa2D.adflow(DTh, PTh, t, T, u, Tk_ad, Tk_de, TQ, ThPa2D.upstream)
# [Pa] loop
[DPa, PPa] = ThPa2D.adflow(DPa, PPa, t, T, u, Pk_ad, Pk_de, PQ, ThPa2D.upstream_d, ThPa2D.upstream_p)
# plot ratio of [Th]/[Pa]
ThPa = plot.ratio(DTh.a, DPa.a, PTh.a, PPa.a, xmin, xmax, zmin, zmax, nx, nz, T)
# store Pa results
DPa1vel_P['60tmax'] = copy.copy(DPa.a)
PPa1vel_P['60tmax'] = copy.copy(PPa.a)

# %% [markdown]
# Both profiles decrease in magnitude with depth. The contours in concentration are highly sensitive to upwelling and downwelling.

# %%
t = time[7]
T = time[8]
# [Th] loop
#[DTh, PTh] = ThPa2D.adflow(DTh, PTh, t, T, u, Tk_ad, Tk_de, TQ, ThPa2D.upstream)
# [Pa] loop
[DPa, PPa] = ThPa2D.adflow(DPa, PPa, t, T, u, Pk_ad, Pk_de, PQ, ThPa2D.upstream_d, ThPa2D.upstream_p)
# plot ratio of [Th]/[Pa]
ThPa = plot.ratio(DTh.a, DPa.a, PTh.a, PPa.a, xmin, xmax, zmin, zmax, nx, nz, T)
# store Pa results
DPa1vel_P['100tmax'] = copy.copy(DPa.a)
PPa1vel_P['100tmax'] = copy.copy(PPa.a)

# %% [markdown]
# # [Th]/[Pa] in a single cell velocity field, flux based method

# %% [markdown]
# Something is wrong in the flux based advection scheme:

# %%
reload(ThPa2D)
reload(flow)
reload(plot)
# set to 0-vel steady state
#DPa.a = copy.copy(DPa0vel['100tmax'])           # (match adflow input)
#PPa.a = copy.copy(PPa0vel['100tmax'])
#DTh.a = copy.copy(DTh0vel['20tmax'])
#PTh.a = copy.copy(PTh0vel['20tmax'])
DTh = ThPa2D.FDTgrid(nx, nz, ng)
PTh = ThPa2D.FPTgrid(nx, nz, ng)
DPa = ThPa2D.FDPgrid(nx, nz, ng)
PPa = ThPa2D.FPPgrid(nx, nz, ng)
# set parameters
time = (0, 1, 2, 3, 5, 10, 20, 60, 100)
t = time[0]
T = time[1]
V = 0.02/1000*365.*86400.  # first number in mm/s, corrections give needed value in m/yr ~ 630
xmin = 0
xmax = 1e6
zmin = 0
zmax = 5e3
nz = 20
nx = 30
ng = 1
# set initial profile to steady state of 0-vel. calculation
init, flowfig = plot.init(DTh.a/DPa.a, PTh.a/PPa.a, u, xmin, xmax, zmin, zmax, nx, nz, 'ThPa')
# velocity
u = flow.onecell(xmin, xmax, zmin, zmax, nx, nz, V)
u = flow.onecell_c(u, xmin, xmax, zmin, zmax, nx, nz)
# Th chemistry
Tk_ad, Tk_de, TQ = ThPa2D.k_sorp('Th', zmin, zmax, nx, nz)
# Pa chemistry
Pk_ad, Pk_de, PQ = ThPa2D.k_sorp('Pa', zmin, zmax, nx, nz)
# [Th] loop
DTh, PTh = ThPa2D.adflow(DTh, PTh, t, T, u, Tk_ad, Tk_de, TQ, ThPa2D.flux_d, ThPa2D.flux_p)
# [Pa] loop
DPa, PPa = ThPa2D.adflow(DPa, PPa, t, T, u, Pk_ad, Pk_de, PQ, ThPa2D.flux_d, ThPa2D.flux_p)
# plot ratio of [Th]/[Pa]
ThPa = plot.ratio(DTh.a, DPa.a, PTh.a, PPa.a, xmin, xmax, zmin, zmax, nx, nz, T)
# store Th results
DTh1vel_T = {}
PTh1vel_T = {}
DTh1vel_T['1tmax'] = copy.copy(DTh.a)
PTh1vel_T['1tmax'] = copy.copy(PTh.a)
# store Pa results
DPa1vel_P = {}
PPa1vel_P = {}
DPa1vel_P['1tmax'] = copy.copy(DPa.a)
PPa1vel_P['1tmax'] = copy.copy(PPa.a)

# %%
t = time[1]
T = time[2]
# [Th] loop
[DTh, PTh] = ThPa2D.adflow(DTh, PTh, t, T, u, Tk_ad, Tk_de, TQ, ThPa2D.flux_d, ThPa2D.flux_p)
# [Pa] loop
[DPa, PPa] = ThPa2D.adflow(DPa, PPa, t, T, u, Pk_ad, Pk_de, PQ, ThPa2D.flux_d, ThPa2D.flux_p)
# plot ratio of [Th]/[Pa]
ThPa = plot.ratio(DTh.a, DPa.a, PTh.a, PPa.a, xmin, xmax, zmin, zmax, nx, nz, T)
# store Th results
DTh1vel_T['2tmax'] = copy.copy(DTh.a)
PTh1vel_T['2tmax'] = copy.copy(PTh.a)
# store Pa results
DPa1vel_P['2tmax'] = copy.copy(DPa.a)
PPa1vel_P['2tmax'] = copy.copy(PPa.a)

# %%
t = time[2]
T = time[3]
# [Th] loop
[DTh, PTh] = ThPa2D.adflow(DTh, PTh, t, T, u, Tk_ad, Tk_de, TQ, ThPa2D.flux_d, ThPa2D.flux_p)
# [Pa] loop
[DPa, PPa] = ThPa2D.adflow(DPa, PPa, t, T, u, Pk_ad, Pk_de, PQ, ThPa2D.flux_d, ThPa2D.flux_p)
# plot ratio of [Th]/[Pa]
ThPa = plot.ratio(DTh.a, DPa.a, PTh.a, PPa.a, xmin, xmax, zmin, zmax, nx, nz, T)
# store Th results
DTh1vel_T['3tmax'] = copy.copy(DTh.a)
PTh1vel_T['3tmax'] = copy.copy(PTh.a)
# store Pa results
DPa1vel_P['3tmax'] = copy.copy(DPa.a)
PPa1vel_P['3tmax'] = copy.copy(PPa.a)

# %%
t = time[3]
T = time[4]
# [Th] loop
[DTh, PTh] = ThPa2D.adflow(DTh, PTh, t, T, u, Tk_ad, Tk_de, TQ, ThPa2D.flux_d, ThPa2D.flux_p)
# [Pa] loop
[DPa, PPa] = ThPa2D.adflow(DPa, PPa, t, T, u, Pk_ad, Pk_de, PQ, ThPa2D.flux_d, ThPa2D.flux_p)
# plot ratio of [Th]/[Pa]
ThPa = plot.ratio(DTh.a, DPa.a, PTh.a, PPa.a, xmin, xmax, zmin, zmax, nx, nz, T)
# store Th results
DTh1vel_T['5tmax'] = copy.copy(DTh.a)
PTh1vel_T['5tmax'] = copy.copy(PTh.a)
# store Pa results
DPa1vel_P['5tmax'] = copy.copy(DPa.a)
PPa1vel_P['5tmax'] = copy.copy(PPa.a)

# %%
t = time[4]
T = time[5]
# [Th] loop
[DTh, PTh] = ThPa2D.adflow(DTh, PTh, t, T, u, Tk_ad, Tk_de, TQ, ThPa2D.flux_d, ThPa2D.flux_p)
# [Pa] loop
[DPa, PPa] = ThPa2D.adflow(DPa, PPa, t, T, u, Pk_ad, Pk_de, PQ, ThPa2D.flux_d, ThPa2D.flux_p)
# plot ratio of [Th]/[Pa]
ThPa = plot.ratio(DTh.a, DPa.a, PTh.a, PPa.a, xmin, xmax, zmin, zmax, nx, nz, T)
# store Th results
DTh1vel_T['10tmax'] = copy.copy(DTh.a)
PTh1vel_T['10tmax'] = copy.copy(PTh.a)
# store Pa results
DPa1vel_P['10tmax'] = copy.copy(DPa.a)
PPa1vel_P['10tmax'] = copy.copy(PPa.a)

# %%
t = time[5]
T = time[6]
# [Th] loop
[DTh, PTh] = ThPa2D.adflow(DTh, PTh, t, T, u, Tk_ad, Tk_de, TQ, ThPa2D.flux_d, ThPa2D.flux_p)
# [Pa] loop
[DPa, PPa] = ThPa2D.adflow(DPa, PPa, t, T, u, Pk_ad, Pk_de, PQ, ThPa2D.flux_d, ThPa2D.flux_p)
# plot ratio of [Th]/[Pa]
ThPa = plot.ratio(DTh.a, DPa.a, PTh.a, PPa.a, xmin, xmax, zmin, zmax, nx, nz, T)
# store Th results
DTh1vel_T['20tmax'] = copy.copy(DTh.a)
PTh1vel_T['20tmax'] = copy.copy(PTh.a)
# store Pa results
DPa1vel_P['20tmax'] = copy.copy(DPa.a)
PPa1vel_P['20tmax'] = copy.copy(PPa.a)

# %%
t = time[6]
T = time[7]
# [Th] loop
#[DTh, PTh] = ThPa2D.adflow(DTh, PTh, t, T, u, Tk_ad, Tk_de, TQ, ThPa2D.flux_d, ThPa2D.flux_p)
# [Pa] loop
[DPa, PPa] = ThPa2D.adflow(DPa, PPa, t, T, u, Pk_ad, Pk_de, PQ, ThPa2D.flux_d, ThPa2D.flux_p)
# plot ratio of [Th]/[Pa]
ThPa = plot.ratio(DTh.a, DPa.a, PTh.a, PPa.a, xmin, xmax, zmin, zmax, nx, nz, T)
# store Pa results
DPa1vel_P['60tmax'] = copy.copy(DPa.a)
PPa1vel_P['60tmax'] = copy.copy(PPa.a)

# %%
t = time[7]
T = time[8]
# [Th] loop
#[DTh, PTh] = ThPa2D.adflow(DTh, PTh, t, T, u, Tk_ad, Tk_de, TQ, ThPa2D.flux_d, ThPa2D.flux_p)
# [Pa] loop
[DPa, PPa] = ThPa2D.adflow(DPa, PPa, t, T, u, Pk_ad, Pk_de, PQ, ThPa2D.flux_d, ThPa2D.flux_p)
# plot ratio of [Th]/[Pa]
ThPa = plot.ratio(DTh.a, DPa.a, PTh.a, PPa.a, xmin, xmax, zmin, zmax, nx, nz, T)
# store Pa results
DPa1vel_P['100tmax'] = copy.copy(DPa.a)
PPa1vel_P['100tmax'] = copy.copy(PPa.a)

# %% [markdown]
# # [Th]/[Pa] in Two Cell Velocity Field, upstream scheme

# %%
reload(ThPa2D)
reload(plot)
reload(flow)
# set to 0-vel steady state
#DPa.a = copy.copy(DPa0vel['100tmax'])           # (match adflow input)
#PPa.a = copy.copy(PPa0vel['100tmax'])
#DTh.a = copy.copy(DTh0vel['20tmax'])
#PTh.a = copy.copy(PTh0vel['20tmax'])
DTh = ThPa2D.FDTgrid(nx, nz, ng)
PTh = ThPa2D.FPTgrid(nx, nz, ng)
DPa = ThPa2D.FDPgrid(nx, nz, ng)
PPa = ThPa2D.FPPgrid(nx, nz, ng)
# set parms
time = (0, 1, 2, 3, 5, 10, 20, 60, 100)
t = time[0]
T = time[1]
V = 0.02/1000*365.*86400.  # first number in mm/s, corrections give needed value in m/yr ~ 630
xmin = 0
xmax = 1e6
zmin = 0
zmax = 5e3
nz = 20
nx = 30
ng = 1
# velocity
u = flow.twocell(xmin, xmax, zmin, zmax, nx, nz, V)
u = flow.twocell_c(u, xmin, xmax, zmin, zmax, nx, nz)
# set initial profile to steady state of 0-vel. calculation
init, flowfig = plot.init(DTh.a/DPa.a, PTh.a/PPa.a, u, xmin, xmax, zmin, zmax, nx, nz, 'ThPa')
# Th chemistry
Tk_ad, Tk_de, TQ = ThPa2D.k_sorp('Th', zmin, zmax, nx, nz)
# Pa chemistry
Pk_ad, Pk_de, PQ = ThPa2D.k_sorp('Pa', zmin, zmax, nx, nz)
# [Th] loop
DTh, PTh = ThPa2D.adflow(DTh, PTh, t, T, u, Tk_ad, Tk_de, TQ, ThPa2D.upstream_d, ThPa2D.upstream_p)
# [Pa] loop
DPa, PPa = ThPa2D.adflow(DPa, PPa, t, T, u, Pk_ad, Pk_de, PQ, ThPa2D.upstream_d, ThPa2D.upstream_p)
# plot ratio of [Th]/[Pa]
ThPa = plot.ratio(DTh.a, DPa.a, PTh.a, PPa.a, xmin, xmax, zmin, zmax, nx, nz, T)
# store Th results
DTh2vel_T = {}
PTh2vel_T = {}
DTh2vel_T['1tmax'] = copy.copy(DTh.a)
PTh2vel_T['1tmax'] = copy.copy(PTh.a)
# store Pa results
DPa2vel_P = {}
PPa2vel_P = {}
DPa2vel_P['1tmax'] = copy.copy(DPa.a)
PPa2vel_P['1tmax'] = copy.copy(PPa.a)
# Out:
# flow.py:151: RuntimeWarning: invalid value encountered in true_divide
#   ux[idx] = np.sin(2*pi*rr[idx] / a) / rr[idx] * -zz[idx]
# flow.py:153: RuntimeWarning: invalid value encountered in true_divide
#   uz[idx] = -np.sin(2*pi*rr[idx] / a) / rr[idx] * -xx[idx]

# %%
t = time[1]
T = time[2]
# [Th] loop
[DTh, PTh] = ThPa2D.adflow(DTh, PTh, t, T, u, Tk_ad, Tk_de, TQ, ThPa2D.upstream_d, ThPa2D.upstream_p)
# [Pa] loop
[DPa, PPa] = ThPa2D.adflow(DPa, PPa, t, T, u, Pk_ad, Pk_de, PQ, ThPa2D.upstream_d, ThPa2D.upstream_p)
# plot ratio of [Th]/[Pa]
ThPa = plot.ratio(DTh.a, DPa.a, PTh.a, PPa.a, xmin, xmax, zmin, zmax, nx, nz, T)
# store Th results
DTh2vel_T['2tmax'] = copy.copy(DTh.a)
PTh2vel_T['2tmax'] = copy.copy(PTh.a)
# store Pa results
DPa2vel_P['2tmax'] = copy.copy(DPa.a)
PPa2vel_P['2tmax'] = copy.copy(PPa.a)

# %%
t = time[2]
T = time[3]
# [Th] loop
[DTh, PTh] = ThPa2D.adflow(DTh, PTh, t, T, u, Tk_ad, Tk_de, TQ, ThPa2D.upstream_d, ThPa2D.upstream_p)
# [Pa] loop
[DPa, PPa] = ThPa2D.adflow(DPa, PPa, t, T, u, Pk_ad, Pk_de, PQ, ThPa2D.upstream_d, ThPa2D.upstream_p)
# plot ratio of [Th]/[Pa]
ThPa = plot.ratio(DTh.a, DPa.a, PTh.a, PPa.a, xmin, xmax, zmin, zmax, nx, nz, T)
# store Th results
DTh2vel_T['3tmax'] = copy.copy(DTh.a)
PTh2vel_T['3tmax'] = copy.copy(PTh.a)
# store Pa results
DPa2vel_P['3tmax'] = copy.copy(DPa.a)
PPa2vel_P['3tmax'] = copy.copy(PPa.a)

# %%
t = time[3]
T = time[4]
# [Th] loop
[DTh, PTh] = ThPa2D.adflow(DTh, PTh, t, T, u, Tk_ad, Tk_de, TQ, ThPa2D.upstream_d, ThPa2D.upstream_p)
# [Pa] loop
[DPa, PPa] = ThPa2D.adflow(DPa, PPa, t, T, u, Pk_ad, Pk_de, PQ, ThPa2D.upstream_d, ThPa2D.upstream_p)
# plot ratio of [Th]/[Pa]
ThPa = plot.ratio(DTh.a, DPa.a, PTh.a, PPa.a, xmin, xmax, zmin, zmax, nx, nz, T)
# store Th results
DTh2vel_T['5tmax'] = copy.copy(DTh.a)
PTh2vel_T['5tmax'] = copy.copy(PTh.a)
# store Pa results
DPa2vel_P['5tmax'] = copy.copy(DPa.a)
PPa2vel_P['5tmax'] = copy.copy(PPa.a)

# %%
t = time[4]
T = time[5]
# [Th] loop
[DTh, PTh] = ThPa2D.adflow(DTh, PTh, t, T, u, Tk_ad, Tk_de, TQ, ThPa2D.upstream_d, ThPa2D.upstream_p)
# [Pa] loop
[DPa, PPa] = ThPa2D.adflow(DPa, PPa, t, T, u, Pk_ad, Pk_de, PQ, ThPa2D.upstream_d, ThPa2D.upstream_p)
# plot ratio of [Th]/[Pa]
ThPa = plot.ratio(DTh.a, DPa.a, PTh.a, PPa.a, xmin, xmax, zmin, zmax, nx, nz, T)
# store Th results
DTh2vel_T['10tmax'] = copy.copy(DTh.a)
PTh2vel_T['10tmax'] = copy.copy(PTh.a)
# store Pa results
DPa2vel_P['10tmax'] = copy.copy(DPa.a)
PPa2vel_P['10tmax'] = copy.copy(PPa.a)

# %%
t = time[5]
T = time[6]
# [Th] loop
DTh, PTh = ThPa2D.adflow(DTh, PTh, t, T, u, Tk_ad, Tk_de, TQ, ThPa2D.upstream_d, ThPa2D.upstream_p)
# [Pa] loop
DPa, PPa = ThPa2D.adflow(DPa, PPa, t, T, u, Pk_ad, Pk_de, PQ, ThPa2D.upstream_d, ThPa2D.upstream_p)
# plot ratio of [Th]/[Pa]
ThPa = plot.ratio(DTh.a, DPa.a, PTh.a, PPa.a, xmin, xmax, zmin, zmax, nx, nz, T)
# store Th results
DTh2vel_T['20tmax'] = copy.copy(DTh.a)
PTh2vel_T['20tmax'] = copy.copy(PTh.a)
# store Pa results
DPa2vel_P['20tmax'] = copy.copy(DPa.a)
PPa2vel_P['20tmax'] = copy.copy(PPa.a)

# %%
t = time[6]
T = time[7]
# [Th] loop
#DTh, PTh = ThPa2D.adflow(DTh, PTh, t, T, u, Tk_ad, Tk_de, TQ, ThPa2D.upstream_d, ThPa2D.upstream_p)
# [Pa] loop
DPa, PPa = ThPa2D.adflow(DPa, PPa, t, T, u, Pk_ad, Pk_de, PQ, ThPa2D.upstream_d, ThPa2D.upstream_p)
# plot ratio of [Th]/[Pa]
ThPa = plot.ratio(DTh.a, DPa.a, PTh.a, PPa.a, xmin, xmax, zmin, zmax, nx, nz, T)
# store Th results
DTh2vel_T['60tmax'] = copy.copy(DTh.a)
PTh2vel_T['60tmax'] = copy.copy(PTh.a)
# store Pa results
DPa2vel_P['60tmax'] = copy.copy(DPa.a)
PPa2vel_P['60tmax'] = copy.copy(PPa.a)

# %%
t = time[7]
T = time[8]
# [Th] loop
#DTh, PTh = ThPa2D.adflow(DTh, PTh, t, T, u, Tk_ad, Tk_de, TQ, ThPa2D.upstream_d, ThPa2D.upstream_p)
# [Pa] loop
DPa, PPa = ThPa2D.adflow(DPa, PPa, t, T, u, Pk_ad, Pk_de, PQ, ThPa2D.upstream_d, ThPa2D.upstream_p)
# plot ratio of [Th]/[Pa]
ThPa = plot.ratio(DTh.a, DPa.a, PTh.a, PPa.a, xmin, xmax, zmin, zmax, nx, nz, T)
# store Pa results
DPa2vel_P['100tmax'] = copy.copy(DPa.a)
PPa2vel_P['100tmax'] = copy.copy(PPa.a)

# %% [markdown]
# The dissolved profile is unstable, but appears to have reached a steady state. It is plotting negative concentrations. You may need to take the absolute value in the interpolated BC. Also try implementing the FT-BC to compare; it looked strange (was a local max) in profiles of individual elements, but was stable in the ratio.

# %% [markdown]
# # [Th]/[Pa] in a 2-cell velocity field with flux based advection

# %%
reload(ThPa2D)
reload(plot)
reload(flow)
# set to 0-vel steady state
#DPa.a = copy.copy(DPa0vel['100tmax'])           # (match adflow input)
#PPa.a = copy.copy(PPa0vel['100tmax'])
#DTh.a = copy.copy(DTh0vel['20tmax'])
#PTh.a = copy.copy(PTh0vel['20tmax'])
DTh = ThPa2D.FDTgrid(nx, nz, ng)
PTh = ThPa2D.FPTgrid(nx, nz, ng)
DPa = ThPa2D.FDPgrid(nx, nz, ng)
PPa = ThPa2D.FPPgrid(nx, nz, ng)
# set parms
time = (0, 1, 2, 3, 5, 10, 20, 60, 100)
t = time[0]
T = time[1]
V = 0.02/1000*365.*86400.  # first number in mm/s, corrections give needed value in m/yr ~ 630
xmin = 0
xmax = 1e6
zmin = 0
zmax = 5e3
nz = 20
nx = 30
ng = 1
# velocity
u = flow.twocell(xmin, xmax, zmin, zmax, nx, nz, V)
u = flow.twocell_c(u, xmin, xmax, zmin, zmax, nx, nz)
# set initial profile to steady state of 0-vel. calculation
init, flowfig = plot.init(DTh.a/DPa.a, PTh.a/PPa.a, u, xmin, xmax, zmin, zmax, nx, nz, 'ThPa')
# Th chemistry
Tk_ad, Tk_de, TQ = ThPa2D.k_sorp('Th', zmin, zmax, nx, nz)
# Pa chemistry
Pk_ad, Pk_de, PQ = ThPa2D.k_sorp('Pa', zmin, zmax, nx, nz)
# [Th] loop
DTh, PTh = ThPa2D.adflow(DTh, PTh, t, T, u, Tk_ad, Tk_de, TQ, ThPa2D.flux_d, ThPa2D.flux_p)
# [Pa] loop
DPa, PPa = ThPa2D.adflow(DPa, PPa, t, T, u, Pk_ad, Pk_de, PQ, ThPa2D.flux_d, ThPa2D.flux_p)
# plot ratio of [Th]/[Pa]
ThPa = plot.ratio(DTh.a, DPa.a, PTh.a, PPa.a, xmin, xmax, zmin, zmax, nx, nz, T)
# store Th results
DTh2vel_T['1tmax'] = copy.copy(DTh.a)
PTh2vel_T['1tmax'] = copy.copy(PTh.a)
# store Pa results
DPa2vel_P['1tmax'] = copy.copy(DPa.a)
PPa2vel_P['1tmax'] = copy.copy(PPa.a)

# %%
t = time[1]
T = time[2]
# [Th] loop
[DTh, PTh] = ThPa2D.adflow(DTh, PTh, t, T, u, Tk_ad, Tk_de, TQ, ThPa2D.flux_d, ThPa2D.flux_p)
# [Pa] loop
[DPa, PPa] = ThPa2D.adflow(DPa, PPa, t, T, u, Pk_ad, Pk_de, PQ, ThPa2D.flux_d, ThPa2D.flux_p)
# plot ratio of [Th]/[Pa]
ThPa = plot.ratio(DTh.a, DPa.a, PTh.a, PPa.a, xmin, xmax, zmin, zmax, nx, nz, T)
# store Th results
DTh2vel_T['2tmax'] = copy.copy(DTh.a)
PTh2vel_T['2tmax'] = copy.copy(PTh.a)
# store Pa results
DPa2vel_P['2tmax'] = copy.copy(DPa.a)
PPa2vel_P['2tmax'] = copy.copy(PPa.a)

# %%
t = time[2]
T = time[3]
# [Th] loop
[DTh, PTh] = ThPa2D.adflow(DTh, PTh, t, T, u, Tk_ad, Tk_de, TQ, ThPa2D.flux_d, ThPa2D.flux_p)
# [Pa] loop
[DPa, PPa] = ThPa2D.adflow(DPa, PPa, t, T, u, Pk_ad, Pk_de, PQ, ThPa2D.flux_d, ThPa2D.flux_p)
# plot ratio of [Th]/[Pa]
ThPa = plot.ratio(DTh.a, DPa.a, PTh.a, PPa.a, xmin, xmax, zmin, zmax, nx, nz, T)
# store Th results
DTh2vel_T['3tmax'] = copy.copy(DTh.a)
PTh2vel_T['3tmax'] = copy.copy(PTh.a)
# store Pa results
DPa2vel_P['3tmax'] = copy.copy(DPa.a)
PPa2vel_P['3tmax'] = copy.copy(PPa.a)

# %%
t = time[3]
T = time[4]
# [Th] loop
[DTh, PTh] = ThPa2D.adflow(DTh, PTh, t, T, u, Tk_ad, Tk_de, TQ, ThPa2D.flux_d, ThPa2D.flux_p)
# [Pa] loop
[DPa, PPa] = ThPa2D.adflow(DPa, PPa, t, T, u, Pk_ad, Pk_de, PQ, ThPa2D.flux_d, ThPa2D.flux_p)
# plot ratio of [Th]/[Pa]
ThPa = plot.ratio(DTh.a, DPa.a, PTh.a, PPa.a, xmin, xmax, zmin, zmax, nx, nz, T)
# store Th results
DTh2vel_T['5tmax'] = copy.copy(DTh.a)
PTh2vel_T['5tmax'] = copy.copy(PTh.a)
# store Pa results
DPa2vel_P['5tmax'] = copy.copy(DPa.a)
PPa2vel_P['5tmax'] = copy.copy(PPa.a)

# %%
t = time[4]
T = time[5]
# [Th] loop
[DTh, PTh] = ThPa2D.adflow(DTh, PTh, t, T, u, Tk_ad, Tk_de, TQ, ThPa2D.flux_d, ThPa2D.flux_p)
# [Pa] loop
[DPa, PPa] = ThPa2D.adflow(DPa, PPa, t, T, u, Pk_ad, Pk_de, PQ, ThPa2D.flux_d, ThPa2D.flux_p)
# plot ratio of [Th]/[Pa]
ThPa = plot.ratio(DTh.a, DPa.a, PTh.a, PPa.a, xmin, xmax, zmin, zmax, nx, nz, T)
# store Th results
DTh2vel_T['10tmax'] = copy.copy(DTh.a)
PTh2vel_T['10tmax'] = copy.copy(PTh.a)
# store Pa results
DPa2vel_P['10tmax'] = copy.copy(DPa.a)
PPa2vel_P['10tmax'] = copy.copy(PPa.a)

# %%
t = time[5]
T = time[6]
# [Th] loop
[DTh, PTh] = ThPa2D.adflow(DTh, PTh, t, T, u, Tk_ad, Tk_de, TQ, ThPa2D.flux_d, ThPa2D.flux_p)
# [Pa] loop
[DPa, PPa] = ThPa2D.adflow(DPa, PPa, t, T, u, Pk_ad, Pk_de, PQ, ThPa2D.flux_d, ThPa2D.flux_p)
# plot ratio of [Th]/[Pa]
ThPa = plot.ratio(DTh.a, DPa.a, PTh.a, PPa.a, xmin, xmax, zmin, zmax, nx, nz, T)
# store Th results
DTh2vel_T['20tmax'] = copy.copy(DTh.a)
PTh2vel_T['20tmax'] = copy.copy(PTh.a)
# store Pa results
DPa2vel_P['20tmax'] = copy.copy(DPa.a)
PPa2vel_P['20tmax'] = copy.copy(PPa.a)

# %%
t = time[6]
T = time[7]
# [Th] loop
#[DTh, PTh] = ThPa2D.adflow(DTh, PTh, t, T, u, Tk_ad, Tk_de, TQ, ThPa2D.flux)
# [Pa] loop
[DPa, PPa] = ThPa2D.adflow(DPa, PPa, t, T, u, Pk_ad, Pk_de, PQ, ThPa2D.flux_d, ThPa2D.flux_p)
# plot ratio of [Th]/[Pa]
ThPa = plot.ratio(DTh.a, DPa.a, PTh.a, PPa.a, xmin, xmax, zmin, zmax, nx, nz, T)
# store Th results
DTh2vel_T['60tmax'] = copy.copy(DTh.a)
PTh2vel_T['60tmax'] = copy.copy(PTh.a)
# store Pa results
DPa2vel_P['60tmax'] = copy.copy(DPa.a)
PPa2vel_P['60tmax'] = copy.copy(PPa.a)

# %%
t = time[7]
T = time[8]
# [Th] loop
#[DTh, PTh] = ThPa2D.adflow(DTh, PTh, t, T, u, Tk_ad, Tk_de, TQ, ThPa2D.flux)
# [Pa] loop
[DPa, PPa] = ThPa2D.adflow(DPa, PPa, t, T, u, Pk_ad, Pk_de, PQ, ThPa2D.flux_d, ThPa2D.flux_p)
# plot ratio of [Th]/[Pa]
ThPa = plot.ratio(DTh.a, DPa.a, PTh.a, PPa.a, xmin, xmax, zmin, zmax, nx, nz, T)
# store Th results
DTh2vel_T['100tmax'] = copy.copy(DTh.a)
PTh2vel_T['100tmax'] = copy.copy(PTh.a)
# store Pa results
DPa2vel_P['100tmax'] = copy.copy(DPa.a)
PPa2vel_P['100tmax'] = copy.copy(PPa.a)
