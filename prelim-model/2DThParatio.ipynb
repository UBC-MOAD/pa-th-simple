# %% [markdown]
# Solves the [Th]/[Pa] on a 2D grid using an upwind advection scheme, and contains plots of [Th]/[Pa] profile for a zero velocity field, a single cell velocity field, and a two cell velocity field.

# %%
from __future__ import division
import numpy
import pylab
import math
import matplotlib.pyplot as plt
from math import pi
import ThPa2D
# %matplotlib inline

# %%
reload(ThPa2D)
# Out:
# <module 'ThPa2D' from 'ThPa2D.pyc'>

# %% [markdown]
# # [Th]/[Pa] in Zero Velocity Field

# %%
# set parameters
time = (0, 1, 2, 3, 5, 10)
t = time[0]
T = time[1]
V = 0.02/1000*365.*86400.  # first number in mm/s, corrections give needed value in m/yr ~ 630
xmin = 1
xmax = 1e6
zmin = 0
zmax = 5e3
nz = 20
nx = 20
ng = 1
g = ThPa2D.FDgrid(nx, nz, ng)
h = ThPa2D.FDgrid(nx, nz, ng)

# velocity field
[u, flowfig, init] = ThPa2D.u_zero(g, h, xmin, xmax, zmin, zmax, nx, nz, V, 'Pa')

# Th chemistry
[Tk_ad, Tk_de, TQ] = ThPa2D.k_sorp('Th', xmin, xmax, zmin, zmax, nx, nz)

# Pa chemistry
[Pk_ad, Pk_de, PQ] = ThPa2D.k_sorp('Pa', xmin, xmax, zmin, zmax, nx, nz)

# [Th] loop
[DTh, PTh] = ThPa2D.adflow(g, h, t, T, u, Tk_ad, Tk_de, TQ, ThPa2D.upwind)

# [Pa] loop
g = ThPa2D.FDgrid(nx, nz, ng)
h = ThPa2D.FDgrid(nx, nz, ng)
[DPa, PPa] = ThPa2D.adflow(g, h, t, T, u, Pk_ad, Pk_de, PQ, ThPa2D.upwind)

# plot ratio of [Th]/[Pa]
ThPa = ThPa2D.plotratio(DTh.a, DPa.a, PTh.a, PPa.a, xmin, xmax, zmin, zmax, nx, nz, T)

# %%
t = time[1]
T = time[2]

# [Th] loop
[DTh, PTh] = ThPa2D.adflow(g, h, t, T, u, Tk_ad, Tk_de, TQ, ThPa2D.upwind)

# [Pa] loop
g = ThPa2D.FDgrid(nx, nz, ng)
h = ThPa2D.FDgrid(nx, nz, ng)
[DPa, PPa] = ThPa2D.adflow(g, h, t, T, u, Pk_ad, Pk_de, PQ, ThPa2D.upwind)
pylab.close('all')

# plot ratio of [Th]/[Pa]
ThPa = ThPa2D.plotratio(DTh.a, DPa.a, PTh.a, PPa.a, xmin, xmax, zmin, zmax, nx, nz, T)

# %%
t = time[2]
T = time[3]

# [Th] loop
[DTh, PTh] = ThPa2D.adflow(g, h, t, T, u, Tk_ad, Tk_de, TQ, ThPa2D.upwind)

# [Pa] loop
g = ThPa2D.FDgrid(nx, nz, ng)
h = ThPa2D.FDgrid(nx, nz, ng)
[DPa, PPa] = ThPa2D.adflow(g, h, t, T, u, Pk_ad, Pk_de, PQ, ThPa2D.upwind)
pylab.close('all')

# plot ratio of [Th]/[Pa]
ThPa = ThPa2D.plotratio(DTh.a, DPa.a, PTh.a, PPa.a, xmin, xmax, zmin, zmax, nx, nz, T)

# %%
t = time[3]
T = time[4]

# [Th] loop
[DTh, PTh] = ThPa2D.adflow(g, h, t, T, u, Tk_ad, Tk_de, TQ, ThPa2D.upwind)

# [Pa] loop
g = ThPa2D.FDgrid(nx, nz, ng)
h = ThPa2D.FDgrid(nx, nz, ng)
[DPa, PPa] = ThPa2D.adflow(g, h, t, T, u, Pk_ad, Pk_de, PQ, ThPa2D.upwind)
pylab.close('all')

# plot ratio of [Th]/[Pa]
ThPa = ThPa2D.plotratio(DTh.a, DPa.a, PTh.a, PPa.a, xmin, xmax, zmin, zmax, nx, nz, T)

# %%
t = time[4]
T = time[5]

# [Th] loop
[DTh, PTh] = ThPa2D.adflow(g, h, t, T, u, Tk_ad, Tk_de, TQ, ThPa2D.upwind)

# [Pa] loop
g = ThPa2D.FDgrid(nx, nz, ng)
h = ThPa2D.FDgrid(nx, nz, ng)
[DPa, PPa] = ThPa2D.adflow(g, h, t, T, u, Pk_ad, Pk_de, PQ, ThPa2D.upwind)
pylab.close('all')

# plot ratio of [Th]/[Pa]
ThPa = ThPa2D.plotratio(DTh.a, DPa.a, PTh.a, PPa.a, xmin, xmax, zmin, zmax, nx, nz, T)

# %% [markdown]
# # [Th]/[Pa] in Single Cell Velocity Field

# %%
reload(ThPa2D)
# Out:
# <module 'ThPa2D' from 'ThPa2D.pyc'>

# %%
# set parms
time = (0, 1, 2, 3, 5, 10)
t = time[0]
T = time[1]
V = 0.02/1000*365.*86400.  # first number in mm/s, corrections give needed value in m/yr ~ 630
xmin = 0
xmax = 1e6
zmin = 0
zmax = 5e3
nz = 20
nx = 20
ng = 1
g = ThPa2D.FDgrid(nx, nz, ng)
h = ThPa2D.FDgrid(nx, nz, ng)

# Th chemistry
[Tk_ad, Tk_de, TQ] = ThPa2D.k_sorp('Th', xmin, xmax, zmin, zmax, nx, nz)

# Pa chemistry
[Pk_ad, Pk_de, PQ] = ThPa2D.k_sorp('Pa', xmin, xmax, zmin, zmax, nx, nz)

# velocity field
[u, flowfig, init] = ThPa2D.u_simple(g, h, xmin, xmax, zmin, zmax, nx, nz, V, 'Pa')

# [Th] loop
[DTh, PTh] = ThPa2D.adflow(g, h, t, T, u, Tk_ad, Tk_de, TQ, ThPa2D.upwind)

# [Pa] loop
g = ThPa2D.FDgrid(nx, nz, ng)
h = ThPa2D.FDgrid(nx, nz, ng)
[DPa, PPa] = ThPa2D.adflow(g, h, t, T, u, Pk_ad, Pk_de, PQ, ThPa2D.upwind)
pylab.close(2)
pylab.close(3)

# plot ratio of [Th]/[Pa]
ThPa = ThPa2D.plotratio(DTh.a, DPa.a, PTh.a, PPa.a, xmin, xmax, zmin, zmax, nx, nz, T)
# Out:
# ThPa2D.py:493: RuntimeWarning: invalid value encountered in true_divide
#   Dratio = DTh/DPa
# ThPa2D.py:498: RuntimeWarning: invalid value encountered in true_divide
#   Pratio = PTh/PPa

# %%
t = time[1]
T = time[2]

# [Th] loop
[DTh, PTh] = ThPa2D.adflow(g, h, t, T, u, Tk_ad, Tk_de, TQ, ThPa2D.upwind)
pylab.close('all')

# [Pa] loop
g = ThPa2D.FDgrid(nx, nz, ng)
h = ThPa2D.FDgrid(nx, nz, ng)
[DPa, PPa] = ThPa2D.adflow(g, h, t, T, u, Pk_ad, Pk_de, PQ, ThPa2D.upwind)
pylab.close('all')

# plot ratio of [Th]/[Pa]
ThPa = ThPa2D.plotratio(DTh.a, DPa.a, PTh.a, PPa.a, xmin, xmax, zmin, zmax, nx, nz, T)

# %%
t = time[2]
T = time[3]

# [Th] loop
[DTh, PTh] = ThPa2D.adflow(g, h, t, T, u, Tk_ad, Tk_de, TQ, ThPa2D.upwind)
pylab.close('all')

# [Pa] loop
g = ThPa2D.FDgrid(nx, nz, ng)
h = ThPa2D.FDgrid(nx, nz, ng)
[DPa, PPa] = ThPa2D.adflow(g, h, t, T, u, Pk_ad, Pk_de, PQ, ThPa2D.upwind)
pylab.close('all')

# plot ratio of [Th]/[Pa]
ThPa = ThPa2D.plotratio(DTh.a, DPa.a, PTh.a, PPa.a, xmin, xmax, zmin, zmax, nx, nz, T)

# %%
t = time[3]
T = time[4]

# [Th] loop
[DTh, PTh] = ThPa2D.adflow(g, h, t, T, u, Tk_ad, Tk_de, TQ, ThPa2D.upwind)
pylab.close('all')

# [Pa] loop
g = ThPa2D.FDgrid(nx, nz, ng)
h = ThPa2D.FDgrid(nx, nz, ng)
[DPa, PPa] = ThPa2D.adflow(g, h, t, T, u, Pk_ad, Pk_de, PQ, ThPa2D.upwind)
pylab.close('all')

# plot ratio of [Th]/[Pa]
ThPa = ThPa2D.plotratio(DTh.a, DPa.a, PTh.a, PPa.a, xmin, xmax, zmin, zmax, nx, nz, T)

# %%
t = time[4]
T = time[5]

# [Th] loop
[DTh, PTh] = ThPa2D.adflow(g, h, t, T, u, Tk_ad, Tk_de, TQ, ThPa2D.upwind)

# [Pa] loop
g = ThPa2D.FDgrid(nx, nz, ng)
h = ThPa2D.FDgrid(nx, nz, ng)
[DPa, PPa] = ThPa2D.adflow(g, h, t, T, u, Pk_ad, Pk_de, PQ, ThPa2D.upwind)
pylab.close('all')

# plot ratio of [Th]/[Pa]
ThPa = ThPa2D.plotratio(DTh.a, DPa.a, PTh.a, PPa.a, xmin, xmax, zmin, zmax, nx, nz, T)

# %% [markdown]
# # [Th]/[Pa] in Two Cell Velocity Field

# %%
# set parms
time = (0, 1, 2, 3, 5, 10)
t = time[0]
T = time[1]
V = 0.02/1000*365.*86400.  # first number in mm/s, corrections give needed value in m/yr ~ 630
xmin = 0
xmax = 1e6
zmin = 0
zmax = 5e3
nz = 20
nx = 20
ng = 1
g = ThPa2D.FDgrid(nx, nz, ng)
h = ThPa2D.FDgrid(nx, nz, ng)

# Th chemistry
[Tk_ad, Tk_de, TQ] = ThPa2D.k_sorp('Th', xmin, xmax, zmin, zmax, nx, nz)

# Pa chemistry
[Pk_ad, Pk_de, PQ] = ThPa2D.k_sorp('Pa', xmin, xmax, zmin, zmax, nx, nz)

# velocity field
[u, flowfig, init] = ThPa2D.u_complex(g, h, xmin, xmax, zmin, zmax, nx, nz, V, 'Pa')

# [Th] loop
[DTh, PTh] = ThPa2D.adflow(g, h, t, T, u, Tk_ad, Tk_de, TQ, ThPa2D.upwind)

# [Pa] loop
g = ThPa2D.FDgrid(nx, nz, ng)
h = ThPa2D.FDgrid(nx, nz, ng)
[DPa, PPa] = ThPa2D.adflow(g, h, t, T, u, Pk_ad, Pk_de, PQ, ThPa2D.upwind)
pylab.close(2)
pylab.close(3)

# plot ratio of [Th]/[Pa]
ThPa = ThPa2D.plotratio(DTh.a, DPa.a, PTh.a, PPa.a, xmin, xmax, zmin, zmax, nx, nz, T)
# Out:
# ThPa2D.py:356: RuntimeWarning: divide by zero encountered in true_divide
#   theta = numpy.arctan(zz/xx)
# ThPa2D.py:356: RuntimeWarning: invalid value encountered in true_divide
#   theta = numpy.arctan(zz/xx)
# ThPa2D.py:357: RuntimeWarning: invalid value encountered in less
#   idx = rr < a*b/ ( 4*numpy.sqrt(1/4 * ((b*numpy.cos(theta))**2 + (a*numpy.sin(theta))**2)) )
# ThPa2D.py:495: RuntimeWarning: invalid value encountered in true_divide
#   Dratio = DTh/DPa
# ThPa2D.py:500: RuntimeWarning: invalid value encountered in true_divide
#   Pratio = PTh/PPa

# %%
t = time[1]
T = time[2]

# [Th] loop
[DTh, PTh] = ThPa2D.adflow(g, h, t, T, u, Tk_ad, Tk_de, TQ, ThPa2D.upwind)
pylab.close('all')

# [Pa] loop
g = ThPa2D.FDgrid(nx, nz, ng)
h = ThPa2D.FDgrid(nx, nz, ng)
[DPa, PPa] = ThPa2D.adflow(g, h, t, T, u, Pk_ad, Pk_de, PQ, ThPa2D.upwind)
pylab.close('all')

# plot ratio of [Th]/[Pa]
ThPa = ThPa2D.plotratio(DTh.a, DPa.a, PTh.a, PPa.a, xmin, xmax, zmin, zmax, nx, nz, T)

# %%
t = time[2]
T = time[3]

# [Th] loop
[DTh, PTh] = ThPa2D.adflow(g, h, t, T, u, Tk_ad, Tk_de, TQ, ThPa2D.upwind)
pylab.close('all')

# [Pa] loop
g = ThPa2D.FDgrid(nx, nz, ng)
h = ThPa2D.FDgrid(nx, nz, ng)
[DPa, PPa] = ThPa2D.adflow(g, h, t, T, u, Pk_ad, Pk_de, PQ, ThPa2D.upwind)
pylab.close('all')

# plot ratio of [Th]/[Pa]
ThPa = ThPa2D.plotratio(DTh.a, DPa.a, PTh.a, PPa.a, xmin, xmax, zmin, zmax, nx, nz, T)

# %%
t = time[3]
T = time[4]

# [Th] loop
[DTh, PTh] = ThPa2D.adflow(g, h, t, T, u, Tk_ad, Tk_de, TQ, ThPa2D.upwind)
pylab.close('all')

# [Pa] loop
g = ThPa2D.FDgrid(nx, nz, ng)
h = ThPa2D.FDgrid(nx, nz, ng)
[DPa, PPa] = ThPa2D.adflow(g, h, t, T, u, Pk_ad, Pk_de, PQ, ThPa2D.upwind)
pylab.close('all')

# plot ratio of [Th]/[Pa]
ThPa = ThPa2D.plotratio(DTh.a, DPa.a, PTh.a, PPa.a, xmin, xmax, zmin, zmax, nx, nz, T)

# %%
t = time[4]
T = time[5]

# [Th] loop
[DTh, PTh] = ThPa2D.adflow(g, h, t, T, u, Tk_ad, Tk_de, TQ, ThPa2D.upwind)
pylab.close('all')

# [Pa] loop
g = ThPa2D.FDgrid(nx, nz, ng)
h = ThPa2D.FDgrid(nx, nz, ng)
[DPa, PPa] = ThPa2D.adflow(g, h, t, T, u, Pk_ad, Pk_de, PQ, ThPa2D.upwind)
pylab.close('all')

# plot ratio of [Th]/[Pa]
ThPa = ThPa2D.plotratio(DTh.a, DPa.a, PTh.a, PPa.a, xmin, xmax, zmin, zmax, nx, nz, T)

# %% [markdown]
# The ratio is still changing significantly in years 50 - 100. Th comes to a stady state in 100 years, so this must be due to the problem in the [Pa] code. It might be unstable.
