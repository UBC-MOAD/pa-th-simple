# %% [markdown]
# Running new modules threeflow.py and threeplot.py

# %%
from __future__ import division
import numpy as np
import pylab as plb
import math
import copy
import matplotlib.pyplot as plt
from math import pi
import ThPa3D
import threeflow
import threeplot
import profile_plots as pp
# %matplotlib inline

# %%
# setup function adflow for Th 
reload(ThPa3D);reload(threeplot);reload(threeflow)
#time coordinates
tmax = (0, 1, 2, 3, 5, 10, 20, 60, 100);t = tmax[0];T = tmax[1]; dt = 0.01
# spatial coordinates
xmin = 0;xmax = 1e6;zmin = 0;zmax = 5e3;ymin = 0;ymax = 1e6;nz = 20;nx = 32;ny = 32;ng = 1
# data storage structures
g = ThPa3D.Fgrid(nx, ny, nz, ng, dt);h = ThPa3D.Fgrid(nx, ny, nz, ng, dt)
# chemistry
k_ad, k_de, Q = ThPa3D.k_sorp3('Pa', zmin, zmax, nx, ny, nz)
# velocity
V = 0.02/1000*365.*86400.
n = 5

# %%
u = threeflow.onecell_cen_xz(xmin, xmax, zmin, zmax, nx, ny, nz, V)
init = threeplot.init(g.a, h.a, u, xmin, xmax, ymin, ymax, zmin, zmax, nx, ny, nz, 'Pa', n)
plt.close(1)

# %%
u = threeflow.twocell_cen_xz(xmin, xmax, zmin, zmax, nx, ny, nz, V)
init = threeplot.init(g.a, h.a, u, xmin, xmax, ymin, ymax, zmin, zmax, nx, ny, nz, 'Pa', n)
plt.close(1)

# %%
reload(threeflow)
u = threeflow.onecell_cen_xyz(xmin, xmax, ymin, ymax,zmin, zmax, nx, ny, nz, V)
init = threeplot.init(g.a, h.a, u, xmin, xmax, ymin, ymax, zmin, zmax, nx, ny, nz, 'Pa', n)
plt.close(1)

# %%
u = threeflow.twocell_cen_xyz(xmin, xmax, ymin,ymax,zmin, zmax, nx, ny, nz, V)
init = threeplot.init(g.a, h.a, u, xmin, xmax, ymin, ymax, zmin, zmax, nx, ny, nz, 'Pa', n)
plt.close(1)
