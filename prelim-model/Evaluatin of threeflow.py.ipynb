# %% [markdown]
# Running new module threeflow.py

# %%
from __future__ import division
import numpy as np
import pylab as plb
import math
import copy
import matplotlib.pyplot as plt
from math import pi
import ThPa2D
import threeflow
import twoplot
import profile_plots as pp
# %matplotlib inline

# %%
# setup function adflow for Th 
reload(ThPa2D);reload(twoplot);reload(threeflow)
#time coordinates
tmax = (0, 1, 2, 3, 5, 10, 20, 60, 100);t = tmax[0];T = tmax[1]; dt = 0.01
# spatial coordinates
xmin = 0;xmax = 1e6;zmin = 0;zmax = 5e3;ymin = 0;ymax = 1e6;nz = 20;nx = 32;ny = 32;ng = 1
# data storage structures
g = ThPa2D.Fgrid(nx, nz, ng, dt);h = ThPa2D.Fgrid(nx, nz, ng, dt)
# chemistry
k_ad, k_de, Q = ThPa2D.k_sorp('Pa', zmin, zmax, nx, nz)
# velocity
V = 0.02/1000*365.*86400.
u = threeflow.onecell_cen_xz(xmin, xmax, zmin, zmax, nx, nz, ny, V)

# %%
x = np.linspace(xmin, xmax, nx)
y = np.linspace(ymin, ymax, ny)
z = np.linspace(zmin, zmax, nz)
n = 10
fig = plt.figure(figsize=(10, 10))
im = plt.imshow(100*(u[0,n,:,:]), interpolation='none',extent=[0,1000,0,1000])
plt.quiver(1e-3*x, 1e-3*y, u[1,n,:,:], u[2,n,:,:], angles='xy', scale_units='xy')
plt.xlabel('x')
plt.ylabel('y')
plt.colorbar(im)
plb.gca().invert_yaxis()

# %%
u = threeflow.twocell_cen_xz(xmin, xmax, zmin, zmax, nx, nz, ny, V)
x = np.linspace(xmin, xmax, nx)
y = np.linspace(ymin, ymax, nx)
z = np.linspace(zmin, zmax, nz)
n = 10
fig = plt.figure(figsize=(10, 10))
im = plt.imshow(100*(u[0,n,:,:]), interpolation='none',extent=[0,1000,0,1000])
plt.quiver(1e-3*x, 1e-3*y, u[1,n,:,:], u[2,n,:,:], angles='xy', scale_units='xy')
plt.xlabel('x')
plt.ylabel('y')
plt.colorbar(im)
plb.gca().invert_yaxis()

# %%
u = threeflow.onecell_cen_xyz(xmin, xmax, ymin,ymax,zmin, zmax, nx, nz, ny, V)
x = np.linspace(xmin, xmax, nx)
y = np.linspace(ymin, ymax, nx)
z = np.linspace(zmin, zmax, nz)
n = 10
fig = plt.figure(figsize=(10, 10))
im = plt.imshow(100*(u[0,n,:,:]), interpolation='none',extent=[0,1000,0,1000])
plt.quiver(1e-3*x, 1e-3*y, u[1,n,:,:], u[2,n,:,:], angles='xy', scale_units='xy')
plt.xlabel('x')
plt.ylabel('y')
plt.colorbar(im)
plb.gca().invert_yaxis()

# %%
u = threeflow.twocell_cen_xyz(xmin, xmax, ymin,ymax,zmin, zmax, nx, nz, ny, V)
x = np.linspace(xmin, xmax, nx)
y = np.linspace(ymin, ymax, nx)
z = np.linspace(zmin, zmax, nz)
n = 10
fig = plt.figure(figsize=(10, 10))
im = plt.imshow(100*(u[0,n,:,:]), interpolation='none',extent=[0,1000,0,1000])
plt.quiver(1e-3*x, 1e-3*y, u[1,n,:,:], u[2,n,:,:], angles='xy', scale_units='xy')
plt.xlabel('x')
plt.ylabel('y')
plt.colorbar(im)
plb.gca().invert_yaxis()
