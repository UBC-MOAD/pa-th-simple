# %% [markdown]
# Plots [Th]/[Pa] for three different velocity fields: stationary, single cell, and two cell overturning.

# %%
from __future__ import division
import numpy
import pylab
import math
import matplotlib.pyplot as plt
from math import pi
import Th2D
# %matplotlib inline

# %%
reload(Th2D)
# Out:
# <module 'Th2D' from 'Th2D.py'>

# %% [markdown]
# ### Zero Velocity

# %%
# set parameters

T = 1
V = 10
xmin = 1
xmax = 10000
zmin = 0
zmax = 5000
nz = 20
nx = 20

# velocity field
[u, flowfig] = Th2D.u_zero(xmin, xmax, zmin, zmax, nx, nz)

# Th chemistry
[Tk_ad, Tk_de, TQ] = Th2D.k_sorp('Th', xmin, xmax, zmin, zmax, nx, nz)

# Pa chemistry
[Pk_ad, Pk_de, PQ] = Th2D.k_sorp('Pa', xmin, xmax, zmin, zmax, nx, nz)

# [Th] loop
[flowfig, meshTh, DTh, PTh] = Th2D.adflow(T, V, u, nz, nx, Tk_ad, Tk_de, TQ, flowfig)
pylab.close()
pylab.close()

# [Pa] loop
[flowfig, meshTh, DPa, PPa] = Th2D.adflow(T, V, u, nz, nx, Pk_ad, Pk_de, PQ, flowfig)
pylab.close()
pylab.close()

# plot ratio of [Th]/[Pa]
ThPa = Th2D.plotratio(DTh, DPa, PTh, PPa, xmin, xmax, zmin, zmax, nx, nz)

# %%
T = 2

# [Th] loop
[flowfig, meshTh, DTh, PTh] = Th2D.adflow(T, V, u, nz, nx, Tk_ad, Tk_de, TQ, flowfig)
pylab.close()
pylab.close()

# [Pa] loop
[flowfig, meshTh, DPa, PPa] = Th2D.adflow(T, V, u, nz, nx, Pk_ad, Pk_de, PQ, flowfig)
pylab.close()
pylab.close()

# plot ratio of [Th]/[Pa]
ThParatio = Th2D.plotratio(DTh, DPa, PTh, PPa, xmin, xmax, zmin, zmax, nx, nz)

# %%
T = 3

# [Th] loop
[flowfig, meshTh, DTh, PTh] = Th2D.adflow(T, V, u, nz, nx, Tk_ad, Tk_de, TQ, flowfig)
pylab.close()
pylab.close()

# [Pa] loop
[flowfig, meshTh, DPa, PPa] = Th2D.adflow(T, V, u, nz, nx, Pk_ad, Pk_de, PQ, flowfig)
pylab.close()
pylab.close()

# plot ratio of [Th]/[Pa]
ThParatio = Th2D.plotratio(DTh, DPa, PTh, PPa, xmin, xmax, zmin, zmax, nx, nz)

# %%
T = 5

# [Th] loop
[flowfig, meshTh, DTh, PTh] = Th2D.adflow(T, V, u, nz, nx, Tk_ad, Tk_de, TQ, flowfig)
pylab.close()
pylab.close()

# [Pa] loop
[flowfig, meshTh, DPa, PPa] = Th2D.adflow(T, V, u, nz, nx, Pk_ad, Pk_de, PQ, flowfig)
pylab.close()
pylab.close()

# plot ratio of [Th]/[Pa]
ThParatio = Th2D.plotratio(DTh, DPa, PTh, PPa, xmin, xmax, zmin, zmax, nx, nz)

# %%
T = 8

# [Th] loop
[flowfig, meshTh, DTh, PTh] = Th2D.adflow(T, V, u, nz, nx, Tk_ad, Tk_de, TQ, flowfig)
pylab.close()
pylab.close()

# [Pa] loop
[flowfig, meshTh, DPa, PPa] = Th2D.adflow(T, V, u, nz, nx, Pk_ad, Pk_de, PQ, flowfig)
pylab.close()
pylab.close()

# plot ratio of [Th]/[Pa]
ThParatio = Th2D.plotratio(DTh, DPa, PTh, PPa, xmin, xmax, zmin, zmax, nx, nz)

# %%
T = 12

# [Th] loop
[flowfig, meshTh, DTh, PTh] = Th2D.adflow(T, V, u, nz, nx, Tk_ad, Tk_de, TQ, flowfig)
pylab.close()
pylab.close()

# [Pa] loop
[flowfig, meshTh, DPa, PPa] = Th2D.adflow(T, V, u, nz, nx, Pk_ad, Pk_de, PQ, flowfig)
pylab.close()
pylab.close()

# plot ratio of [Th]/[Pa]
ThParatio = Th2D.plotratio(DTh, DPa, PTh, PPa, xmin, xmax, zmin, zmax, nx, nz, T)

# %% [markdown]
# ### Single Cell Velocity

# %%
reload(Th2D)
# Out:
# <module 'Th2D' from 'Th2D.py'>

# %%
T = 1

# velocity field
[u, flowfig] = Th2D.u_simple(xmin, xmax, zmin, zmax, nx, nz)

# [Th] loop
[flowfig, meshTh, DTh, PTh] = Th2D.adflow(T, V, u, nz, nx, Tk_ad, Tk_de, TQ, flowfig)
pylab.close()
pylab.close()

# [Pa] loop
[flowfig, meshTh, DPa, PPa] = Th2D.adflow(T, V, u, nz, nx, Pk_ad, Pk_de, PQ, flowfig)
pylab.close()
pylab.close()

# plot ratio of [Th]/[Pa]
ThParatio = Th2D.plotratio(DTh, DPa, PTh, PPa, xmin, xmax, zmin, zmax, nx, nz, T)
# Out:
# Th2D.py:518: RuntimeWarning: invalid value encountered in true_divide
#   ratio = PPa/PTh

# %%
T = 2

# [Th] loop
[flowfig, meshTh, DTh, PTh] = Th2D.adflow(T, V, u, nz, nx, Tk_ad, Tk_de, TQ, flowfig)
pylab.close()
pylab.close()

# [Pa] loop
[flowfig, meshTh, DPa, PPa] = Th2D.adflow(T, V, u, nz, nx, Pk_ad, Pk_de, PQ, flowfig)
pylab.close()
pylab.close()

# plot ratio of [Th]/[Pa]
ThParatio = Th2D.plotratio(DTh, DPa, PTh, PPa, xmin, xmax, zmin, zmax, nx, nz)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-33-a8019b5cae05> in <module>()
#       2
#       3 # [Th] loop
# ----> 4 [flowfig, meshTh, DTh, PTh] = Th2D.adflow(T, V, u, nz, nx, Tk_ad, Tk_de, TQ, flowfig)
#       5 pylab.close()
#       6 pylab.close()
#
# /home/abellas/Documents/GEOTRACES/Pa-Th/prelim-model/Th2D.py in adflow(T, V, u, nz, nx, k_ad, k_de, Q, flowfig)
#     159                                 # dissolved:
#     160 				anew[i, j] = g.a[i, j] + ( Q - k_ad[i, j] * g.a[i, j] + k_de[i, j] * h.a[i, j] +
# --> 161                                             ux[i, j] * ( n_upx[i, j]*g.a[i, j - 1] - g.a[i, j] + p_upx[i, j]*g.a[i, j + 1] ) / g.dx +
#     162 					    uz[i, j] * ( n_upz[i, j]*g.a[i - 1, j] - g.a[i, j] + p_upz[i, j]*g.a[i + 1, j] ) / g.dz ) 							* dt
#     163
#
# KeyboardInterrupt:

# %%
T = 3

# [Th] loop
[flowfig, meshTh, DTh, PTh] = Th2D.adflow(T, V, u, nz, nx, Tk_ad, Tk_de, TQ, flowfig)
pylab.close()
pylab.close()

# [Pa] loop
[flowfig, meshTh, DPa, PPa] = Th2D.adflow(T, V, u, nz, nx, Pk_ad, Pk_de, PQ, flowfig)
pylab.close()
pylab.close()

# plot ratio of [Th]/[Pa]
ThParatio = Th2D.plotratio(DTh, DPa, PTh, PPa, xmin, xmax, zmin, zmax, nx, nz)

# %%
T = 5

# [Th] loop
[flowfig, meshTh, DTh, PTh] = Th2D.adflow(T, V, u, nz, nx, Tk_ad, Tk_de, TQ, flowfig)
pylab.close()
pylab.close()

# [Pa] loop
[flowfig, meshTh, DPa, PPa] = Th2D.adflow(T, V, u, nz, nx, Pk_ad, Pk_de, PQ, flowfig)
pylab.close()
pylab.close()

# plot ratio of [Th]/[Pa]
ThParatio = Th2D.plotratio(DTh, DPa, PTh, PPa, xmin, xmax, zmin, zmax, nx, nz)

# %%
T = 8

# [Th] loop
[flowfig, meshTh, DTh, PTh] = Th2D.adflow(T, V, u, nz, nx, Tk_ad, Tk_de, TQ, flowfig)
pylab.close()
pylab.close()

# [Pa] loop
[flowfig, meshTh, DPa, PPa] = Th2D.adflow(T, V, u, nz, nx, Pk_ad, Pk_de, PQ, flowfig)
pylab.close()
pylab.close()

# plot ratio of [Th]/[Pa]
ThParatio = Th2D.plotratio(DTh, DPa, PTh, PPa, xmin, xmax, zmin, zmax, nx, nz)

# %% [markdown]
# ### Two Cell Velocity

# %%
T = 1

# velocity field
[u, flowfig] = Th2D.u_complex(xmin, xmax, zmin, zmax, nx, nz)

# [Th] loop
[flowfig, meshTh, DTh, PTh] = Th2D.adflow(T, V, u, nz, nx, Tk_ad, Tk_de, TQ, flowfig)
pylab.close()
pylab.close()

# [Pa] loop
[flowfig, meshTh, DPa, PPa] = Th2D.adflow(T, V, u, nz, nx, Pk_ad, Pk_de, PQ, flowfig)
pylab.close()
pylab.close()

# plot ratio of [Th]/[Pa]
ThParatio = Th2D.plotratio(DTh, DPa, PTh, PPa, xmin, xmax, zmin, zmax, nx, nz)

# %%
T = 2

# [Th] loop
[flowfig, meshTh, DTh, PTh] = Th2D.adflow(T, V, u, nz, nx, Tk_ad, Tk_de, TQ, flowfig)
pylab.close()
pylab.close()

# [Pa] loop
[flowfig, meshTh, DPa, PPa] = Th2D.adflow(T, V, u, nz, nx, Pk_ad, Pk_de, PQ, flowfig)
pylab.close()
pylab.close()

# plot ratio of [Th]/[Pa]
ThParatio = Th2D.plotratio(DTh, DPa, PTh, PPa, xmin, xmax, zmin, zmax, nx, nz)

# %%
T = 3

# [Th] loop
[flowfig, meshTh, DTh, PTh] = Th2D.adflow(T, V, u, nz, nx, Tk_ad, Tk_de, TQ, flowfig)
pylab.close()
pylab.close()

# [Pa] loop
[flowfig, meshTh, DPa, PPa] = Th2D.adflow(T, V, u, nz, nx, Pk_ad, Pk_de, PQ, flowfig)
pylab.close()
pylab.close()

# plot ratio of [Th]/[Pa]
ThParatio = Th2D.plotratio(DTh, DPa, PTh, PPa, xmin, xmax, zmin, zmax, nx, nz)

# %%
T = 5

# [Th] loop
[flowfig, meshTh, DTh, PTh] = Th2D.adflow(T, V, u, nz, nx, Tk_ad, Tk_de, TQ, flowfig)
pylab.close()
pylab.close()

# [Pa] loop
[flowfig, meshTh, DPa, PPa] = Th2D.adflow(T, V, u, nz, nx, Pk_ad, Pk_de, PQ, flowfig)
pylab.close()
pylab.close()

# plot ratio of [Th]/[Pa]
ThParatio = Th2D.plotratio(DTh, DPa, PTh, PPa, xmin, xmax, zmin, zmax, nx, nz)

# %%
T = 8

# [Th] loop
[flowfig, meshTh, DTh, PTh] = Th2D.adflow(T, V, u, nz, nx, Tk_ad, Tk_de, TQ, flowfig)
pylab.close()
pylab.close()

# [Pa] loop
[flowfig, meshTh, DPa, PPa] = Th2D.adflow(T, V, u, nz, nx, Pk_ad, Pk_de, PQ, flowfig)
pylab.close()
pylab.close()

# plot ratio of [Th]/[Pa]
ThParatio = Th2D.plotratio(DTh, DPa, PTh, PPa, xmin, xmax, zmin, zmax, nx, nz)
