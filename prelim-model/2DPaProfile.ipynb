# %% [markdown]
# Solves the [Pa] on a 2D 1e6m x 5e3m grid using an upwind advection scheme, and contains plots of [Pa] profile for a zero velocity field, a single cell velocity field, and a two cell velocity field.

# %%
from __future__ import division
import numpy
import pylab
import math
import matplotlib.pyplot as plt
from math import pi
import ThPa2D
# %matplotlib inline

# %% [markdown]
# # [Pa] for Zero Velocity Field

# %%
reload(ThPa2D)
# Out:
# <module 'ThPa2D' from 'ThPa2D.pyc'>

# %%
# setup function adflow for Th 

tmax = (0, 1, 2, 3, 5, 10)
t = tmax[0]
T = tmax[1]
V = 1
xmin = 1
xmax = 1e6
zmin = 0
zmax = 5e3
nz = 20
nx = 20
ng = 1
g = ThPa2D.FDgrid(nx, nz, ng)
h = ThPa2D.FDgrid(nx, nz, ng)

# chemistry
k_ad, k_de, Q = ThPa2D.k_sorp('Pa', xmin, xmax, zmin, zmax, nx, nz)

# velocity
u, flowfig = ThPa2D.u_zero(g, h, xmin, xmax, zmin, zmax, nx, nz, 'Pa')

# Th loop
g, h = ThPa2D.adflow(g, h, t, T, V, u, nz, nx, k_ad, k_de, Q)

#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')

# store results
DPa0vel = {}
PPa0vel = {}
DPa0vel['1tmax'] = g.a
PPa0vel['1tmax'] = h.a
# Out:
# /home/sallen/anaconda/lib/python2.7/site-packages/matplotlib/quiver.py:570: RuntimeWarning: divide by zero encountered in double_scalars
#   length = a * (widthu_per_lenu / (self.scale * self.width))
# /home/sallen/anaconda/lib/python2.7/site-packages/matplotlib/quiver.py:570: RuntimeWarning: invalid value encountered in multiply
#   length = a * (widthu_per_lenu / (self.scale * self.width))
# /home/sallen/anaconda/lib/python2.7/site-packages/matplotlib/quiver.py:626: RuntimeWarning: invalid value encountered in less
#   short = np.repeat(length < minsh, 8, axis=1)
# /home/sallen/anaconda/lib/python2.7/site-packages/matplotlib/quiver.py:636: RuntimeWarning: invalid value encountered in less
#   tooshort = length < self.minlength

# %%
plt.plot (DPa0vel['1tmax'][:,2],range(20,0,-1),'b',DPa0vel['1tmax'][:,18],range(20,0,-1),'r')

# %%
t = tmax[1]
T = tmax[2]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, V, u, nz, nx, k_ad, k_de, Q)

#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')

# store results
DPa0vel['2tmax'] = g.a
PPa0vel['2tmax'] = h.a

# %%
t = tmax[2]
T = tmax[3]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, V, u, nz, nx, k_ad, k_de, Q)

#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')

# store results
DPa0vel['3tmax'] = g.a
PPa0vel['3tmax'] = h.a

# %%
t = tmax[3]
T = tmax[4]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, V, u, nz, nx, k_ad, k_de, Q)

#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')

# store results
DPa0vel['5tmax'] = g.a
PPa0vel['5tmax'] = h.a

# %%
t = tmax[4]
T = tmax[5]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, V, u, nz, nx, k_ad, k_de, Q)

#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')

# store results
DPa0vel['10tmax'] = g.a
PPa0vel['10tmax'] = h.a

# %% [markdown]
# # [Pa] for Single Cell Velocity Field

# %%
reload(ThPa2D)
# Out:
# <module 'ThPa2D' from 'ThPa2D.pyc'>

# %%
# setup function adflow for Th 

tmax = (0, 1, 2, 3, 5, 10)
t = tmax[0]
T = tmax[1]
V = 1/10
xmin = 1
xmax = 1e6
zmin = 0
zmax = 5e3
nz = 20
nx = 20
ng = 1
g = ThPa2D.FDgrid(nx, nz, ng)
h = ThPa2D.FDgrid(nx, nz, ng)

# chemistry
k_ad, k_de, Q = ThPa2D.k_sorp('Pa', xmin, xmax, zmin, zmax, nx, nz)

# velocity
u, flowfig = ThPa2D.u_simple(g, h, xmin, xmax, zmin, zmax, nx, nz, 'Pa')

# Th loop
g, h = ThPa2D.adflow(g, h, t, T, V, u, nz, nx, k_ad, k_de, Q)

#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')

# store results
DPa1vel = {}
PPa1vel = {}
DPa1vel['1tmax'] = g.a
PPa1vel['1tmax'] = h.a

# %%
t = tmax[1]
T = tmax[2]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, V, u, nz, nx, k_ad, k_de, Q)

#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')

# store results
DPa1vel['2tmax'] = g.a
PPa1vel['2tmax'] = h.a

# %%
t = tmax[2]
T = tmax[3]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, V, u, nz, nx, k_ad, k_de, Q)

#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')

# store results
DPa1vel['3tmax'] = g.a
PPa1vel['3tmax'] = h.a

# %%
t = tmax[3]
T = tmax[4]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, V, u, nz, nx, k_ad, k_de, Q)

#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')

# store results
DPa1vel['5tmax'] = g.a
PPa1vel['5tmax'] = h.a

# %%
t = tmax[4]
T = tmax[5]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, V, u, nz, nx, k_ad, k_de, Q)

#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')

# store results
DPa1vel['10tmax'] = g.a
PPa1vel['10tmax'] = h.a

# %%
dz = (zmax-zmin)/nz
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.plot (DPa1vel['10tmax'][:,2],dz*numpy.arange(20),'bo-',label="Downwelling Side")
plt.plot (DPa1vel['10tmax'][:,10],dz*numpy.arange(20),'rx-',label="Center")
plt.plot (DPa1vel['10tmax'][:,18],dz*numpy.arange(20),'k+-',label="Upwelling Side")
plt.title("Dissolved Concentration")
plt.ylim (5000,0)
plt.legend(loc='center left')
plt.subplot(1,2,2)
plt.plot (1e6*(DPa1vel['10tmax'][:,2]-DPa1vel['10tmax'][:,18]),dz*numpy.arange(20),'gs-',label = "Downwelling-Upwelling")
plt.plot (1e6*(DPa1vel['10tmax'][:,10]-DPa1vel['10tmax'][:,18]),dz*numpy.arange(20),'m^-',label = "Center-Upwelling")
plt.legend(loc='lower left')
plt.ylim (5000,0)
plt.title("Difference in Concentration (x1e-6)")

# %% [markdown]
# # [Pa] for Two Cell Velocity Scheme

# %%
reload(ThPa2D)
# Out:
# <module 'ThPa2D' from 'ThPa2D.pyc'>

# %%
# setup function adflow for Th 

t = 0
T = 1
V = 1/10
xmin = 1
xmax = 1e6
zmin = 0
zmax = 5e3
nz = 20
nx = 20
ng = 1
g = Th2D.FDgrid(nx, nz, ng)
h = Th2D.FDgrid(nx, nz, ng)

# chemistry
k_ad, k_de, Q = Th2D.k_sorp('Pa', xmin, xmax, zmin, zmax, nx, nz)

# velocity
u, flowfig = Th2D.u_complex(g, h, xmin, xmax, zmin, zmax, nx, nz, 'Pa')

# Th loop
g, h = Th2D.adflow(g, h, t, T, V, u, nz, nx, k_ad, k_de, Q)

#plot results
meshTh = Th2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')

# store results
DPa2vel = {}
PPa2vel = {}
DPa2vel['1tmax'] = g.a
PPa2vel['1tmax'] = h.a

# %%
t = tmax[1]
T = tmax[2]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, V, u, nz, nx, k_ad, k_de, Q)

#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')

# store results
DPa2vel['2tmax'] = g.a
PPa2vel['2tmax'] = h.a

# %%
t = tmax[2]
T = tmax[3]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, V, u, nz, nx, k_ad, k_de, Q)

#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')

# store results
DPa2vel['3tmax'] = g.a
PPa2vel['3tmax'] = h.a

# %%
t = tmax[3]
T = tmax[4]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, V, u, nz, nx, k_ad, k_de, Q)

#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')

# store results
DPa2vel['5tmax'] = g.a
PPa2vel['5tmax'] = h.a

# %%
t = tmax[4]
T = tmax[5]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, V, u, nz, nx, k_ad, k_de, Q)

#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')

# store results
DPa2vel['10tmax'] = g.a
PPa2vel['10tmax'] = h.a
