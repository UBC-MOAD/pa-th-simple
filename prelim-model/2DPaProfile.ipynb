# %% [markdown]
# Solves the [Pa] on a 2D 1e6m x 5e3m grid using an upwind advection scheme, and contains plots of [Pa] profile for a zero velocity field, a single cell velocity field, and a two cell velocity field.

# %%
from __future__ import division
import numpy as np
import pylab as plb
import math
import copy
import matplotlib.pyplot as plt
from math import pi
import ThPa2D
import twoflow
import twoplot
import profile_plots as pp
# %matplotlib inline

# %% [markdown]
# # [Pa] for Zero Velocity Field

# %%
# setup function adflow for Th 
reload(ThPa2D)
reload(twoplot)
reload(twoflow)
tmax = (0, 1, 2, 3, 5, 10, 20, 60, 100)
t = tmax[0]
T = tmax[1]
V = 0.02/1000*365.*86400.
xmin = 0
xmax = 1e6
zmin = 0
zmax = 5e3
nz = 20
nx = 30
ng = 1
dt = 0.1
g = ThPa2D.Fgrid(nx, nz, ng, dt)
h = ThPa2D.Fgrid(nx, nz, ng, dt)
# chemistry
k_ad, k_de, Q = ThPa2D.k_sorp2('Pa', zmin, zmax, nx, nz)
# velocity
u = twoflow.zero(nz, nx)
# initial profile
init = twoplot.init(g.a, h.a, u, xmin, xmax, zmin, zmax, nx, nz, 'Pa')
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upstream)
#plot results
meshTh = twoplot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa0vel = {}
PPa0vel = {}
DPa0vel['1tmax'] = copy.copy(g.a)
PPa0vel['1tmax'] = copy.copy(h.a)
print "Errors produced are because field is constant or Zero"
# Out:
# Errors produced are because field is constant or Zero

# %%
plt.plot (DPa0vel['1tmax'][:,2],'b*-',DPa0vel['1tmax'][:,18],'r*-')

# %%
plt.plot (PPa0vel['1tmax'][:,2],'b*-',PPa0vel['1tmax'][:,18],'r*-')

# %%
t = tmax[1]
T = tmax[2]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upstream)
#plot results
meshTh = twoplot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa0vel['2tmax'] = copy.copy(g.a)
PPa0vel['2tmax'] = copy.copy(h.a)

# %%
t = tmax[2]
T = tmax[3]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upstream)
#plot results
meshTh = twoplot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa0vel['3tmax'] = copy.copy(g.a)
PPa0vel['3tmax'] = copy.copy(h.a)

# %%
t = tmax[3]
T = tmax[4]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upstream)
#plot results
meshTh = twoplot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa0vel['5tmax'] = copy.copy(g.a)
PPa0vel['5tmax'] = copy.copy(h.a)

# %%
t = tmax[4]
T = tmax[5]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upstream)
#plot results
meshTh = twoplot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa0vel['10tmax'] = copy.copy(g.a)
PPa0vel['10tmax'] = copy.copy(h.a)

# %%
t = tmax[5]
T = tmax[6]
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upstream)
#plot results
meshTh = twoplot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa0vel['20tmax'] = copy.copy(g.a)
PPa0vel['20tmax'] = copy.copy(h.a)

# %%
t = tmax[6]
T = tmax[7]
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upstream)
#plot results
meshTh = twoplot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa0vel['60tmax'] = copy.copy(g.a)
PPa0vel['60tmax'] = copy.copy(h.a)

# %%
plt.plot (DPa0vel['60tmax'][:,2],'b*-',DPa0vel['60tmax'][:,18],'r*-')

# %%
t = tmax[7]
T = tmax[8]
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upstream)
#plot results
meshTh = twoplot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa0vel['100tmax'] = copy.copy(g.a)
PPa0vel['100tmax'] = copy.copy(h.a)

# %% [markdown]
# Although [Th] reaches steady state after 100 years, [Pa] takes ~10 times as long because:
#
# 1.) Q
#
# 2.) k_ad
#
# 3.) k_de
#
# are an order of magnitude smaller for Pa.

# %% [markdown]
# # [Pa] according to upstream advection scheme, corrected single cell velocity

# %%
# define initial condition as 0-vel steady state
#g.a = copy.copy(DPa0vel['100tmax'])
#h.a = copy.copy(PPa0vel['100tmax'])
g = ThPa2D.Fgrid(nx, nz, ng, dt)
h = ThPa2D.Fgrid(nx, nz, ng, dt)
# setup function adflow for Pa 
reload(ThPa2D)
time = (0, 1, 2, 3, 5, 10, 20, 60, 100)
t = time[0]
T = time[1]
V = 0.02/1000*365.*86400.  # first number in mm/s, corrections give needed value in m/yr ~ 630
xmin = 0
xmax = 1e6
zmin = 0
zmax = 5e3
nz = 20
nx = 30
ng = 1
# chemistry
k_ad, k_de, Q = ThPa2D.k_sorp2('Pa', zmin, zmax, nx, nz)
# velocity
u = twoflow.onecell_up(xmin, xmax, zmin, zmax, nx, nz, V)
# let initial profile be the 0-vel steady state
init, flowfig = twoplot.init(g.a, h.a, u, xmin, xmax, zmin, zmax, nx, nz, 'Pa')
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upstream)
#plot results
meshTh = twoplot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa1vel = {}
PPa1vel = {}
DPa1vel['1tmax'] = copy.copy(g.a)
PPa1vel['1tmax'] = copy.copy(h.a)

# %%
fig, axs = plt.subplots(1,2,figsize=(10,5))
axs[0].plot(DPa1vel['1tmax'][4],'b*-',DPa1vel['1tmax'][16],'r*-')
axs[1].plot(PPa1vel['1tmax'][4],'b*-',PPa1vel['1tmax'][16],'r*-')

# %%
pp.plot_profiles(zmin,zmax,nz,nx,DPa1vel['1tmax'])
print "Maximum vertical Velocity", u[:,:,0].max()*V/365/86400.*1000.*zmax/xmax, "mm/s"
print "Maximum horizontal Velocity", u[:,:,1].max()*V/365/86400.*1000., "mm/s"
print "Maximum vertical Velocity", u[:,:,0].max()*V*zmax/xmax, "m/yr"
# Out:
# Maximum vertical Velocity 0.0 mm/s
# Maximum horizontal Velocity 0.730577131551 mm/s
# Maximum vertical Velocity 0.0 m/yr

# %%
t = time[1]
T = time[2]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upstream)
#plot results
meshTh = twoplot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa1vel['2tmax'] = copy.copy(g.a)
PPa1vel['2tmax'] = copy.copy(h.a)

# %%
pp.plot_profiles(zmin,zmax,nz,nx,DPa1vel['2tmax'])
print T*10,' years: Dissolved Concentrations'
# Out:
# 20  years: Dissolved Concentrations

# %%
t = time[2]
T = time[3]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upstream)
#plot results
meshTh = twoplot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa1vel['3tmax'] = copy.copy(g.a)
PPa1vel['3tmax'] = copy.copy(h.a)

# %%
fig, axs = plt.subplots(1,2,figsize=(10,5))
axs[0].plot(DPa1vel['3tmax'][4],'b*-',DPa1vel['3tmax'][16],'r*-')
axs[1].plot(PPa1vel['3tmax'][4],'b*-',PPa1vel['3tmax'][16],'r*-')

# %%
pp.plot_profiles(zmin,zmax,nz,nx,DPa1vel['3tmax'])
print T*10,' years: Dissolved Concentrations'
# Out:
# 30  years: Dissolved Concentrations

# %%
pp.plot_profiles(zmin,zmax,nz,nx,PPa1vel['3tmax'])
print T*10,' years: Particulate Concentrations'
# Out:
# 30  years: Particulate Concentrations

# %%
t = time[3]
T = time[4]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upstream)
#plot results
meshTh = twoplot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa1vel['5tmax'] = copy.copy(g.a)
PPa1vel['5tmax'] = copy.copy(h.a)

# %%
pp.plot_profiles(zmin,zmax,nz,nx,DPa1vel['5tmax'])
print T*10,' years: Dissolved Concentrations'
# Out:
# 50  years: Dissolved Concentrations

# %%
t = time[4]
T = time[5]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upstream)
#plot results
meshTh = twoplot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa1vel['10tmax'] = copy.copy(g.a)
PPa1vel['10tmax'] = copy.copy(h.a)

# %%
pp.plot_profiles(zmin,zmax,nz,nx,DPa1vel['10tmax'])
print T*10,' years: Dissolved Concentrations'
# Out:
# 100  years: Dissolved Concentrations

# %%
t = time[5]
T = time[6]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upstream)
#plot results
meshTh = twoplot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa1vel['20tmax'] = copy.copy(g.a)
PPa1vel['20tmax'] = copy.copy(h.a)

# %%
t = time[6]
T = time[7]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upstream)
#plot results
meshTh = twoplot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa1vel['60tmax'] = copy.copy(g.a)
PPa1vel['60tmax'] = copy.copy(h.a)

# %%
t = time[7]
T = time[8]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upstream)
#plot results
meshTh = twoplot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa1vel['100tmax'] = copy.copy(g.a)
PPa1vel['100tmax'] = copy.copy(h.a)

# %%
fig, axs = plt.subplots(1,2,figsize=(10,5))
axs[0].plot(DPa1vel['100tmax'][4],'b*-',DPa1vel['100tmax'][16],'r*-')
axs[1].plot(PPa1vel['100tmax'][4],'b*-',PPa1vel['100tmax'][16],'r*-')

# %% [markdown]
# The result at 100 years shows that the bottom left corner is unstable. Since the velocity field being used is essentially divergenceless (largest terms order 1e-10), this demonstrates an issue in the upstream advection scheme.
#
# This code has been run with the corrected uz -> ux in the upstream function.

# %% [markdown]
# # [Pa] in single cell velocity field, flux based advection

# %%
# define initial condition as 0-vel steady state
g.a = copy.copy(DPa0vel['100tmax'])
h.a = copy.copy(PPa0vel['100tmax'])
# setup function adflow for Pa 
reload(ThPa2D)
reload(twoflow)
reload(twoplot)
time = (0, 1, 2, 3, 5, 10, 20, 60, 100)
t = time[0]
T = time[1]
V = 0.02/1000*365.*86400.  # first number in mm/s, corrections give needed value in m/yr ~ 630
xmin = 0
xmax = 1e6
zmin = 0
zmax = 5e3
nz = 20
nx = 30
ng = 1
# chemistry
k_ad, k_de, Q = ThPa2D.k_sorp2('Pa', zmin, zmax, nx, nz)
# velocity
u = twoflow.onecell_up(xmin, xmax, zmin, zmax, nx, nz, V)
# let initial profile be the 0-vel steady state
init, flowfig = twoplot.init(g.a, h.a, u, xmin, xmax, zmin, zmax, nx, nz, 'Pa')
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.flux)
#plot results
meshTh = twoplot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa1vel = {}
PPa1vel = {}
DPa1vel['1tmax'] = copy.copy(g.a)
PPa1vel['1tmax'] = copy.copy(h.a)

# %%
fig, axs = plt.subplots(1,2,figsize=(10,5))
axs[0].plot(DPa1vel['1tmax'][4],'b*-',DPa1vel['1tmax'][16],'r*-')
axs[1].plot(PPa1vel['1tmax'][4],'b*-',PPa1vel['1tmax'][16],'r*-')

# %%
t = time[1]
T = time[2]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.flux)
#plot results
meshTh = twoplot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa1vel['2tmax'] = copy.copy(g.a)
PPa1vel['2tmax'] = copy.copy(h.a)

# %%
t = time[2]
T = time[3]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.flux)
#plot results
meshTh = twoplot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa1vel['3tmax'] = copy.copy(g.a)
PPa1vel['3tmax'] = copy.copy(h.a)

# %%
t = time[3]
T = time[4]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.flux)
#plot results
meshTh = twoplot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa1vel['5tmax'] = copy.copy(g.a)
PPa1vel['5tmax'] = copy.copy(h.a)

# %%
t = time[4]
T = time[5]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.flux)
#plot results
meshTh = twoplot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa1vel['10tmax'] = copy.copy(g.a)
PPa1vel['10tmax'] = copy.copy(h.a)

# %%
t = time[5]
T = time[6]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.flux)
#plot results
meshTh = twoplot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa1vel['20tmax'] = copy.copy(g.a)
PPa1vel['20tmax'] = copy.copy(h.a)

# %%
t = time[6]
T = time[7]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.flux)
#plot results
meshTh = twoplot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa1vel['60tmax'] = copy.copy(g.a)
PPa1vel['60tmax'] = copy.copy(h.a)

# %%
t = time[7]
T = time[8]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.flux)
#plot results
meshTh = twoplot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa1vel['100tmax'] = copy.copy(g.a)
PPa1vel['100tmax'] = copy.copy(h.a)

# %% [markdown]
# # [Pa] for Corrected Two Cell Velocity Scheme, upstream advection

# %%
# set initial profile to 0-vel steady state
g.a = copy.copy(DPa0vel['100tmax'])
h.a = copy.copy(PPa0vel['100tmax'])
# setup function adflow for Th 
reload(ThPa2D)
tmax = (0, 1, 2, 3, 5, 10, 20, 60, 100)
t = tmax[0]
T = tmax[1]
V = 0.02/1000*365.*86400.  # first number in mm/s, corrections give needed value in m/yr ~ 630
xmin = 0
xmax = 1e6
zmin = 0
zmax = 5e3
nz = 20
nx = 30
ng = 1
# chemistry
k_ad, k_de, Q = ThPa2D.k_sorp2('Pa', zmin, zmax, nx, nz)
# velocity
u = twoflow.twocell_up(xmin, xmax, zmin, zmax, nx, nz, V)
# initial conditions
init, flowfig = twoplot.init(g.a, h.a, u, xmin, xmax, zmin, zmax, nx, nz, 'Pa')
# advection 
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upstream)
#plot results
meshTh = twoplot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa2vel = {}
PPa2vel = {}
DPa2vel['1tmax'] = copy.copy(g.a)
PPa2vel['1tmax'] = copy.copy(h.a)

# %%
t = tmax[1]
T = tmax[2]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upstream)
#plot results
meshTh = twoplot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa2vel['2tmax'] = copy.copy(g.a)
PPa2vel['2tmax'] = copy.copy(h.a)

# %%
g.a = copy.copy(DPa2vel['2tmax'])
h.a = copy.copy(PPa2vel['2tmax'])
t = tmax[2]
T = tmax[3]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upstream)
#plot results
meshTh = twoplot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa2vel['3tmax'] = copy.copy(g.a)
PPa2vel['3tmax'] = copy.copy(h.a)

# %%
t = tmax[3]
T = tmax[4]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upstream)
#plot results
meshTh = twoplot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa2vel['5tmax'] = copy.copy(g.a)
PPa2vel['5tmax'] = copy.copy(h.a)

# %%
t = tmax[4]
T = tmax[5]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upstream)
#plot results
meshTh = twoplot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa2vel['10tmax'] = copy.copy(g.a)
PPa2vel['10tmax'] = copy.copy(h.a)

# %%
t = tmax[5]
T = tmax[6]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upstream)
#plot results
meshTh = twoplot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa2vel['20tmax'] = copy.copy(g.a)
PPa2vel['20tmax'] = copy.copy(h.a)

# %%
t = tmax[6]
T = tmax[7]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upstream)
#plot results
meshTh = twoplot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa2vel['60tmax'] = copy.copy(g.a)
PPa2vel['60tmax'] = copy.copy(h.a)

# %%
t = tmax[7]
T = tmax[8]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upstream)
#plot results
meshTh = twoplot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa2vel['100tmax'] = copy.copy(g.a)
PPa2vel['100tmax'] = copy.copy(h.a)

# %% [markdown]
# Profiles show that the concentration in a water column is inversely proportional to downwelling. This is a result of upwelling currents effectively reducing the sinking velocity, leading to regions in which the Pa is suspended, or sinking very slowly.
#
# The dissolved and particulate phases appear to be identical except for a scaling factor.

# %% [markdown]
# The solutions at 600 and 1000yrs demonstrate an instability in the code.

# %% [markdown]
# # [Pa] according to flux based advection scheme with 2-cell velocity field

# %%
# set initial profile to 0-vel steady state
g.a = copy.copy(DPa0vel['100tmax'])
h.a = copy.copy(PPa0vel['100tmax'])
# setup function adflow for Th 
reload(ThPa2D)
tmax = (0, 1, 2, 3, 5, 10, 20, 60, 100)
t = tmax[0]
T = tmax[1]
V = 0.02/1000*365.*86400.  # first number in mm/s, corrections give needed value in m/yr ~ 630
xmin = 0
xmax = 1e6
zmin = 0
zmax = 5e3
nz = 20
nx = 30
ng = 1
# chemistry
k_ad, k_de, Q = ThPa2D.k_sorp2('Pa', zmin, zmax, nx, nz)
# velocity
u = twoflow.twocell_up(xmin, xmax, zmin, zmax, nx, nz, V)
# initial conditions
init, flowfig = twoplot.init(g.a, h.a, u, xmin, xmax, zmin, zmax, nx, nz, 'Pa')
# advection 
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.flux)
#plot results
meshTh = twoplot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa2vel = {}
PPa2vel = {}
DPa2vel['1tmax'] = copy.copy(g.a)
PPa2vel['1tmax'] = copy.copy(h.a)

# %%
t = tmax[1]
T = tmax[2]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.flux)
#plot results
meshTh = twoplot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa2vel['2tmax'] = copy.copy(g.a)
PPa2vel['2tmax'] = copy.copy(h.a)

# %%
t = tmax[2]
T = tmax[3]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.flux)
#plot results
meshTh = twoplot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa2vel['3tmax'] = copy.copy(g.a)
PPa2vel['3tmax'] = copy.copy(h.a)

# %%
t = tmax[3]
T = tmax[4]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.flux)
#plot results
meshTh = twoplot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa2vel['5tmax'] = copy.copy(g.a)
PPa2vel['5tmax'] = copy.copy(h.a)

# %%
t = tmax[4]
T = tmax[5]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.flux)
#plot results
meshTh = twoplot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa2vel['10tmax'] = copy.copy(g.a)
PPa2vel['10tmax'] = copy.copy(h.a)

# %%
t = tmax[5]
T = tmax[6]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.flux)
#plot results
meshTh = twoplot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa2vel['20tmax'] = copy.copy(g.a)
PPa2vel['20tmax'] = copy.copy(h.a)

# %%
t = tmax[6]
T = tmax[7]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.flux)
#plot results
meshTh = twoplot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa2vel['60tmax'] = copy.copy(g.a)
PPa2vel['60tmax'] = copy.copy(h.a)

# %%
t = tmax[7]
T = tmax[8]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.flux)
#plot results
meshTh = twoplot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa2vel['100tmax'] = copy.copy(g.a)
PPa2vel['100tmax'] = copy.copy(h.a)

# %% [markdown]
# The system appears to reach steady state after 600 yrs.
