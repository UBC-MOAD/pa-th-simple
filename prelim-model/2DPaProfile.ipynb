# %% [markdown]
# Solves the [Pa] on a 2D 1e6m x 5e3m grid using an upwind advection scheme, and contains plots of [Pa] profile for a zero velocity field, a single cell velocity field, and a two cell velocity field.

# %%
from __future__ import division
import numpy
import pylab
import math
import matplotlib.pyplot as plt
from math import pi
import ThPa2D
import profile_plots as pp
# %matplotlib inline

# %% [markdown]
# # [Pa] for Zero Velocity Field

# %%
reload(ThPa2D)
# Out:
# <module 'ThPa2D' from 'ThPa2D.pyc'>

# %%
# setup function adflow for Th 

tmax = (0, 1, 2, 3, 5, 10)
t = tmax[0]
T = tmax[1]
V = 1
xmin = 1
xmax = 1e6
zmin = 0
zmax = 5e3
nz = 20
nx = 20
ng = 1
g = ThPa2D.FDgrid(nx, nz, ng)
h = ThPa2D.FDgrid(nx, nz, ng)

# chemistry
k_ad, k_de, Q = ThPa2D.k_sorp('Pa', xmin, xmax, zmin, zmax, nx, nz)

# velocity
u, flowfig, init = ThPa2D.u_zero(g, h, xmin, xmax, zmin, zmax, nx, nz, V, 'Pa')

# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upwind)

#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')

# store results
DPa0vel = {}
PPa0vel = {}
DPa0vel['1tmax'] = g.a
PPa0vel['1tmax'] = h.a

# %%
plt.plot (DPa0vel['1tmax'][:,2],'b',DPa0vel['1tmax'][:,18],'r')
# Out:
# [<matplotlib.lines.Line2D at 0x396ec50>,
#  <matplotlib.lines.Line2D at 0x4175a10>]

# %%
t = tmax[1]
T = tmax[2]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upwind)

#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')

# store results
DPa0vel['2tmax'] = g.a
PPa0vel['2tmax'] = h.a

# %%
t = tmax[2]
T = tmax[3]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upwind)

#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')

# store results
DPa0vel['3tmax'] = g.a
PPa0vel['3tmax'] = h.a

# %%
t = tmax[3]
T = tmax[4]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, V, u, nz, nx, k_ad, k_de, Q)

#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')

# store results
DPa0vel['5tmax'] = g.a
PPa0vel['5tmax'] = h.a
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-45c35db45651> in <module>()
#       2 T = tmax[4]
#       3 # Th loop
# ----> 4 g, h = ThPa2D.adflow(g, h, t, T, V, u, nz, nx, k_ad, k_de, Q)
#       5
#       6 #plot results
#
# TypeError: adflow() takes exactly 9 arguments (11 given)

# %%
t = tmax[4]
T = tmax[5]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, V, u, nz, nx, k_ad, k_de, Q)

#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')

# store results
DPa0vel['10tmax'] = g.a
PPa0vel['10tmax'] = h.a

# %% [markdown]
# # [Pa] for Single Cell Velocity Field

# %%
reload(ThPa2D)

# %%
# setup function adflow for Th 

tmax = (0, 1, 2, 3, 5, 10)
t = tmax[0]
T = tmax[1]
V = 0.02/1000*365.*86400.  # first number in mm/s, corrections give needed value in m/yr ~ 630
xmin = 1
xmax = 1e6
zmin = 0
zmax = 5e3
nz = 20
nx = 20
ng = 1
g = ThPa2D.FDgrid(nx, nz, ng)
h = ThPa2D.FDgrid(nx, nz, ng)

# chemistry
k_ad, k_de, Q = ThPa2D.k_sorp('Pa', xmin, xmax, zmin, zmax, nx, nz)

# velocity
u, flowfig, init = ThPa2D.u_simple(g, h, xmin, xmax, zmin, zmax, nx, nz, V, 'Pa')

# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upwind)

#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')

# store results
DPa1vel = {}
PPa1vel = {}
DPa1vel['1tmax'] = g.a
PPa1vel['1tmax'] = h.a

# %% [markdown]
# Flipping the z axis changes the sign of x-velocity, but not z-velocity, because z-velocity is symmetric about this rotation, while x-velocity is not. This means if you prescribe the rotation to be in the +theta direction before zaxis flip, it will become -theta after zaxis flip, and vice versa.

# %%
pp.plot_profiles(zmin,zmax,nz,nx,DPa1vel['1tmax'])
print "Maximum vertical Velocity", u[:,:,0].max()*V/365/86400.*1000.*zmax/xmax, "mm/s"
print "Maximum horizontal Velocity", u[:,:,1].max()*V/365/86400.*1000., "mm/s"
print "Maximum vertical Velocity", u[:,:,0].max()*V*zmax/xmax, "m/yr"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-e6035de3f2e3> in <module>()
# ----> 1 pp.plot_profiles(zmin,zmax,nz,nx,DPa1vel['1tmax'])
#       2 print "Maximum vertical Velocity", u[:,:,0].max()*V/365/86400.*1000.*zmax/xmax, "mm/s"
#       3 print "Maximum horizontal Velocity", u[:,:,1].max()*V/365/86400.*1000., "mm/s"
#       4 print "Maximum vertical Velocity", u[:,:,0].max()*V*zmax/xmax, "m/yr"
#
# NameError: name 'DPa1vel' is not defined

# %%
t = tmax[1]
T = tmax[2]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upwind)

#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')

# store results
DPa1vel['2tmax'] = g.a
PPa1vel['2tmax'] = h.a
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-d10a7ee06825> in <module>()
#       2 T = tmax[2]
#       3 # Th loop
# ----> 4 g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upwind)
#       5
#       6 #plot results
#
# /home/abellas/Documents/GEOTRACES/Pa-Th/prelim-model/ThPa2D.pyc in adflow(g, h, t, T, u, k_ad, k_de, Q, adscheme)
#      87         tmax = T * (g.zmax - g.zmin)/S
#      88
# ---> 89         g, h = adscheme(g, h, t, T, u, k_ad, k_de, Q, S, dt, tmax)
#      90
#      91         return g, h
#
# /home/abellas/Documents/GEOTRACES/Pa-Th/prelim-model/ThPa2D.pyc in upwind(g, h, t, T, u, k_ad, k_de, Q, S, dt, tmax)
#     132                                 # dissolved:
#     133 				anew[i, j] = g.a[i, j] + ( Q - k_ad[i, j] * g.a[i, j] + k_de[i, j] * h.a[i, j] +
# --> 134                                             ux[i, j] * ( n_upx[i, j]*g.a[i, j - 1] - g.a[i, j] + p_upx[i, j]*g.a[i, j + 1] ) / g.dx +
#     135 					    uz[i, j] * ( n_upz[i, j]*g.a[i - 1, j] - g.a[i, j] + p_upz[i, j]*g.a[i + 1, j] ) / g.dz ) * dt
#     136
#
# KeyboardInterrupt:

# %%
pp.plot_profiles(zmin,zmax,nz,nx,DPa1vel['2tmax'])
print T*10,' years: Dissolved Concentrations'

# %%
t = tmax[2]
T = tmax[3]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upwind)

#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')

# store results
DPa1vel['3tmax'] = g.a
PPa1vel['3tmax'] = h.a

# %%
pp.plot_profiles(zmin,zmax,nz,nx,DPa1vel['3tmax'])
print T*10,' years: Dissolved Concentrations'

# %%
pp.plot_profiles(zmin,zmax,nz,nx,PPa1vel['3tmax'])
print T*10,' years: Particulate Concentrations'

# %%
t = tmax[3]
T = tmax[4]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upwind)

#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')

# store results
DPa1vel['5tmax'] = g.a
PPa1vel['5tmax'] = h.a

# %%
pp.plot_profiles(zmin,zmax,nz,nx,DPa1vel['5tmax'])
print T*10,' years: Dissolved Concentrations'

# %%
t = tmax[4]
T = tmax[5]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, V, u, nz, nx, k_ad, k_de, Q)

#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')

# store results
DPa1vel['10tmax'] = g.a
PPa1vel['10tmax'] = h.a

# %%
pp.plot_profiles(zmin,zmax,nz,nx,DPa1vel['10tmax'])
print T*10,' years: Dissolved Concentrations'

# %% [markdown]
# # [Pa] for Two Cell Velocity Scheme

# %%
reload(ThPa2D)
# Out:
# <module 'ThPa2D' from 'ThPa2D.pyc'>

# %%
# setup function adflow for Th 

tmax = (0, 1, 2, 3, 5, 10)
t = tmax[0]
T = tmax[1]
V = 0.02/1000*365.*86400.  # first number in mm/s, corrections give needed value in m/yr ~ 630
xmin = 1
xmax = 1e6
zmin = 1
zmax = 5e3
nz = 20
nx = 20
ng = 1
g = ThPa2D.FDgrid(nx, nz, ng)
h = ThPa2D.FDgrid(nx, nz, ng)

# chemistry
k_ad, k_de, Q = ThPa2D.k_sorp('Pa', xmin, xmax, zmin, zmax, nx, nz)

# velocity
u, flowfig, init = ThPa2D.u_complex(g, h, xmin, xmax, zmin, zmax, nx, nz, 'Pa')

# Th loop
g, h = ThPa2D.adflow(g, h, t, T, V, u, nz, nx, k_ad, k_de, Q)

#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')

# store results
DPa2vel = {}
PPa2vel = {}
DPa2vel['1tmax'] = g.a
PPa2vel['1tmax'] = h.a
# Out:
# ThPa2D.py:424: RuntimeWarning: divide by zero encountered in true_divide
#   theta = numpy.arctan(zz/xx)
# ThPa2D.py:424: RuntimeWarning: invalid value encountered in true_divide
#   theta = numpy.arctan(zz/xx)
# ThPa2D.py:425: RuntimeWarning: invalid value encountered in less
#   idx = rr < a*b/ ( 4*numpy.sqrt(1/4 * ((b*numpy.cos(theta))**2 + (a*numpy.sin(theta))**2)) )

# %%
pylab.pcolormesh(numpy.sign(u[:,:,0]))

# %%
t = tmax[1]
T = tmax[2]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, V, u, nz, nx, k_ad, k_de, Q)

#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')

# store results
DPa2vel['2tmax'] = g.a
PPa2vel['2tmax'] = h.a

# %%
t = tmax[2]
T = tmax[3]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, V, u, nz, nx, k_ad, k_de, Q)

#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')

# store results
DPa2vel['3tmax'] = g.a
PPa2vel['3tmax'] = h.a

# %%
t = tmax[3]
T = tmax[4]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, V, u, nz, nx, k_ad, k_de, Q)

#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')

# store results
DPa2vel['5tmax'] = g.a
PPa2vel['5tmax'] = h.a

# %%
t = tmax[4]
T = tmax[5]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, V, u, nz, nx, k_ad, k_de, Q)

#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')

# store results
DPa2vel['10tmax'] = g.a
PPa2vel['10tmax'] = h.a
