# %% [markdown]
# Solves the [Pa] on a 2D 1e6m x 5e3m grid using an upwind advection scheme, and contains plots of [Pa] profile for a zero velocity field, a single cell velocity field, and a two cell velocity field.

# %%
from __future__ import division
import numpy
import pylab
import math
import matplotlib.pyplot as plt
from math import pi
import Th2D
# %matplotlib inline

# %% [markdown]
# # [Pa] for Zero Velocity Field

# %%
# set parameters

T = 1
V = 1/100
xmin = 1
xmax = 1000000
zmin = 0
zmax = 5000
nz = 20
nx = 20

# chemistry
[k_ad, k_de, Q] = Th2D.k_sorp('Pa', xmin, xmax, zmin, zmax, nx, nz)

# velocity
[u, flowfig] = Th2D.u_zero(xmin, xmax, zmin, zmax, nx, nz)

# [Th] loop
[flowfig, meshTh, DPa, PPa] = Th2D.adflow(T, V, u, nz, nx, k_ad, k_de, Q, flowfig, 'Pa')
# Out:
# /home/abellas/anaconda/lib/python2.7/site-packages/matplotlib/colorbar.py:829: RuntimeWarning: invalid value encountered in divide
#   z = np.take(y, i0) + (xn - np.take(b, i0)) * dy / db
# /home/abellas/anaconda/lib/python2.7/site-packages/matplotlib/colorbar.py:581: RuntimeWarning: invalid value encountered in greater
#   inrange = (ticks > -0.001) & (ticks < 1.001)
# /home/abellas/anaconda/lib/python2.7/site-packages/matplotlib/colorbar.py:581: RuntimeWarning: invalid value encountered in less
#   inrange = (ticks > -0.001) & (ticks < 1.001)
# /home/abellas/anaconda/lib/python2.7/site-packages/matplotlib/quiver.py:570: RuntimeWarning: divide by zero encountered in double_scalars
#   length = a * (widthu_per_lenu / (self.scale * self.width))
# /home/abellas/anaconda/lib/python2.7/site-packages/matplotlib/quiver.py:570: RuntimeWarning: invalid value encountered in multiply
#   length = a * (widthu_per_lenu / (self.scale * self.width))
# ...

# %%
T = 2
[flowfig, meshTh, DPa, PPa] = Th2D.adflow(T, V, u, nz, nx, k_ad, k_de, Q, flowfig, 'Pa')
pylab.close(1)

# %%
T = 3
[flowfig, meshTh, DPa, PPa] = Th2D.adflow(T, V, u, nz, nx, k_ad, k_de, Q, flowfig, 'Pa')
pylab.close(1)

# %%
T = 5
[flowfig, meshTh, DPa, PPa] = Th2D.adflow(T, V, u, nz, nx, k_ad, k_de, Q, flowfig, 'Pa')
pylab.close(1)

# %%
T = 10
[flowfig, meshTh, DPa, PPa] = Th2D.adflow(T, V, u, nz, nx, k_ad, k_de, Q, flowfig, 'Pa')
pylab.close(1)

# %% [markdown]
# # [Pa] for Single Cell Velocity Field

# %%
reload(Th2D)
# Out:
# <module 'Th2D' from 'Th2D.pyc'>

# %%
# set parameters

T = 1
V = 1/10
xmin = 1
xmax = 1e6
zmin = 0
zmax = 5e3
nz = 40
nx = 20

# chemistry
[k_ad, k_de, Q] = Th2D.k_sorp('Pa', xmin, xmax, zmin, zmax, nx, nz)

# velocity
[u, flowfig] = Th2D.u_simple(xmin, xmax, zmin, zmax, nx, nz)

# [Th] loop
[flowfig, meshTh, DTh, PTh] = Th2D.adflow(T, V, u, nz, nx, k_ad, k_de, Q, flowfig, 'Pa')

# %%
T = 2
[flowfig, meshTh, DTh, PTh] = Th2D.adflow(T, V, u, nz, nx, k_ad, k_de, Q, flowfig, 'Pa')
pylab.close(1)

# %%
T = 3
[flowfig, meshTh, DTh, PTh] = Th2D.adflow(T, V, u, nz, nx, k_ad, k_de, Q, flowfig, 'Pa')
pylab.close(1)

# %%
T = 5
[flowfig, meshTh, DTh, PTh] = Th2D.adflow(T, V, u, nz, nx, k_ad, k_de, Q, flowfig, 'Pa')
pylab.close(1)

# %%
T = 10
[flowfig, meshTh, DTh, PTh] = Th2D.adflow(T, V, u, nz, nx, k_ad, k_de, Q, flowfig, 'Pa')
pylab.close(1)

# %% [markdown]
# # [Pa] for Two Cell Velocity Scheme

# %%
reload(Th2D)
# Out:
# <module 'Th2D' from 'Th2D.py'>

# %%
# setup function adflow for Th 

t = 0
T = 1
V = 1
xmin = 1
xmax = 1e6
zmin = 0
zmax = 5e3
nz = 20
nx = 20
ng = 1
g = Th2D.FDgrid(nx, nz, ng)
h = Th2D.FDgrid(nx, nz, ng)

# chemistry
k_ad, k_de, Q = Th2D.k_sorp('Pa', xmin, xmax, zmin, zmax, nx, nz)

# velocity
u, flowfig = Th2D.u_complex(g, h, xmin, xmax, zmin, zmax, nx, nz, 'Pa')

# Th loop
g, h = Th2D.adflow(g, h, t, T, V, u, nz, nx, k_ad, k_de, Q)

#plot results
meshTh = Th2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')

# store results
DPa2vel = {}
PPa2vel = {}
DPa2vel['1tmax'] = g.a
PPa2vel['1tmax'] = h.a

# %%
T = 3
[flowfig, meshTh, DTh, PTh] = Th2D.adflow(T, V, u, nz, nx, k_ad, k_de, Q, flowfig, 'Pa')
pylab.close(1)

# %%
T = 5
[flowfig, meshTh, DTh, PTh] = Th2D.adflow(T, V, u, nz, nx, k_ad, k_de, Q, flowfig, 'Pa')
pylab.close(1)

# %%
T = 10
[flowfig, meshTh, DTh, PTh] = Th2D.adflow(T, V, u, nz, nx, k_ad, k_de, Q, flowfig, 'Pa')
pylab.close(1)

# %% [markdown]
# # practise with edited adflow

# %%
reload(Th2D)
# Out:
# <module 'Th2D' from 'Th2D.py'>

# %%
# setup function adflow for Th 

t = 0
T = 1
V = 1
xmin = 1
xmax = 1e6
zmin = 0
zmax = 5e3
nz = 20
nx = 20
ng = 1
g = Th2D.FDgrid(nx, nz, ng)
h = Th2D.FDgrid(nx, nz, ng)

# chemistry
k_ad, k_de, Q = Th2D.k_sorp('Th', xmin, xmax, zmin, zmax, nx, nz)

# velocity
u, flowfig = Th2D.u_simple(g, h, xmin, xmax, zmin, zmax, nx, nz, 'Th')

# Th loop
g, h = Th2D.adflow(g, h, t, T, V, u, nz, nx, k_ad, k_de, Q)

#plot results
meshTh = Th2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Th')

# store results
DTh1vel = {}
PTh1vel = {}
DTh1vel['1tmax'] = g.a
PTh1vel['1tmax'] = h.a

# %%
t = T
T = 2
# Th loop
g, h = Th2D.adflow(g, h, t, T, V, u, nz, nx, k_ad, k_de, Q)

#plot results
meshTh = Th2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Th')

# store results
DTh1vel['2tmax'] = g.a
PTh1vel['2tmax'] = h.a

# %%
t = T
T = 3
# Th loop
g, h = Th2D.adflow(g, h, t, T, V, u, nz, nx, k_ad, k_de, Q)

#plot results
meshTh = Th2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Th')

# store results
DTh1vel['3tmax'] = g.a
PTh1vel['3tmax'] = h.a

# %%
t = T
T = 5
# Th loop
g, h = Th2D.adflow(g, h, t, T, V, u, nz, nx, k_ad, k_de, Q)

#plot results
meshTh = Th2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Th')

# store results
DTh1vel['5tmax'] = g.a
PTh1vel['5tmax'] = h.a

# %%
t = T
T = 10
# Th loop
g, h = Th2D.adflow(g, h, t, T, V, u, nz, nx, k_ad, k_de, Q)

#plot results
meshTh = Th2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Th')

# store results
DTh1vel['10tmax'] = g.a
PTh1vel['10tmax'] = h.a
