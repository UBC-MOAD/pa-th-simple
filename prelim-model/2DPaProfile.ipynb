# %% [markdown]
# Solves the [Pa] on a 2D 1e6m x 5e3m grid using an upwind advection scheme, and contains plots of [Pa] profile for a zero velocity field, a single cell velocity field, and a two cell velocity field.

# %%
from __future__ import division
import numpy
import pylab
import math
import matplotlib.pyplot as plt
from math import pi
import ThPa2D
import profile_plots as pp
# %matplotlib inline

# %% [markdown]
# # [Pa] for Zero Velocity Field

# %%
reload(ThPa2D)
# setup function adflow for Th 

tmax = (0, 1, 2, 3, 5, 10)
t = tmax[0]
T = tmax[1]
V = 1
xmin = 1
xmax = 1e6
zmin = 0
zmax = 5e3
nz = 20
nx = 29
ng = 1
g = ThPa2D.FDgrid(nx, nz, ng)
h = ThPa2D.FDgrid(nx, nz, ng)

# chemistry
k_ad, k_de, Q = ThPa2D.k_sorp('Pa', xmin, xmax, zmin, zmax, nx, nz)

# initial profile
init = ThPa2D.plot_init(g, h, xmin, xmax, zmin, zmax, nx, nz, 'Pa')

# velocity
u, flowfig = ThPa2D.u_zero(xmin, xmax, zmin, zmax, nx, nz, V)

# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upwind)

#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')

# store results
DPa0vel = {}
PPa0vel = {}
DPa0vel['1tmax'] = g.a
PPa0vel['1tmax'] = h.a

# %%
plt.plot (DPa0vel['1tmax'][:,2],'b',DPa0vel['1tmax'][:,18],'r')
# Out:
# [<matplotlib.lines.Line2D at 0x624c390>,
#  <matplotlib.lines.Line2D at 0x624cf50>]

# %%
t = tmax[1]
T = tmax[2]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upwind)

#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')

# store results
DPa0vel['2tmax'] = g.a
PPa0vel['2tmax'] = h.a

# %%
t = tmax[2]
T = tmax[3]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upwind)

#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')

# store results
DPa0vel['3tmax'] = g.a
PPa0vel['3tmax'] = h.a

# %%
t = tmax[3]
T = tmax[4]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upwind)

#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')

# store results
DPa0vel['5tmax'] = g.a
PPa0vel['5tmax'] = h.a

# %%
t = tmax[4]
T = tmax[5]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upwind)

#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')

# store results
DPa0vel['10tmax'] = g.a
PPa0vel['10tmax'] = h.a

# %%
tmax = (0, 1, 2, 3, 5, 10, 20)
t = tmax[5]
T = tmax[6]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upwind)

#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')

# store results
DPa0vel['20tmax'] = g.a
PPa0vel['20tmax'] = h.a

# %%
tmax = (0, 1, 2, 3, 5, 10, 20, 30, 60)
t = tmax[6]
T = tmax[7]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upwind)

#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')

# store results
DPa0vel['20tmax'] = g.a
PPa0vel['20tmax'] = h.a

# %%
t = tmax[7]
T = tmax[8]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upwind)

#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')

# store results
DPa0vel['20tmax'] = g.a
PPa0vel['20tmax'] = h.a

# %% [markdown]
# Since the maximum [Pa] continues to change into the 600 year time interval, this system has not yet reached equilibrium. This is perplexing because [Th] reaches steady state after 100 years, and the only difference between the two are:
# 1.) Q
# 2.) k_ad
# 3.) k_de
#
# All three Pa constants are an order of magnitude < Th constants. Why would this lead to a longer interval to reach steady state?

# %% [markdown]
# # [Pa] for Corrected Single Cell Velocity Field (absolute mass conservation)

# %%
# setup function adflow for Pa 
reload(ThPa2D)

time = (0, 1, 2, 3, 5, 10, 20, 30)
t = time[0]
T = time[1]
V = 0.02/1000*365.*86400.  # first number in mm/s, corrections give needed value in m/yr ~ 630
xmin = 0
xmax = 1e6
zmin = 0
zmax = 5e3
nz = 20
nx = 29
ng = 1
g = ThPa2D.FDgrid(nx, nz, ng)
h = ThPa2D.FDgrid(nx, nz, ng)

# chemistry
k_ad, k_de, Q = ThPa2D.k_sorp('Pa', xmin, xmax, zmin, zmax, nx, nz)

# initial profile
init = ThPa2D.plot_init(g, h, xmin, xmax, zmin, zmax, nx, nz, 'Pa')

# velocity
u, flowfig = ThPa2D.u_simple(xmin, xmax, zmin, zmax, nx, nz, V)
u, flowfig = ThPa2D.u_simple_c(u, xmin, xmax, zmin, zmax, nx, nz)


# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upwind)

#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')

# store results
DPa1vel = {}
PPa1vel = {}
DPa1vel['1tmax'] = g.a
PPa1vel['1tmax'] = h.a

# %%
pp.plot_profiles(zmin,zmax,nz,nx,DPa1vel['1tmax'])
print "Maximum vertical Velocity", u[:,:,0].max()*V/365/86400.*1000.*zmax/xmax, "mm/s"
print "Maximum horizontal Velocity", u[:,:,1].max()*V/365/86400.*1000., "mm/s"
print "Maximum vertical Velocity", u[:,:,0].max()*V*zmax/xmax, "m/yr"
# Out:
# Maximum vertical Velocity 0.00031536 mm/s
# Maximum horizontal Velocity 12.0645786184 mm/s
# Maximum vertical Velocity 9.94519296 m/yr

# %%
t = time[1]
T = time[2]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upwind)

#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')

# store results
DPa1vel['2tmax'] = g.a
PPa1vel['2tmax'] = h.a

# %%
pp.plot_profiles(zmin,zmax,nz,nx,DPa1vel['2tmax'])
print T*10,' years: Dissolved Concentrations'
# Out:
# 20  years: Dissolved Concentrations

# %%
t = time[2]
T = time[3]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upwind)

#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')

# store results
DPa1vel['3tmax'] = g.a
PPa1vel['3tmax'] = h.a

# %%
pp.plot_profiles(zmin,zmax,nz,nx,DPa1vel['3tmax'])
print T*10,' years: Dissolved Concentrations'
# Out:
# 30  years: Dissolved Concentrations

# %%
pp.plot_profiles(zmin,zmax,nz,nx,PPa1vel['3tmax'])
print T*10,' years: Particulate Concentrations'
# Out:
# 30  years: Particulate Concentrations

# %%
t = time[3]
T = time[4]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upwind)

#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')

# store results
DPa1vel['5tmax'] = g.a
PPa1vel['5tmax'] = h.a

# %%
pp.plot_profiles(zmin,zmax,nz,nx,DPa1vel['5tmax'])
print T*10,' years: Dissolved Concentrations'
# Out:
# 50  years: Dissolved Concentrations

# %%
t = time[4]
T = time[5]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upwind)

#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')

# store results
DPa1vel['10tmax'] = g.a
PPa1vel['10tmax'] = h.a

# %%
pp.plot_profiles(zmin,zmax,nz,nx,DPa1vel['10tmax'])
print T*10,' years: Dissolved Concentrations'
# Out:
# 100  years: Dissolved Concentrations

# %%
t = time[5]
T = time[6]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upwind)

#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')

# store results
DPa1vel['20tmax'] = g.a
PPa1vel['20tmax'] = h.a

# %% [markdown]
# The maximum [Pa] increases from 0.225 at 100 yrs to 0.45 at 200 yrs. It seems that Pa does not reach a steady state before blowing up. The profile is computed using the same code as Th, which does converge to a steady state.

# %%
time = (0, 1, 2, 3, 5, 10, 20, 30, 100)
t = time[6]
T = time[7]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upwind)

#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')

# store results
DPa1vel['30tmax'] = g.a
PPa1vel['30tmax'] = h.a

# %% [markdown]
# ### Run Single Cell for large time to check stability

# %%
t = time[7]
T = time[8]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upwind)

#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')

# store results
DPa1vel['100tmax'] = g.a
PPa1vel['100tmax'] = h.a

# %% [markdown]
# # [Pa] for Corrected Two Cell Velocity Scheme

# %%
# setup function adflow for Th 
reload(ThPa2D)
tmax = (0, 1, 2, 3, 5, 10, 20, 30)
t = tmax[0]
T = tmax[1]
V = 0.02/1000*365.*86400.  # first number in mm/s, corrections give needed value in m/yr ~ 630
xmin = 0
xmax = 1e6
zmin = 0
zmax = 5e3
nz = 20
nx = 29
ng = 1
g = ThPa2D.FDgrid(nx, nz, ng)
h = ThPa2D.FDgrid(nx, nz, ng)

# chemistry
k_ad, k_de, Q = ThPa2D.k_sorp('Pa', xmin, xmax, zmin, zmax, nx, nz)

# initial profile
init = ThPa2D.plot_init(g, h, xmin, xmax, zmin, zmax, nx, nz, 'Pa')

# velocity
u, flowfig = ThPa2D.u_complex(xmin, xmax, zmin, zmax, nx, nz, V)
u, flowfig = ThPa2D.u_complex_c(u, xmin, xmax, zmin, zmax, nx, nz)
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upwind)

#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')

# store results
DPa2vel = {}
PPa2vel = {}
DPa2vel['1tmax'] = g.a
PPa2vel['1tmax'] = h.a

# %%
t = tmax[1]
T = tmax[2]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upwind)

#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')

# store results
DPa2vel['2tmax'] = g.a
PPa2vel['2tmax'] = h.a

# %%
t = tmax[2]
T = tmax[3]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upwind)

#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')

# store results
DPa2vel['3tmax'] = g.a
PPa2vel['3tmax'] = h.a

# %%
t = tmax[3]
T = tmax[4]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upwind)

#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')

# store results
DPa2vel['5tmax'] = g.a
PPa2vel['5tmax'] = h.a

# %%
t = tmax[4]
T = tmax[5]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upwind)

#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')

# store results
DPa2vel['10tmax'] = g.a
PPa2vel['10tmax'] = h.a

# %%
tmax = (0, 1, 2, 3, 5, 10, 15)
t = tmax[5]
T = tmax[6]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upwind)

#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')

# store results
DPa2vel['15tmax'] = g.a
PPa2vel['15tmax'] = h.a

# %% [markdown]
# The solution is symmetric from 500km outward until the 650 : 350 mirror. Beyond that point, the solution are quite different. Check BCs.

# %%
tmax = (0, 1, 2, 3, 5, 10, 15, 20)
t = tmax[6]
T = tmax[7]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upwind)

#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')

# store results
DPa2vel['20tmax'] = g.a
PPa2vel['20tmax'] = h.a

# %%
tmax = (0, 1, 2, 3, 5, 10, 15, 20, 30)
t = tmax[7]
T = tmax[8]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upwind)

#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')

# store results
DPa2vel['30tmax'] = g.a
PPa2vel['30tmax'] = h.a

# %% [markdown]
# Profiles show that the concentration in a water column is inversely proportional to downwelling. This is a result of upwelling currents effectively reducing the sinking velocity, leading to regions in which the Pa is suspended, or sinking very slowly.
#
# The dissolved and particulate phases appear to be identical except for a scaling factor.
#
# Unfortunately, the solution does not reach a steady state before blowing up. 300 yrs is the last meaningful solution.

# %%
tmax = (0, 1, 2, 3, 5, 10, 15, 20, 30, 60)
t = tmax[8]
T = tmax[9]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upwind)

#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')

# store results
DPa2vel['60tmax'] = g.a
PPa2vel['60tmax'] = h.a

# %%
tmax = (0, 1, 2, 3, 5, 10, 15, 20, 30, 60, 100)
t = tmax[9]
T = tmax[10]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upwind)

#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')

# store results
DPa2vel['100tmax'] = g.a
PPa2vel['100tmax'] = h.a

# %% [markdown]
# The solutions at 600 and 1000yrs demonstrate an instability in the code.
