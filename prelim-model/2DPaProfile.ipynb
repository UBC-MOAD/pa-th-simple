# %% [markdown]
# Solves the [Pa] on a 2D 1e6m x 5e3m grid using an upwind advection scheme, and contains plots of [Pa] profile for a zero velocity field, a single cell velocity field, and a two cell velocity field.

# %%
from __future__ import division
import numpy as np
import pylab as plb
import math
import copy
import matplotlib.pyplot as plt
from math import pi
import ThPa2D
import profile_plots as pp
# %matplotlib inline

# %% [markdown]
# # [Pa] for Zero Velocity Field

# %%
# setup function adflow for Th 
reload(ThPa2D)
tmax = (0, 1, 2, 3, 5, 10, 20, 60, 100)
t = tmax[0]
T = tmax[1]
V = 1
xmin = 0
xmax = 1e6
zmin = 0
zmax = 5e3
nz = 20
nx = 30
ng = 1
g = ThPa2D.FDgrid(nx, nz, ng)
h = ThPa2D.FPgrid(nx, nz, ng)
# chemistry
k_ad, k_de, Q = ThPa2D.k_sorp('Pa', xmin, xmax, zmin, zmax, nx, nz)
# velocity
u = ThPa2D.u_zero(nz, nx)
# initial profile
init = ThPa2D.plot_init(g, h, u, xmin, xmax, zmin, zmax, nx, nz, 'Pa')
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upstream)
#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa0vel = {}
PPa0vel = {}
DPa0vel['1tmax'] = copy.copy(g.a)
PPa0vel['1tmax'] = copy.copy(h.a)

# %%
plt.plot (DPa0vel['1tmax'][:,2],'b',DPa0vel['1tmax'][:,18],'r')
# Out:
# [<matplotlib.lines.Line2D at 0x4a28890>,
#  <matplotlib.lines.Line2D at 0x4a28b10>]

# %%
t = tmax[1]
T = tmax[2]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upstream)
#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa0vel['2tmax'] = copy.copy(g.a)
PPa0vel['2tmax'] = copy.copy(h.a)

# %%
t = tmax[2]
T = tmax[3]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upstream)
#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa0vel['3tmax'] = copy.copy(g.a)
PPa0vel['3tmax'] = copy.copy(h.a)

# %%
t = tmax[3]
T = tmax[4]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upstream)
#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa0vel['5tmax'] = copy.copy(g.a)
PPa0vel['5tmax'] = copy.copy(h.a)

# %%
t = tmax[4]
T = tmax[5]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upstream)
#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa0vel['10tmax'] = copy.copy(g.a)
PPa0vel['10tmax'] = copy.copy(h.a)

# %%
t = tmax[5]
T = tmax[6]
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upstream)
#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa0vel['20tmax'] = copy.copy(g.a)
PPa0vel['20tmax'] = copy.copy(h.a)

# %%
t = tmax[6]
T = tmax[7]
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upstream)
#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa0vel['60tmax'] = copy.copy(g.a)
PPa0vel['60tmax'] = copy.copy(h.a)

# %%
t = tmax[7]
T = tmax[8]
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upstream)
#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa0vel['100tmax'] = copy.copy(g.a)
PPa0vel['100tmax'] = copy.copy(h.a)

# %% [markdown]
# Although [Th] reaches steady state after 100 years, [Pa] takes ~10 times as long because:
#
# 1.) Q
#
# 2.) k_ad
#
# 3.) k_de
#
# are an order of magnitude smaller for Pa.

# %% [markdown]
# # [Pa] according to upstream advection scheme, corrected single cell velocity

# %%
# define initial condition as 0-vel steady state
g.a = copy.copy(DPa0vel['100tmax'])
h.a = copy.copy(PPa0vel['100tmax'])
# setup function adflow for Pa 
reload(ThPa2D)
time = (0, 1, 2, 3, 5, 10, 20, 60, 100)
t = time[0]
T = time[1]
V = 0.02/1000*365.*86400.  # first number in mm/s, corrections give needed value in m/yr ~ 630
xmin = 0
xmax = 1e6
zmin = 0
zmax = 5e3
nz = 20
nx = 30
ng = 1
# chemistry
k_ad, k_de, Q = ThPa2D.k_sorp('Pa', xmin, xmax, zmin, zmax, nx, nz)
# velocity
u = ThPa2D.u_simple(xmin, xmax, zmin, zmax, nx, nz, V)
u = ThPa2D.u_simple_c(u, xmin, xmax, zmin, zmax, nx, nz)
# let initial profile be the 0-vel steady state
init, flowfig = ThPa2D.plot_init(g, h, u, xmin, xmax, zmin, zmax, nx, nz, 'Pa')
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upstream)
#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa1vel = {}
PPa1vel = {}
DPa1vel['1tmax'] = copy.copy(g.a)
PPa1vel['1tmax'] = copy.copy(h.a)

# %%
pp.plot_profiles(zmin,zmax,nz,nx,DPa1vel['1tmax'])
print "Maximum vertical Velocity", u[:,:,0].max()*V/365/86400.*1000.*zmax/xmax, "mm/s"
print "Maximum horizontal Velocity", u[:,:,1].max()*V/365/86400.*1000., "mm/s"
print "Maximum vertical Velocity", u[:,:,0].max()*V*zmax/xmax, "m/yr"

# %%
t = time[1]
T = time[2]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upstream)
#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa1vel['2tmax'] = copy.copy(g.a)
PPa1vel['2tmax'] = copy.copy(h.a)

# %%
pp.plot_profiles(zmin,zmax,nz,nx,DPa1vel['2tmax'])
print T*10,' years: Dissolved Concentrations'

# %%
t = time[2]
T = time[3]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upstream)
#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa1vel['3tmax'] = copy.copy(g.a)
PPa1vel['3tmax'] = copy.copy(h.a)

# %%
pp.plot_profiles(zmin,zmax,nz,nx,DPa1vel['3tmax'])
print T*10,' years: Dissolved Concentrations'

# %%
pp.plot_profiles(zmin,zmax,nz,nx,PPa1vel['3tmax'])
print T*10,' years: Particulate Concentrations'

# %%
t = time[3]
T = time[4]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upstream)
#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa1vel['5tmax'] = copy.copy(g.a)
PPa1vel['5tmax'] = copy.copy(h.a)

# %%
pp.plot_profiles(zmin,zmax,nz,nx,DPa1vel['5tmax'])
print T*10,' years: Dissolved Concentrations'

# %%
t = time[4]
T = time[5]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upstream)
#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa1vel['10tmax'] = copy.copy(g.a)
PPa1vel['10tmax'] = copy.copy(h.a)

# %%
pp.plot_profiles(zmin,zmax,nz,nx,DPa1vel['10tmax'])
print T*10,' years: Dissolved Concentrations'

# %%
t = time[5]
T = time[6]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upstream)
#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa1vel['20tmax'] = copy.copy(g.a)
PPa1vel['20tmax'] = copy.copy(h.a)

# %%
t = time[6]
T = time[7]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upstream)
#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa1vel['60tmax'] = copy.copy(g.a)
PPa1vel['60tmax'] = copy.copy(h.a)

# %%
t = time[7]
T = time[8]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upstream)
#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa1vel['100tmax'] = copy.copy(g.a)
PPa1vel['100tmax'] = copy.copy(h.a)

# %% [markdown]
# The result at 100 years shows that the bottom left corner is unstable. Since the velocity field being used is essentially divergenceless (largest terms order 1e-10), this demonstrates an issue in the upstream advection scheme.
#
# This code has been run with the corrected uz -> ux in the upstream function.

# %% [markdown]
# # [Pa] according to flux-based advection scheme & corrected single cell velocity

# %%
# define initial condition as 0-vel steady state
g.a = copy.copy(DPa0vel['100tmax'])
h.a = copy.copy(PPa0vel['100tmax'])
# setup function adflow for Pa 
reload(ThPa2D)
time = (0, 1, 2, 3, 5, 10, 20, 60, 100)
t = time[0]
T = time[1]
V = 0.02/1000*365.*86400.  # first number in mm/s, corrections give needed value in m/yr ~ 630
xmin = 0
xmax = 1e6
zmin = 0
zmax = 5e3
nz = 20
nx = 30
ng = 1
# chemistry
k_ad, k_de, Q = ThPa2D.k_sorp('Pa', xmin, xmax, zmin, zmax, nx, nz)
# velocity
u = ThPa2D.u_simple(xmin, xmax, zmin, zmax, nx, nz, V)
u = ThPa2D.u_simple_c(u, xmin, xmax, zmin, zmax, nx, nz)
# let initial profile be the 0-vel steady state
init, flowfig = ThPa2D.plot_init(g, h, u, xmin, xmax, zmin, zmax, nx, nz, 'Pa')
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.flux)
#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa1vel = {}
PPa1vel = {}
DPa1vel['1tmax'] = copy.copy(g.a)
PPa1vel['1tmax'] = copy.copy(h.a)

# %%
t = time[1]
T = time[2]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.flux)
#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa1vel['2tmax'] = copy.copy(g.a)
PPa1vel['2tmax'] = copy.copy(h.a)

# %%
t = time[2]
T = time[3]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.flux)
#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa1vel['3tmax'] = copy.copy(g.a)
PPa1vel['3tmax'] = copy.copy(h.a)

# %%
t = time[3]
T = time[4]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.flux)
#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa1vel['5tmax'] = copy.copy(g.a)
PPa1vel['5tmax'] = copy.copy(h.a)

# %%
t = time[4]
T = time[5]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.flux)
#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa1vel['10tmax'] = copy.copy(g.a)
PPa1vel['10tmax'] = copy.copy(h.a)

# %%
t = time[5]
T = time[6]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.flux)
#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa1vel['20tmax'] = copy.copy(g.a)
PPa1vel['20tmax'] = h.a

# %%
t = time[6]
T = time[7]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.flux)
#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa1vel['60tmax'] = copy.copy(g.a)
PPa1vel['60tmax'] = copy.copy(h.a)

# %%
t = time[7]
T = time[8]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.flux)
#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa1vel['100tmax'] = copy.copy(g.a)
PPa1vel['100tmax'] = copy.copy(h.a)

# %% [markdown]
# # [Pa] for Corrected Two Cell Velocity Scheme, upstream advection

# %%
# set initial profile to 0-vel steady state
g.a = copy.copy(DPa0vel['100tmax'])
h.a = copy.copy(PPa0vel['100tmax'])
# setup function adflow for Th 
reload(ThPa2D)
tmax = (0, 1, 2, 3, 5, 10, 20, 60, 100)
t = tmax[0]
T = tmax[1]
V = 0.02/1000*365.*86400.  # first number in mm/s, corrections give needed value in m/yr ~ 630
xmin = 0
xmax = 1e6
zmin = 0
zmax = 5e3
nz = 20
nx = 30
ng = 1
# chemistry
k_ad, k_de, Q = ThPa2D.k_sorp('Pa', xmin, xmax, zmin, zmax, nx, nz)
# velocity
u = ThPa2D.u_complex(xmin, xmax, zmin, zmax, nx, nz, V)
u = ThPa2D.u_complex_c(u, xmin, xmax, zmin, zmax, nx, nz)
# initial conditions
init, flowfig = ThPa2D.plot_init(g, h, u, xmin, xmax, zmin, zmax, nx, nz, 'Pa')
# advection 
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upstream)
#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa2vel = {}
PPa2vel = {}
DPa2vel['1tmax'] = copy.copy(g.a)
PPa2vel['1tmax'] = copy.copy(h.a)
# Out:
# ThPa2D.py:389: RuntimeWarning: invalid value encountered in true_divide
#   uz[idx] = -np.sin(2*pi*rr[idx] / a) / rr[idx] * -xx[idx]
# ThPa2D.py:391: RuntimeWarning: invalid value encountered in true_divide
#   # remove nans

# %%
t = tmax[1]
T = tmax[2]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upstream)
#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa2vel['2tmax'] = copy.copy(g.a)
PPa2vel['2tmax'] = copy.copy(h.a)

# %%
t = tmax[2]
T = tmax[3]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upstream)
#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa2vel['3tmax'] = copy.copy(g.a)
PPa2vel['3tmax'] = copy.copy(h.a)

# %%
t = tmax[3]
T = tmax[4]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upstream)
#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa2vel['5tmax'] = copy.copy(g.a)
PPa2vel['5tmax'] = copy.copy(h.a)

# %%
t = tmax[4]
T = tmax[5]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upstream)
#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa2vel['10tmax'] = copy.copy(g.a)
PPa2vel['10tmax'] = copy.copy(h.a)

# %%
t = tmax[5]
T = tmax[6]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upstream)
#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa2vel['20tmax'] = copy.copy(g.a)
PPa2vel['20tmax'] = copy.copy(h.a)

# %%
t = tmax[6]
T = tmax[7]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upstream)
#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa2vel['60tmax'] = copy.copy(g.a)
PPa2vel['60tmax'] = copy.copy(h.a)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-251-7f9f278fe8f7> in <module>()
#       2 T = tmax[7]
#       3 # Th loop
# ----> 4 g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upstream)
#       5 #plot results
#       6 meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
#
# /home/abellas/Documents/GEOTRACES/Pa-Th/prelim-model/ThPa2D.pyc in adflow(g, h, t, T, u, k_ad, k_de, Q, adscheme)
#     129         T = T * (g.zmax - g.zmin)*S_i
#     130
# --> 131         g, h = adscheme(g, h, t, T, u, k_ad, k_de, Q, S, dt)
#     132
#     133         return g, h
#
# /home/abellas/Documents/GEOTRACES/Pa-Th/prelim-model/ThPa2D.pyc in upstream(g, h, t, T, u, k_ad, k_de, Q, S, dt)
#     177                 # particulate:
#     178                 bnew[i, j] = h.a[i, j] + ( S * ( (n_upz_p[i, j]*h.a[i - 1, j] - h.a[i, j]) + p_upz_p[i, j]*(h.a[i, j] - h.a[i + 1, j]) ) * h.dz_i + k_ad[i, j] * g.a[i, j] - k_de[i, j] * h.a[i, j] +
# --> 179                     ux[i, j] * ( n_upx[i, j - 1]*(h.a[i, j - 1] - h.a[i, j]) + p_upx[i, j]*(h.a[i, j] - h.a[i, j + 1]) ) * h.dx_i +
#     180                     uz[i, j] * ( n_upz_p[i - 1, j]*(h.a[i - 1, j] - h.a[i, j]) + p_upz_p[i, j]*(h.a[i, j] - h.a[i + 1, j]) ) * h.dz_i ) * dt
#     181
#
# KeyboardInterrupt:

# %%
t = tmax[7]
T = tmax[8]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upstream)
#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa2vel['100tmax'] = copy.copy(g.a)
PPa2vel['100tmax'] = copy.copy(h.a)

# %% [markdown]
# Profiles show that the concentration in a water column is inversely proportional to downwelling. This is a result of upwelling currents effectively reducing the sinking velocity, leading to regions in which the Pa is suspended, or sinking very slowly.
#
# The dissolved and particulate phases appear to be identical except for a scaling factor.

# %% [markdown]
# The solutions at 600 and 1000yrs demonstrate an instability in the code.

# %% [markdown]
# # [Pa] according to flux based advection scheme with 2-cell velocity field

# %%
# set initial profile to 0-vel steady state
g.a = copy.copy(DPa0vel['100tmax'])
h.a = copy.copy(PPa0vel['100tmax'])
# setup function adflow for Th 
reload(ThPa2D)
tmax = (0, 1, 2, 3, 5, 10, 20, 60, 100)
t = tmax[0]
T = tmax[1]
V = 0.02/1000*365.*86400.  # first number in mm/s, corrections give needed value in m/yr ~ 630
xmin = 0
xmax = 1e6
zmin = 0
zmax = 5e3
nz = 20
nx = 30
ng = 1
# chemistry
k_ad, k_de, Q = ThPa2D.k_sorp('Pa', xmin, xmax, zmin, zmax, nx, nz)
# velocity
u = ThPa2D.u_complex(xmin, xmax, zmin, zmax, nx, nz, V)
# run correction code
u = ThPa2D.u_complex_c(u, xmin, xmax, zmin, zmax, nx, nz)
# initial conditions
init, flowfig = ThPa2D.plot_init(g, h, u, xmin, xmax, zmin, zmax, nx, nz, 'Pa')
# advection 
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.flux)
#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa2vel = {}
PPa2vel = {}
DPa2vel['1tmax'] = copy.copy(g.a)
PPa2vel['1tmax'] = copy.copy(h.a)

# %%
t = tmax[1]
T = tmax[2]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.flux)
#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa2vel['2tmax'] = copy.copy(g.a)
PPa2vel['2tmax'] = copy.copy(h.a)

# %%
t = tmax[2]
T = tmax[3]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.flux)
#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa2vel['3tmax'] = copy.copy(g.a)
PPa2vel['3tmax'] = copy.copy(h.a)

# %%
t = tmax[3]
T = tmax[4]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.flux)
#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa2vel['5tmax'] = copy.copy(g.a)
PPa2vel['5tmax'] = copy.copy(h.a)

# %%
t = tmax[4]
T = tmax[5]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.flux)
#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa2vel['10tmax'] = copy.copy(g.a)
PPa2vel['10tmax'] = copy.copy(h.a)

# %%
t = tmax[5]
T = tmax[6]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.flux)
#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa2vel['20tmax'] = copy.copy(g.a)
PPa2vel['20tmax'] = copy.copy(h.a)

# %%
t = tmax[6]
T = tmax[7]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.flux)
#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa2vel['60tmax'] = copy.copy(g.a)
PPa2vel['60tmax'] = copy.copy(h.a)

# %%
t = tmax[7]
T = tmax[8]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.flux)
#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa2vel['100tmax'] = copy.copy(g.a)
PPa2vel['100tmax'] = copy.copy(h.a)

# %% [markdown]
# The system appears to reach steady state after 600 yrs.
