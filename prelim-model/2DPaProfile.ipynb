# %% [markdown]
# Solves the [Pa] on a 2D 1e6m x 5e3m grid using an upwind advection scheme, and contains plots of [Pa] profile for a zero velocity field, a single cell velocity field, and a two cell velocity field.

# %%
from __future__ import division
import numpy
import pylab
import math
import matplotlib.pyplot as plt
from math import pi
import ThPa2D
import profile_plots as pp
# %matplotlib inline

# %% [markdown]
# # [Pa] for Zero Velocity Field

# %%
reload(ThPa2D)
# Out:
# <module 'ThPa2D' from 'ThPa2D.pyc'>

# %%
# setup function adflow for Th 

tmax = (0, 1, 2, 3, 5, 10)
t = tmax[0]
T = tmax[1]
V = 1
xmin = 1
xmax = 1e6
zmin = 0
zmax = 5e3
nz = 20
nx = 20
ng = 1
g = ThPa2D.FDgrid(nx, nz, ng)
h = ThPa2D.FDgrid(nx, nz, ng)

# chemistry
k_ad, k_de, Q = ThPa2D.k_sorp('Pa', xmin, xmax, zmin, zmax, nx, nz)

# velocity
u, flowfig, init = ThPa2D.u_zero(g, h, xmin, xmax, zmin, zmax, nx, nz, V, 'Pa')

# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upwind)

#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')

# store results
DPa0vel = {}
PPa0vel = {}
DPa0vel['1tmax'] = g.a
PPa0vel['1tmax'] = h.a
# Out:
# /home/abellas/anaconda/lib/python2.7/site-packages/matplotlib/quiver.py:570: RuntimeWarning: divide by zero encountered in double_scalars
#   length = a * (widthu_per_lenu / (self.scale * self.width))
# /home/abellas/anaconda/lib/python2.7/site-packages/matplotlib/quiver.py:570: RuntimeWarning: invalid value encountered in multiply
#   length = a * (widthu_per_lenu / (self.scale * self.width))
# /home/abellas/anaconda/lib/python2.7/site-packages/matplotlib/quiver.py:626: RuntimeWarning: invalid value encountered in less
#   short = np.repeat(length < minsh, 8, axis=1)
# /home/abellas/anaconda/lib/python2.7/site-packages/matplotlib/quiver.py:636: RuntimeWarning: invalid value encountered in less
#   tooshort = length < self.minlength

# %%
plt.plot (DPa0vel['1tmax'][:,2],'b',DPa0vel['1tmax'][:,18],'r')
# Out:
# [<matplotlib.lines.Line2D at 0x46a7310>,
#  <matplotlib.lines.Line2D at 0x46a7590>]

# %%
t = tmax[1]
T = tmax[2]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upwind)

#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')

# store results
DPa0vel['2tmax'] = g.a
PPa0vel['2tmax'] = h.a

# %%
t = tmax[2]
T = tmax[3]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upwind)

#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')

# store results
DPa0vel['3tmax'] = g.a
PPa0vel['3tmax'] = h.a

# %%
t = tmax[3]
T = tmax[4]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upwind)

#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')

# store results
DPa0vel['5tmax'] = g.a
PPa0vel['5tmax'] = h.a

# %%
t = tmax[4]
T = tmax[5]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upwind)

#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')

# store results
DPa0vel['10tmax'] = g.a
PPa0vel['10tmax'] = h.a

# %% [markdown]
# # [Pa] for Single Cell Velocity Field

# %%
reload(ThPa2D)
# Out:
# <module 'ThPa2D' from 'ThPa2D.py'>

# %%
# setup function adflow for Pa 

time = (0, 1, 2, 3, 5, 10)
t = time[0]
T = time[1]
V = 0.02/1000*365.*86400.  # first number in mm/s, corrections give needed value in m/yr ~ 630
xmin = 0
xmax = 1e6
zmin = 0
zmax = 5e3
nz = 20
nx = 20
ng = 1
g = ThPa2D.FDgrid(nx, nz, ng)
h = ThPa2D.FDgrid(nx, nz, ng)

# chemistry
k_ad, k_de, Q = ThPa2D.k_sorp('Pa', xmin, xmax, zmin, zmax, nx, nz)

# velocity
u, flowfig, init = ThPa2D.u_simple(g, h, xmin, xmax, zmin, zmax, nx, nz, V, 'Pa')

# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upwind)

#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')

# store results
DPa1vel = {}
PPa1vel = {}
DPa1vel['1tmax'] = g.a
PPa1vel['1tmax'] = h.a

# %%
pp.plot_profiles(zmin,zmax,nz,nx,DPa1vel['1tmax'])
print "Maximum vertical Velocity", u[:,:,0].max()*V/365/86400.*1000.*zmax/xmax, "mm/s"
print "Maximum horizontal Velocity", u[:,:,1].max()*V/365/86400.*1000., "mm/s"
print "Maximum vertical Velocity", u[:,:,0].max()*V*zmax/xmax, "m/yr"
# Out:
# Maximum vertical Velocity 0.00031536 mm/s
# Maximum horizontal Velocity 12.6144 mm/s
# Maximum vertical Velocity 9.94519296 m/yr

# %%
t = time[1]
T = time[2]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upwind)

#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')

# store results
DPa1vel['2tmax'] = g.a
PPa1vel['2tmax'] = h.a

# %%
pp.plot_profiles(zmin,zmax,nz,nx,DPa1vel['2tmax'])
print T*10,' years: Dissolved Concentrations'
# Out:
# 20  years: Dissolved Concentrations

# %%
t = time[2]
T = time[3]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upwind)

#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')

# store results
DPa1vel['3tmax'] = g.a
PPa1vel['3tmax'] = h.a

# %%
pp.plot_profiles(zmin,zmax,nz,nx,DPa1vel['3tmax'])
print T*10,' years: Dissolved Concentrations'
# Out:
# 30  years: Dissolved Concentrations

# %%
pp.plot_profiles(zmin,zmax,nz,nx,PPa1vel['3tmax'])
print T*10,' years: Particulate Concentrations'
# Out:
# 30  years: Particulate Concentrations

# %%
t = time[3]
T = time[4]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upwind)

#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')

# store results
DPa1vel['5tmax'] = g.a
PPa1vel['5tmax'] = h.a

# %%
pp.plot_profiles(zmin,zmax,nz,nx,DPa1vel['5tmax'])
print T*10,' years: Dissolved Concentrations'
# Out:
# 50  years: Dissolved Concentrations

# %%
t = time[4]
T = time[5]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upwind)

#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')

# store results
DPa1vel['10tmax'] = g.a
PPa1vel['10tmax'] = h.a

# %%
pp.plot_profiles(zmin,zmax,nz,nx,DPa1vel['10tmax'])
print T*10,' years: Dissolved Concentrations'
# Out:
# 100  years: Dissolved Concentrations

# %% [markdown]
# # [Pa] for Two Cell Velocity Scheme

# %%
reload(ThPa2D)
# Out:
# <module 'ThPa2D' from 'ThPa2D.py'>

# %%
# setup function adflow for Th 

tmax = (0, 1, 2, 3, 5, 10)
t = tmax[0]
T = tmax[1]
V = 0.02/1000*365.*86400.  # first number in mm/s, corrections give needed value in m/yr ~ 630
xmin = 0
xmax = 1e6
zmin = 0
zmax = 5e3
nz = 20
nx = 20
ng = 1
g = ThPa2D.FDgrid(nx, nz, ng)
h = ThPa2D.FDgrid(nx, nz, ng)

# chemistry
k_ad, k_de, Q = ThPa2D.k_sorp('Pa', xmin, xmax, zmin, zmax, nx, nz)

# velocity
u, flowfig, init = ThPa2D.u_complex(g, h, xmin, xmax, zmin, zmax, nx, nz, V, 'Pa')

# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upwind)

#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')

# store results
DPa2vel = {}
PPa2vel = {}
DPa2vel['1tmax'] = g.a
PPa2vel['1tmax'] = h.a
# Out:
# ThPa2D.py:405: RuntimeWarning: invalid value encountered in true_divide

# %%
t = tmax[1]
T = tmax[2]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upwind)

#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')

# store results
DPa2vel['2tmax'] = g.a
PPa2vel['2tmax'] = h.a

# %%
t = tmax[2]
T = tmax[3]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upwind)

#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')

# store results
DPa2vel['3tmax'] = g.a
PPa2vel['3tmax'] = h.a

# %%
t = tmax[3]
T = tmax[4]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upwind)

#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')

# store results
DPa2vel['5tmax'] = g.a
PPa2vel['5tmax'] = h.a

# %%
t = tmax[4]
T = tmax[5]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upwind)

#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')

# store results
DPa2vel['10tmax'] = g.a
PPa2vel['10tmax'] = h.a

# %% [markdown]
# At 850km there is a column of high [Pa]. This is likely a relic of an error because
#
# a.) the model is symmetric and it is not mirrored at 150 km.  *Now it is mirrored.  Note model is not quite symmetric
#
# b.) it is in a region of upwelling, which should be characterized by low [Pa]. *Upwelling is high dissolved Pa
#
# Hopefully this will be mitigated now that the BC have been altered.

# %%
tmax = (0, 1, 2, 3, 5, 10, 15)
t = tmax[5]
T = tmax[6]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upwind)

#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')

# store results
DPa2vel['15tmax'] = g.a
PPa2vel['15tmax'] = h.a

# %% [markdown]
# The solution is symmetric from 500km outward until the 650 : 350 mirror. Beyond that point, the solution are quite different. Check BCs.

# %%
tmax = (0, 1, 2, 3, 5, 10, 15, 20)
t = tmax[6]
T = tmax[7]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upwind)

#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')

# store results
DPa2vel['20tmax'] = g.a
PPa2vel['20tmax'] = h.a

# %%
tmax = (0, 1, 2, 3, 5, 10, 15, 20, 30)
t = tmax[7]
T = tmax[8]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upwind)

#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')

# store results
DPa2vel['30tmax'] = g.a
PPa2vel['30tmax'] = h.a

# %%
tmax = (0, 1, 2, 3, 5, 10, 15, 20, 30, 60)
t = tmax[8]
T = tmax[9]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.upwind)

#plot results
meshTh = ThPa2D.plotprof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')

# store results
DPa2vel['60tmax'] = g.a
PPa2vel['60tmax'] = h.a

# %% [markdown]
# The assymetry of the dissolved [Pa] profile is disconcerting. The boundary conditions at x = 0 and x = 1000km are congruent with each other:
# g(:, 0) = g(:, 1) & g(:, end) = g(:, end - 1).
#
# The high [Pa] in downwelling region is expected, as is low [Pa] in upwelling regions.
#
# Check if this arises using adflow before creation of upwind and vectorization of j index.
#
# It does. Is this definitely a stability error? Why would an assymetry in the distribution arise?
# *I think the flow does not conserve mass well enough.  Fix to come.
