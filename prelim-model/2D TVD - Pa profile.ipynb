# %% [markdown]
# Plotting [Pa] under TVD advection scheme

# %%
from __future__ import division
import numpy as np
import pylab as plb
import math
import copy
import matplotlib.pyplot as plt
from math import pi
import ThPa2D
import twoflow
import twoplot
import profile_plots as pp
# %matplotlib inline

# %% [markdown]
# ## For dt = 0.1

# %%
# setup function adflow for Th 
reload(ThPa2D);reload(twoplot);reload(twoflow)
#time coordinates
tmax = (0, 1, 2, 3, 5, 10, 20, 60, 100);   t = tmax[0];   T = tmax[1];    dt = 0.1
# spatial coordinates
xmin = 0;   xmax = 1e6;   zmin = 0;   zmax = 5e3;   nz = 20;   nx = 30;  ng = 1
# data storage structures
g = ThPa2D.Fgrid(nx, nz, ng, dt);  h = ThPa2D.Fgrid(nx, nz, ng, dt)
# chemistry
k_ad, k_de, Q = ThPa2D.k_sorp2('Pa', zmin, zmax, nx, nz)
# velocity
V = 0.02/1000*365.*86400.
u = twoflow.zero(nz, nx)
#u = twoflow.onecell_cen(xmin, xmax, zmin, zmax, nx, nz, V)
# initial profile
init = twoplot.init(g.a, h.a, u, xmin, xmax, zmin, zmax, nx, nz, 'Pa')
# time evolution
#g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.TVD)
# plot
#meshTh = twoplot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store
DPa0vel = {}
PPa0vel = {}
DPa0vel['1tmax'] = copy.copy(g.a)
PPa0vel['1tmax'] = copy.copy(h.a)
# Out:
# /home/sallen/anaconda/lib/python2.7/site-packages/matplotlib/colorbar.py:829: RuntimeWarning: invalid value encountered in divide
#   z = np.take(y, i0) + (xn - np.take(b, i0)) * dy / db
# /home/sallen/anaconda/lib/python2.7/site-packages/matplotlib/colorbar.py:581: RuntimeWarning: invalid value encountered in greater
#   inrange = (ticks > -0.001) & (ticks < 1.001)
# /home/sallen/anaconda/lib/python2.7/site-packages/matplotlib/colorbar.py:581: RuntimeWarning: invalid value encountered in less
#   inrange = (ticks > -0.001) & (ticks < 1.001)
# /home/sallen/anaconda/lib/python2.7/site-packages/matplotlib/quiver.py:570: RuntimeWarning: divide by zero encountered in double_scalars
#   length = a * (widthu_per_lenu / (self.scale * self.width))
# /home/sallen/anaconda/lib/python2.7/site-packages/matplotlib/quiver.py:570: RuntimeWarning: invalid value encountered in multiply
#   length = a * (widthu_per_lenu / (self.scale * self.width))
# /home/sallen/anaconda/lib/python2.7/site-packages/matplotlib/quiver.py:626: RuntimeWarning: invalid value encountered in less
#   short = np.repeat(length < minsh, 8, axis=1)
# /home/sallen/anaconda/lib/python2.7/site-packages/matplotlib/quiver.py:636: RuntimeWarning: invalid value encountered in less
#   tooshort = length < self.minlength

# %%
plt.plot (DPa0vel['1tmax'][:,2],'b*-',DPa0vel['1tmax'][:,18],'r*-')
# Out:
# [<matplotlib.lines.Line2D at 0x4d22ed0>,
#  <matplotlib.lines.Line2D at 0x4d22bd0>]

# %%
t = tmax[1]
T = tmax[2]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.TVD)
#plot results
meshTh = twoplot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa0vel['2tmax'] = copy.copy(g.a)
PPa0vel['2tmax'] = copy.copy(h.a)
# Out:
# (19, 28) (18, 29)

# %%
plt.plot (DPa0vel['2tmax'][:,2],'b*-',DPa0vel['2tmax'][:,18],'r*-')
# Out:
# [<matplotlib.lines.Line2D at 0x5340450>,
#  <matplotlib.lines.Line2D at 0x518abd0>]

# %%
plt.plot (PPa0vel['2tmax'][:,2],'b*-',PPa0vel['2tmax'][:,18],'r*-')
# Out:
# [<matplotlib.lines.Line2D at 0x5001f50>,
#  <matplotlib.lines.Line2D at 0x5001890>]

# %%
t = tmax[2]
T = tmax[3]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.TVD)
#plot results
meshTh = twoplot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa0vel['3tmax'] = copy.copy(g.a)
PPa0vel['3tmax'] = copy.copy(h.a)
# Out:
# (19, 28) (18, 29)

# %%
plt.plot (DPa0vel['3tmax'][:,2],'b*-',DPa0vel['3tmax'][:,18],'r*-')
# Out:
# [<matplotlib.lines.Line2D at 0x589a510>,
#  <matplotlib.lines.Line2D at 0x58a0fd0>]

# %%
plt.plot (PPa0vel['3tmax'][:,2],'b*-',PPa0vel['3tmax'][:,18],'r*-')
# Out:
# [<matplotlib.lines.Line2D at 0x5601ed0>,
#  <matplotlib.lines.Line2D at 0x5601110>]

# %%
t = tmax[3]
T = tmax[4]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.TVD)
#plot results
meshTh = twoplot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa0vel['5tmax'] = copy.copy(g.a)
PPa0vel['5tmax'] = copy.copy(h.a)
# Out:
# (19, 28) (18, 29)

# %%
plt.plot (DPa0vel['5tmax'][:,2],'b*-',DPa0vel['5tmax'][:,18],'r*-')
# Out:
# [<matplotlib.lines.Line2D at 0x5fb8f50>,
#  <matplotlib.lines.Line2D at 0x5fb8810>]

# %%
plt.plot (PPa0vel['5tmax'][:,2],'b*-',PPa0vel['5tmax'][:,18],'r*-')
# Out:
# [<matplotlib.lines.Line2D at 0x5fbe310>,
#  <matplotlib.lines.Line2D at 0x5fbe690>]

# %%
pp.plot_profiles(zmin,zmax,nz,nx,DPa0vel['5tmax'])
print T*10,' years: Dissolved Concentrations'
# Out:
# 50  years: Dissolved Concentrations

# %%
t = tmax[4]
T = tmax[5]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.TVD)
#plot results
meshTh = twoplot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa0vel['10tmax'] = copy.copy(g.a)
PPa0vel['10tmax'] = copy.copy(h.a)
# Out:
# (19, 28) (18, 29)

# %%
pp.plot_profiles(zmin,zmax,nz,nx,DPa0vel['10tmax'])
print T*10,' years: Dissolved Concentrations'
# Out:
# 100  years: Dissolved Concentrations

# %%
plt.plot(DPa0vel['10tmax'][:,3])

# %%
t = tmax[5]
T = tmax[6]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.TVD)
#plot results
meshTh = twoplot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa0vel['20tmax'] = copy.copy(g.a)
PPa0vel['20tmax'] = copy.copy(h.a)
# Out:
# (19, 28) (18, 29)

# %%
plt.plot(DPa0vel['20tmax'][:,3])

# %%
t = tmax[6]
T = tmax[7]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.TVD)
#plot results
meshTh = twoplot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa0vel['600tmax'] = copy.copy(g.a)
PPa0vel['600tmax'] = copy.copy(h.a)
# Out:
# (19, 28) (18, 29)

# %%
t = tmax[7]
T = tmax[8]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.TVD)
#plot results
meshTh = twoplot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa0vel['1000tmax'] = copy.copy(g.a)
PPa0vel['1000tmax'] = copy.copy(h.a)
# Out:
# (19, 28) (18, 29)

# %% [markdown]
# Needs finer spatial grid than 20x32.

# %% [markdown]
# # 2-cell velocity

# %%
# setup function adflow for Th 
reload(ThPa2D);reload(plot);reload(flow)
#time coordinates
tmax = (0, 1, 2, 3, 5, 10, 20, 60, 100);t = tmax[0];T = tmax[1];dt = 0.01
# spatial coordinates
xmin = 0;xmax = 1e6;zmin = 0;zmax = 5e3;nz = 20;nx = 32;ng = 1
# data storage structures
g = ThPa2D.Fgrid(nx, nz, ng, dt);h = ThPa2D.Fgrid(nx, nz, ng, dt)
# chemistry
k_ad, k_de, Q = ThPa2D.k_sorp('Pa', zmin, zmax, nx, nz)
# velocity
V = 0.02/1000*365.*86400.
u = flow.twocell_cen(xmin, xmax, zmin, zmax, nx, nz, V)
# initial profile
init = plot.init(g.a, h.a, u, xmin, xmax, zmin, zmax, nx, nz, 'Pa')
# time evolution
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.TVD)
# plot
meshTh = plot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store
DPa0vel = {}
PPa0vel = {}
DPa0vel['1tmax'] = copy.copy(g.a)
PPa0vel['1tmax'] = copy.copy(h.a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-136-0d38614f14b1> in <module>()
#       1 # setup function adflow for Th
# ----> 2 reload(ThPa2D);reload(plot);reload(flow)
#       3 #time coordinates
#       4 tmax = (0, 1, 2, 3, 5, 10, 20, 60, 100);t = tmax[0];T = tmax[1];dt = 0.01
#       5 # spatial coordinates
#
# NameError: name 'plot' is not defined

# %%
t = tmax[1]
T = tmax[2]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.TVD)
#plot results
meshTh = plot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa0vel['2tmax'] = copy.copy(g.a)
PPa0vel['2tmax'] = copy.copy(h.a)

# %%
t = tmax[2]
T = tmax[3]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.TVD)
#plot results
meshTh = plot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa0vel['3tmax'] = copy.copy(g.a)
PPa0vel['3tmax'] = copy.copy(h.a)

# %%
t = tmax[3]
T = tmax[4]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.TVD)
#plot results
meshTh = plot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa0vel['5tmax'] = copy.copy(g.a)
PPa0vel['5tmax'] = copy.copy(h.a)

# %%
t = tmax[4]
T = tmax[5]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.TVD)
#plot results
meshTh = plot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa0vel['10tmax'] = copy.copy(g.a)
PPa0vel['10tmax'] = copy.copy(h.a)

# %%
t = tmax[5]
T = tmax[6]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.TVD)
#plot results
meshTh = plot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa0vel['20tmax'] = copy.copy(g.a)
PPa0vel['20tmax'] = copy.copy(h.a)

# %%
t = tmax[6]
T = tmax[7]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.TVD)
#plot results
meshTh = plot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa0vel['60tmax'] = copy.copy(g.a)
PPa0vel['60tmax'] = copy.copy(h.a)

# %%
t = tmax[7]
T = tmax[8]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.TVD)
#plot results
meshTh = plot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa0vel['100tmax'] = copy.copy(g.a)
PPa0vel['100tmax'] = copy.copy(h.a)

# %% [markdown]
# Stable, and it looks like the spatial resolution may as well be larger since TVD scheme smooths the result.

# %% [markdown]
# # Courser spatial grid

# %%
# setup function adflow for Th 
reload(ThPa2D);reload(plot);reload(flow)
#time coordinates
tmax = (0, 1, 2, 3, 5, 10, 20, 60, 100);t = tmax[0];T = tmax[1];dt = 0.01
# spatial coordinates
xmin = 0;xmax = 1e6;zmin = 0;zmax = 5e3;nz = 10;nx = 20;ng = 1
# data storage structures
g = ThPa2D.Fgrid(nx, nz, ng, dt);h = ThPa2D.Fgrid(nx, nz, ng, dt)
# chemistry
k_ad, k_de, Q = ThPa2D.k_sorp('Pa', zmin, zmax, nx, nz)
# velocity
V = 0.02/1000*365.*86400.
u = flow.twocell_cen(xmin, xmax, zmin, zmax, nx, nz, V)
# initial profile
init = plot.init(g.a, h.a, u, xmin, xmax, zmin, zmax, nx, nz, 'Pa')
# time evolution
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.TVD)
# plot
meshTh = plot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store
DPa0vel = {}
PPa0vel = {}
DPa0vel['1tmax'] = copy.copy(g.a)
PPa0vel['1tmax'] = copy.copy(h.a)

# %%
t = tmax[1]
T = tmax[2]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.TVD)
#plot results
meshTh = plot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa0vel['2tmax'] = copy.copy(g.a)
PPa0vel['2tmax'] = copy.copy(h.a)

# %%
t = tmax[2]
T = tmax[3]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.TVD)
#plot results
meshTh = plot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa0vel['3tmax'] = copy.copy(g.a)
PPa0vel['3tmax'] = copy.copy(h.a)

# %%
t = tmax[3]
T = tmax[4]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.TVD)
#plot results
meshTh = plot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa0vel['5tmax'] = copy.copy(g.a)
PPa0vel['5tmax'] = copy.copy(h.a)

# %%
t = tmax[4]
T = tmax[5]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.TVD)
#plot results
meshTh = plot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa0vel['10tmax'] = copy.copy(g.a)
PPa0vel['10tmax'] = copy.copy(h.a)

# %%
t = tmax[5]
T = tmax[6]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.TVD)
#plot results
meshTh = plot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa0vel['20tmax'] = copy.copy(g.a)
PPa0vel['20tmax'] = copy.copy(h.a)

# %%
t = tmax[6]
T = tmax[7]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.TVD)
#plot results
meshTh = plot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa0vel['60tmax'] = copy.copy(g.a)
PPa0vel['60tmax'] = copy.copy(h.a)

# %%
t = tmax[7]
T = tmax[8]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.TVD)
#plot results
meshTh = plot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa0vel['100tmax'] = copy.copy(g.a)
PPa0vel['100tmax'] = copy.copy(h.a)

# %% [markdown]
# The smoothing effect of TVD simulates a course-ifying of the grid coordinates. Contrary to my initial thought, this means that TVD actualy requires a finer spatial grid.

# %% [markdown]
# # dt = 0.01, 32x48 grid

# %%
# setup function adflow for Th 
reload(ThPa2D);reload(plot);reload(flow)
#time coordinates
tmax = (0, 1, 2, 3, 5, 10, 20, 60, 100);t = tmax[0];T = tmax[1];dt = 0.01
# spatial coordinates
xmin = 0;xmax = 1e6;zmin = 0;zmax = 5e3;nz = 32;nx = 48;ng = 1
# data storage structures
g = ThPa2D.Fgrid(nx, nz, ng, dt);h = ThPa2D.Fgrid(nx, nz, ng, dt)
# chemistry
k_ad, k_de, Q = ThPa2D.k_sorp('Pa', zmin, zmax, nx, nz)
# velocity
V = 0.02/1000*365.*86400.
u = flow.twocell_cen(xmin, xmax, zmin, zmax, nx, nz, V)
# initial profile
init = plot.init(g.a, h.a, u, xmin, xmax, zmin, zmax, nx, nz, 'Pa')
# time evolution
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.TVD)
# plot
meshTh = plot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store
DPa0vel = {}
PPa0vel = {}
DPa0vel['1tmax'] = copy.copy(g.a)
PPa0vel['1tmax'] = copy.copy(h.a)

# %%
t = tmax[1]
T = tmax[2]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.TVD)
#plot results
meshTh = plot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa0vel['2tmax'] = copy.copy(g.a)
PPa0vel['2tmax'] = copy.copy(h.a)

# %%
t = tmax[2]
T = tmax[3]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.TVD)
#plot results
meshTh = plot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa0vel['3tmax'] = copy.copy(g.a)
PPa0vel['3tmax'] = copy.copy(h.a)

# %%
t = tmax[3]
T = tmax[4]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.TVD)
#plot results
meshTh = plot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa0vel['5tmax'] = copy.copy(g.a)
PPa0vel['5tmax'] = copy.copy(h.a)

# %%
t = tmax[4]
T = tmax[5]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.TVD)
#plot results
meshTh = plot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa0vel['10tmax'] = copy.copy(g.a)
PPa0vel['10tmax'] = copy.copy(h.a)

# %%
t = tmax[5]
T = tmax[6]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.TVD)
#plot results
meshTh = plot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa0vel['20tmax'] = copy.copy(g.a)
PPa0vel['20tmax'] = copy.copy(h.a)

# %%
t = tmax[6]
T = tmax[7]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.TVD)
#plot results
meshTh = plot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa0vel['60tmax'] = copy.copy(g.a)
PPa0vel['60tmax'] = copy.copy(h.a)

# %%
t = tmax[7]
T = tmax[8]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.TVD)
#plot results
meshTh = plot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa0vel['100tmax'] = copy.copy(g.a)
PPa0vel['100tmax'] = copy.copy(h.a)

# %% [markdown]
# 95% of the behaviour captured by the 30x50 grid is visible in the 20x30 grid. There is some interesting behaviour at x = 200km because of the drastic change in adsorption and desorption constants, and the concentration wave is undeniably more beautiful in the finer grid. The concentration wave is difficult to discern in the 20x30 grid plot, so next, try grid 24x36.

# %% [markdown]
# # dt = 0.01, 50 x 80 grid

# %%
# setup function adflow for Th 
reload(ThPa2D);reload(plot);reload(flow)
#time coordinates
tmax = (0, 1, 2, 3, 5, 10, 20, 60, 100);t = tmax[0];T = tmax[1];dt = 0.01
# spatial coordinates
xmin = 0;xmax = 1e6;zmin = 0;zmax = 5e3;nz = 50;nx = 80;ng = 1
# data storage structures
g = ThPa2D.Fgrid(nx, nz, ng, dt);h = ThPa2D.Fgrid(nx, nz, ng, dt)
# chemistry
k_ad, k_de, Q = ThPa2D.k_sorp('Pa', zmin, zmax, nx, nz)
# velocity
V = 0.02/1000*365.*86400.
u = flow.twocell_cen(xmin, xmax, zmin, zmax, nx, nz, V)
# initial profile
init = plot.init(g.a, h.a, u, xmin, xmax, zmin, zmax, nx, nz, 'Pa')
# time evolution
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.TVD)
# plot
meshTh = plot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store
DPa0vel = {}
PPa0vel = {}
DPa0vel['1tmax'] = copy.copy(g.a)
PPa0vel['1tmax'] = copy.copy(h.a)

# %%
t = tmax[1]
T = tmax[2]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.TVD)
#plot results
meshTh = plot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa0vel['2tmax'] = copy.copy(g.a)
PPa0vel['2tmax'] = copy.copy(h.a)

# %%
t = tmax[2]
T = tmax[3]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.TVD)
#plot results
meshTh = plot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa0vel['3tmax'] = copy.copy(g.a)
PPa0vel['3tmax'] = copy.copy(h.a)

# %%
t = tmax[3]
T = tmax[4]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.TVD)
#plot results
meshTh = plot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa0vel['5tmax'] = copy.copy(g.a)
PPa0vel['5tmax'] = copy.copy(h.a)

# %%
t = tmax[4]
T = tmax[5]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.TVD)
#plot results
meshTh = plot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa0vel['10tmax'] = copy.copy(g.a)
PPa0vel['10tmax'] = copy.copy(h.a)

# %%
t = tmax[5]
T = tmax[6]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.TVD)
#plot results
meshTh = plot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa0vel['20tmax'] = copy.copy(g.a)
PPa0vel['20tmax'] = copy.copy(h.a)

# %%
t = tmax[6]
T = tmax[7]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.TVD)
#plot results
meshTh = plot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa0vel['60tmax'] = copy.copy(g.a)
PPa0vel['60tmax'] = copy.copy(h.a)

# %%
t = tmax[7]
T = tmax[8]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.TVD)
#plot results
meshTh = plot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa0vel['100tmax'] = copy.copy(g.a)
PPa0vel['100tmax'] = copy.copy(h.a)

# %% [markdown]
# # dt = 0.05, 50 x 80 grid

# %%
# setup function adflow for Th 
reload(ThPa2D);reload(plot);reload(flow)
#time coordinates
tmax = (0, 1, 2, 3, 5, 10, 20, 60, 100);t = tmax[0];T = tmax[1];dt = 0.05
# spatial coordinates
xmin = 0;xmax = 1e6;zmin = 0;zmax = 5e3;nz = 50;nx = 80;ng = 1
# data storage structures
g = ThPa2D.Fgrid(nx, nz, ng, dt);h = ThPa2D.Fgrid(nx, nz, ng, dt)
# chemistry
k_ad, k_de, Q = ThPa2D.k_sorp('Pa', zmin, zmax, nx, nz)
# velocity
V = 0.02/1000*365.*86400.
u = flow.twocell_cen(xmin, xmax, zmin, zmax, nx, nz, V)
# initial profile
init = plot.init(g.a, h.a, u, xmin, xmax, zmin, zmax, nx, nz, 'Pa')
# time evolution
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.TVD)
# plot
meshTh = plot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store
DPa0vel = {}
PPa0vel = {}
DPa0vel['1tmax'] = copy.copy(g.a)
PPa0vel['1tmax'] = copy.copy(h.a)

# %%
t = tmax[1]
T = tmax[2]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.TVD)
#plot results
meshTh = plot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa0vel['2tmax'] = copy.copy(g.a)
PPa0vel['2tmax'] = copy.copy(h.a)

# %%
t = tmax[2]
T = tmax[3]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.TVD)
#plot results
meshTh = plot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa0vel['3tmax'] = copy.copy(g.a)
PPa0vel['3tmax'] = copy.copy(h.a)

# %%
t = tmax[3]
T = tmax[4]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.TVD)
#plot results
meshTh = plot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa0vel['5tmax'] = copy.copy(g.a)
PPa0vel['5tmax'] = copy.copy(h.a)

# %%
t = tmax[4]
T = tmax[5]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.TVD)
#plot results
meshTh = plot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa0vel['10tmax'] = copy.copy(g.a)
PPa0vel['10tmax'] = copy.copy(h.a)

# %%
t = tmax[5]
T = tmax[6]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.TVD)
#plot results
meshTh = plot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa0vel['20tmax'] = copy.copy(g.a)
PPa0vel['20tmax'] = copy.copy(h.a)

# %%
t = tmax[6]
T = tmax[7]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.TVD)
#plot results
meshTh = plot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa0vel['60tmax'] = copy.copy(g.a)
PPa0vel['60tmax'] = copy.copy(h.a)

# %%
t = tmax[7]
T = tmax[8]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.TVD)
#plot results
meshTh = plot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa0vel['100tmax'] = copy.copy(g.a)
PPa0vel['100tmax'] = copy.copy(h.a)

# %% [markdown]
# Great! time step of 0.05 is stable. Try 0.1:

# %% [markdown]
# # dt = 0.1, 50 x 80 grid

# %%
# setup function adflow for Th 
reload(ThPa2D);reload(plot);reload(flow)
#time coordinates
tmax = (0, 1, 2, 3, 5, 10, 20, 60, 100);t = tmax[0];T = tmax[1];dt = 0.1
# spatial coordinates
xmin = 0;xmax = 1e6;zmin = 0;zmax = 5e3;nz = 50;nx = 80;ng = 1
# data storage structures
g = ThPa2D.Fgrid(nx, nz, ng, dt);h = ThPa2D.Fgrid(nx, nz, ng, dt)
# chemistry
k_ad, k_de, Q = ThPa2D.k_sorp('Pa', zmin, zmax, nx, nz)
# velocity
V = 0.02/1000*365.*86400.
u = flow.twocell_cen(xmin, xmax, zmin, zmax, nx, nz, V)
# initial profile
init = plot.init(g.a, h.a, u, xmin, xmax, zmin, zmax, nx, nz, 'Pa')
# time evolution
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.TVD)
# plot
meshTh = plot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store
DPa0vel = {}
PPa0vel = {}
DPa0vel['1tmax'] = copy.copy(g.a)
PPa0vel['1tmax'] = copy.copy(h.a)

# %%
t = tmax[1]
T = tmax[2]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.TVD)
#plot results
meshTh = plot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa0vel['2tmax'] = copy.copy(g.a)
PPa0vel['2tmax'] = copy.copy(h.a)

# %%
t = tmax[2]
T = tmax[3]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.TVD)
#plot results
meshTh = plot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa0vel['3tmax'] = copy.copy(g.a)
PPa0vel['3tmax'] = copy.copy(h.a)

# %%
t = tmax[3]
T = tmax[4]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.TVD)
#plot results
meshTh = plot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa0vel['5tmax'] = copy.copy(g.a)
PPa0vel['5tmax'] = copy.copy(h.a)

# %%
t = tmax[4]
T = tmax[5]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.TVD)
#plot results
meshTh = plot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa0vel['10tmax'] = copy.copy(g.a)
PPa0vel['10tmax'] = copy.copy(h.a)

# %%
t = tmax[5]
T = tmax[6]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.TVD)
#plot results
meshTh = plot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa0vel['20tmax'] = copy.copy(g.a)
PPa0vel['20tmax'] = copy.copy(h.a)

# %%
t = tmax[6]
T = tmax[7]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.TVD)
#plot results
meshTh = plot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa0vel['60tmax'] = copy.copy(g.a)
PPa0vel['60tmax'] = copy.copy(h.a)

# %%
t = tmax[7]
T = tmax[8]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.TVD)
#plot results
meshTh = plot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa0vel['100tmax'] = copy.copy(g.a)
PPa0vel['100tmax'] = copy.copy(h.a)

# %% [markdown]
# # dt = 0.2

# %%
# setup function adflow for Th 
reload(ThPa2D);reload(plot);reload(flow)
#time coordinates
tmax = (0, 1, 2, 3, 5, 10, 20, 60, 100);t = tmax[0];T = tmax[1];dt = 0.2
# spatial coordinates
xmin = 0;xmax = 1e6;zmin = 0;zmax = 5e3;nz = 50;nx = 80;ng = 1
# data storage structures
g = ThPa2D.Fgrid(nx, nz, ng, dt);h = ThPa2D.Fgrid(nx, nz, ng, dt)
# chemistry
k_ad, k_de, Q = ThPa2D.k_sorp('Pa', zmin, zmax, nx, nz)
# velocity
V = 0.02/1000*365.*86400.
u = flow.twocell_cen(xmin, xmax, zmin, zmax, nx, nz, V)
# initial profile
init = plot.init(g.a, h.a, u, xmin, xmax, zmin, zmax, nx, nz, 'Pa')
# time evolution
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.TVD)
# plot
meshTh = plot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store
DPa0vel = {}
PPa0vel = {}
DPa0vel['1tmax'] = copy.copy(g.a)
PPa0vel['1tmax'] = copy.copy(h.a)

# %% [markdown]
# Starts to go unstable.

# %% [markdown]
# Ideal dt  = 0.1
#
# Ideal grid: 32 x 48 captures 95% of the behaviour in the 50 x 80 plots.

# %% [markdown]
# # dt = 0.1, 32 x 48 grid

# %%
# setup function adflow for Th 
reload(ThPa2D);reload(plot);reload(flow)
#time coordinates
tmax = (0, 1, 2, 3, 5, 10, 20, 60, 100);t = tmax[0];T = tmax[1];dt = 0.1
# spatial coordinates
xmin = 0;xmax = 1e6;zmin = 0;zmax = 5e3;nz = 32;nx = 48;ng = 1
# data storage structures
g = ThPa2D.Fgrid(nx, nz, ng, dt);h = ThPa2D.Fgrid(nx, nz, ng, dt)
# chemistry
k_ad, k_de, Q = ThPa2D.k_sorp('Pa', zmin, zmax, nx, nz)
# velocity
V = 0.02/1000*365.*86400.
u = flow.twocell_cen(xmin, xmax, zmin, zmax, nx, nz, V)
# initial profile
init = plot.init(g.a, h.a, u, xmin, xmax, zmin, zmax, nx, nz, 'Pa')
# time evolution
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.TVD)
# plot
meshTh = plot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store
DPa0vel = {}
PPa0vel = {}
DPa0vel['1tmax'] = copy.copy(g.a)
PPa0vel['1tmax'] = copy.copy(h.a)

# %%
t = tmax[1]
T = tmax[2]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.TVD)
#plot results
meshTh = plot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa0vel['2tmax'] = copy.copy(g.a)
PPa0vel['2tmax'] = copy.copy(h.a)

# %%
t = tmax[2]
T = tmax[3]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.TVD)
#plot results
meshTh = plot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa0vel['3tmax'] = copy.copy(g.a)
PPa0vel['3tmax'] = copy.copy(h.a)

# %%
t = tmax[3]
T = tmax[4]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.TVD)
#plot results
meshTh = plot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa0vel['5tmax'] = copy.copy(g.a)
PPa0vel['5tmax'] = copy.copy(h.a)

# %%
t = tmax[4]
T = tmax[5]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.TVD)
#plot results
meshTh = plot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa0vel['10tmax'] = copy.copy(g.a)
PPa0vel['10tmax'] = copy.copy(h.a)

# %%
t = tmax[5]
T = tmax[6]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.TVD)
#plot results
meshTh = plot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa0vel['20tmax'] = copy.copy(g.a)
PPa0vel['20tmax'] = copy.copy(h.a)

# %%
t = tmax[6]
T = tmax[7]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.TVD)
#plot results
meshTh = plot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa0vel['60tmax'] = copy.copy(g.a)
PPa0vel['60tmax'] = copy.copy(h.a)

# %%
t = tmax[7]
T = tmax[8]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.TVD)
#plot results
meshTh = plot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa0vel['100tmax'] = copy.copy(g.a)
PPa0vel['100tmax'] = copy.copy(h.a)

# %% [markdown]
# Vertical wave behaviour at x = 200km - not good. Try a slightly finer grid:

# %%
# setup function adflow for Th 
reload(ThPa2D);reload(plot);reload(flow)
#time coordinates
tmax = (0, 1, 2, 3, 5, 10, 20, 60, 100);t = tmax[0];T = tmax[1];dt = 0.1
# spatial coordinates
xmin = 0;xmax = 1e6;zmin = 0;zmax = 5e3;nz = 36;nx = 56;ng = 1
# data storage structures
g = ThPa2D.Fgrid(nx, nz, ng, dt);h = ThPa2D.Fgrid(nx, nz, ng, dt)
# chemistry
k_ad, k_de, Q = ThPa2D.k_sorp('Pa', zmin, zmax, nx, nz)
# velocity
V = 0.02/1000*365.*86400.
u = twoflow.twocell_cen(xmin, xmax, zmin, zmax, nx, nz, V)
# initial profile
init = plot.init(g.a, h.a, u, xmin, xmax, zmin, zmax, nx, nz, 'Pa')
# time evolution
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.TVD)
# plot
meshTh = plot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store
DPa0vel = {}
PPa0vel = {}
DPa0vel['1tmax'] = copy.copy(g.a)
PPa0vel['1tmax'] = copy.copy(h.a)

# %%
t = tmax[1]
T = tmax[2]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.TVD)
#plot results
meshTh = plot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa0vel['2tmax'] = copy.copy(g.a)
PPa0vel['2tmax'] = copy.copy(h.a)

# %%
t = tmax[2]
T = tmax[3]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.TVD)
#plot results
meshTh = plot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa0vel['3tmax'] = copy.copy(g.a)
PPa0vel['3tmax'] = copy.copy(h.a)

# %%
t = tmax[3]
T = tmax[4]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.TVD)
#plot results
meshTh = plot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa0vel['5tmax'] = copy.copy(g.a)
PPa0vel['5tmax'] = copy.copy(h.a)

# %%
t = tmax[4]
T = tmax[5]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.TVD)
#plot results
meshTh = plot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa0vel['10tmax'] = copy.copy(g.a)
PPa0vel['10tmax'] = copy.copy(h.a)

# %%
t = tmax[5]
T = tmax[6]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.TVD)
#plot results
meshTh = plot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa0vel['20tmax'] = copy.copy(g.a)
PPa0vel['20tmax'] = copy.copy(h.a)

# %%
t = tmax[6]
T = tmax[7]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.TVD)
#plot results
meshTh = plot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa0vel['60tmax'] = copy.copy(g.a)
PPa0vel['60tmax'] = copy.copy(h.a)

# %%
t = tmax[7]
T = tmax[8]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.TVD)
#plot results
meshTh = plot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa0vel['100tmax'] = copy.copy(g.a)
PPa0vel['100tmax'] = copy.copy(h.a)

# %% [markdown]
# Still exhibiting vert. wave, need still finer grid:

# %%
# setup function adflow for Th 
reload(ThPa2D);reload(plot);reload(flow)
#time coordinates
tmax = (0, 1, 2, 3, 5, 10, 20, 60, 100);t = tmax[0];T = tmax[1];dt = 0.1
# spatial coordinates
xmin = 0;xmax = 1e6;zmin = 0;zmax = 5e3;nz = 42;nx = 56;ng = 1
# data storage structures
g = ThPa2D.Fgrid(nx, nz, ng, dt);h = ThPa2D.Fgrid(nx, nz, ng, dt)
# chemistry
k_ad, k_de, Q = ThPa2D.k_sorp('Pa', zmin, zmax, nx, nz)
# velocity
V = 0.02/1000*365.*86400.
u = flow.twocell_cen(xmin, xmax, zmin, zmax, nx, nz, V)
# initial profile
init = plot.init(g.a, h.a, u, xmin, xmax, zmin, zmax, nx, nz, 'Pa')
# time evolution
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.TVD)
# plot
meshTh = plot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store
DPa0vel = {}
PPa0vel = {}
DPa0vel['1tmax'] = copy.copy(g.a)
PPa0vel['1tmax'] = copy.copy(h.a)

# %%
t = tmax[1]
T = tmax[2]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.TVD)
#plot results
meshTh = plot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa0vel['2tmax'] = copy.copy(g.a)
PPa0vel['2tmax'] = copy.copy(h.a)

# %%
t = tmax[2]
T = tmax[3]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.TVD)
#plot results
meshTh = plot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa0vel['3tmax'] = copy.copy(g.a)
PPa0vel['3tmax'] = copy.copy(h.a)

# %%
t = tmax[3]
T = tmax[4]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.TVD)
#plot results
meshTh = plot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa0vel['5tmax'] = copy.copy(g.a)
PPa0vel['5tmax'] = copy.copy(h.a)

# %%
t = tmax[4]
T = tmax[5]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.TVD)
#plot results
meshTh = plot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa0vel['10tmax'] = copy.copy(g.a)
PPa0vel['10tmax'] = copy.copy(h.a)

# %%
t = tmax[5]
T = tmax[6]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.TVD)
#plot results
meshTh = plot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa0vel['20tmax'] = copy.copy(g.a)
PPa0vel['20tmax'] = copy.copy(h.a)

# %%
t = tmax[6]
T = tmax[7]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.TVD)
#plot results
meshTh = plot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa0vel['60tmax'] = copy.copy(g.a)
PPa0vel['60tmax'] = copy.copy(h.a)

# %%
t = tmax[7]
T = tmax[8]
# Th loop
g, h = ThPa2D.adflow(g, h, t, T, u, k_ad, k_de, Q, ThPa2D.TVD)
#plot results
meshTh = plot.prof(g, h, xmin, xmax, zmin, zmax, nx, nz, T, 'Pa')
# store results
DPa0vel['100tmax'] = copy.copy(g.a)
PPa0vel['100tmax'] = copy.copy(h.a)

# %% [markdown]
# There is a tade-off between spatial courseness and temporal courseness. The solution is reasonable and resolves 95% of the solution with 42 x 56 grid.
